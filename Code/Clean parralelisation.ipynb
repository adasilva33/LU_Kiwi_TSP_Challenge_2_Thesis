# %% [markdown]
# ### Transform log to pickle

# %%
import os
import pickle
from Logs_process import logs_analysis

# Define the directory path
directory_path = r"/Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset"

# Get a list of all files in the directory
all_files = os.listdir(directory_path)

# Filter out files that are not between 1.in and 14.in
filtered_files = [
    file for file in all_files if file not in [f"{i}.in" for i in range(1, 15)]
]

# Get the full paths of the filtered files
file_paths = [os.path.join(directory_path, file) for file in filtered_files]

# Loop through each file path
for path in file_paths:
    # Extract the file name without extension
    name = os.path.splitext(os.path.basename(path))[0]

    # Print the name and the full path
    print(f"Name without extension: {name}")
    print(f"Full path: {path}\n")

    # Assuming logs_analysis is a custom class or function you've defined elsewhere
    L = logs_analysis(
        root_dir=path,
        create_or_not=True,
        do_we_delete=True,
    )

    # Extract log data using the method from your logs_analysis class
    log_data = L.extract_log_data(L.root_dir)

    # Define the path for the pickle file to be saved
    pickle_file_path = os.path.join(directory_path, f"{name}.pkl")

    # Save the extracted log data as a pickle file
    with open(pickle_file_path, "wb") as file:
        pickle.dump(log_data, file)

    print(f"Saved pickle file: {pickle_file_path}\n")

# Deleting original files after processing
for path in file_paths:
    if os.path.isfile(path):
        os.remove(path)
        print(f"Deleted file: {path}")
    else:
        print(f"File not found: {path}")
# Out:
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_3
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_3.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_3.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_58
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_58.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_58.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_64
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_64.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_64.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_70
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_70.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_70.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_71
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_71.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_71.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_65
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_65.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_65.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_59
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_59.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_59.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_2
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_2.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_2.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_0
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_0.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_0.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_73
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_73.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_73.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_67
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_67.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_67.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_98
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_98.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_98.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_99
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_99.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_99.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_66
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_66.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_66.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_72
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_72.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_72.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_1
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_1.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_1.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_5
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_5.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_5.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_76
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_76.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_76.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_62
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_62.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_62.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_89
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_89.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_89.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_88
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_88.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_88.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_63
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_63.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_63.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_77
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_77.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_77.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_4
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_4.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_4.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_6
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_6.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_6.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_61
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_61.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_61.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_75
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_75.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_75.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_49
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_49.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_49.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_48
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_48.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_48.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_74
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_74.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_74.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_60
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_60.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_60.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_7
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_7.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_7.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_13
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_13.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_13.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_12
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_12.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_12.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_38
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_38.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_38.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_10
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_10.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_10.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_11
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_11.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_11.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_39
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_39.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_39.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_15
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_15.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_15.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_29
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_29.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_29.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_28
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_28.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_28.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_14
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_14.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_14.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_16
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_16.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_16.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_17
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_17.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_17.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_26
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_26.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_26.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_32
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_32.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_32.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_33
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_33.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_33.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_27
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_27.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_27.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_19
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_19.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_19.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_31
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_31.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_31.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_25
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_25.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_25.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_24
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_24.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_24.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_30
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_30.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_30.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_18
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_18.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_18.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_34
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_34.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_34.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_20
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_20.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_20.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_21
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_21.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_21.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_35
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_35.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_35.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_23
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_23.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_23.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_37
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_37.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_37.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_36
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_36.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_36.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_22
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_22.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_22.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_79
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_79.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_79.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_45
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_45.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_45.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_51
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_51.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_51.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_86
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_86.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_86.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_92
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_92.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_92.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_93
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_93.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_93.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_87
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_87.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_87.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_50
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_50.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_50.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_44
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_44.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_44.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_78
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_78.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_78.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_9
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_9.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_9.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_52
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_52.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_52.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_46
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_46.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_46.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_91
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_91.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_91.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_85
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_85.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_85.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_84
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_84.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_84.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_90
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_90.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_90.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_47
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_47.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_47.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_53
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_53.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_53.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_8
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_8.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_8.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_57
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_57.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_57.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_43
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_43.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_43.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_94
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_94.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_94.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_80
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_80.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_80.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_81
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_81.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_81.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_95
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_95.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_95.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_42
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_42.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_42.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_56
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_56.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_56.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_40
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_40.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_40.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_54
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_54.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_54.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_68
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_68.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_68.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_83
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_83.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_83.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_97
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_97.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_97.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_96
# ...
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_55
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_55.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_55.pkl
#
# Name without extension: 3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_41
# Full path: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_41.log
#
# File /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/Simulation output.xlsx does not exist.
# Saved pickle file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_41.pkl
#
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_3.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_58.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_64.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_70.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_71.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_65.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_59.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_2.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_0.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_73.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_67.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_98.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_99.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_66.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_72.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_1.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_5.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_76.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_62.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_89.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_88.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_63.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_77.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_4.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_6.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_61.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_75.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_49.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_48.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_74.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_60.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_7.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_13.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_12.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_38.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_10.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_11.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_39.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_15.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_29.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_28.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_14.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_16.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_17.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_26.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_32.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_33.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_27.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_19.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_31.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_25.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_24.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_30.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_18.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_34.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_20.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_21.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_35.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_23.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_37.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_36.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_22.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_79.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_45.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_51.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_86.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_92.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_93.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_87.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_50.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_44.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_78.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_9.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_52.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_46.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_91.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_85.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_84.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_90.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_47.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_53.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_8.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_57.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_43.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_94.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_80.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_81.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_95.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_42.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_56.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_40.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_54.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_68.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_83.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_97.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_96.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_82.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_69.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_55.log
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_41.log

# %% [markdown]
# ### Multiple pickle in one

# %%
# Initialize dictionaries to store aggregated data
aggregated_data = {
    'Best node - day': [],
    'Best node - path': [],
    'Best node - cost': [],
    'Time to preprocess the data': [],
    'Time to find the solution': [],
    'Total time': [],
    'Number of SELECTION phases': [],
    'Number of SIMULATION phases': [],
    'Simulation dictionnary': {},
    'Number childrens':[],
    'Desired expansion policy':[],
    'Desired simulation policy':[], 
    'Desired selection policy':[], 
    'Ratio expansion':[], 
    'Cp':[], 
    'Instance':[]
}

# Get a list of all files in the directory
all_files = os.listdir(directory_path)

# Iterate over each file
for file in all_files:
    # Construct the full path to the file
    file_path = os.path.join(directory_path, file)
    
    # Check if the file is a pickle file
    if file.endswith('.pkl') and file.startswith('3.in'):
        try:
            # Open the pickle file and load its contents
            with open(file_path, 'rb') as f:
                data = pickle.load(f)
            
            # Aggregate the data
            aggregated_data['Best node - day'].append(data.get('Best node - day'))
            aggregated_data['Best node - path'].append(data.get('Best node - path'))
            aggregated_data['Best node - cost'].append(data.get('Best node - cost'))
            aggregated_data['Time to preprocess the data'].append(float(data.get('Time to preprocess the data', 0)))
            aggregated_data['Time to find the solution'].append(float(data.get('Time to find the solution', 0)))
            aggregated_data['Total time'].append(float(data.get('Total time', 0)))
            aggregated_data['Number of SELECTION phases'].append(data.get('Number of SELECTION phases'))
            aggregated_data['Number childrens'].append(data.get('Number childrens'))
            aggregated_data['Desired expansion policy'].append(data.get('Desired expansion policy'))
            aggregated_data['Desired selection policy'].append(data.get('Desired selection policy'))
            aggregated_data['Ratio expansion'].append(float(data.get('Ratio expansion')))
            aggregated_data['Cp'].append(float(data.get('Cp')))
            aggregated_data['Instance'].append(data.get('Instance'))

            # Handle the 'Simulation dictionnary' which is itself a dictionary
            sim_dict = data.get('Simulation dictionnary', {})
            for key, value in sim_dict.items():
                if key in aggregated_data['Simulation dictionnary']:
                    aggregated_data['Simulation dictionnary'][key].extend(value)
                else:
                    aggregated_data['Simulation dictionnary'][key] = value
            
        except Exception as e:
            print(f"Error loading {file}: {e}")

# Save aggregated data to a pickle file
with open("3_not_parralelised.pkl", 'wb') as file:
    pickle.dump(aggregated_data, file)
    
# Deleting files, but skip files that are named '1.in' to '14.in'
files_to_skip = [f"{i}.in" for i in range(1, 15)]

for file in all_files:
    if file in files_to_skip:
        print(f"Skipping file: {file}")
        continue
    
    try:
        file_path = os.path.join(directory_path, file)
        if os.path.isfile(file_path):
            os.remove(file_path)
            print(f"Deleted file: {file_path}")
        else:
            print(f"Skipping non-file entry: {file_path}")
    except Exception as e:
        print(f"Error deleting {file_path}: {e}")
# Out:
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_8.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_90.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_84.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_53.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_47.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_46.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_52.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_85.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_91.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_9.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_87.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_93.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_78.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_44.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_50.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_51.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_45.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_79.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_92.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_86.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_82.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_96.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_41.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_55.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_69.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_68.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_54.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_40.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_97.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_83.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_95.pkl
# Skipping file: 3.in
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_81.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_56.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_42.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_43.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_57.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_80.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_94.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_18.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_30.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_24.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_25.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_31.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_19.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_27.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_33.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_32.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_26.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_22.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_36.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_37.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_23.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_35.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_21.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_20.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_34.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_39.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_11.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_10.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_38.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_12.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_13.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_17.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_16.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_14.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_28.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_29.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_15.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_1.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_99.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_72.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_66.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_67.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_73.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_98.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_0.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_2.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_59.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_65.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_71.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_70.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_64.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_58.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_3.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_7.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_60.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_74.pkl
# Skipping file: 1.in
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_48.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_49.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_75.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_61.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_6.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_4.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_88.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_77.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_63.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_62.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_76.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_89.pkl
# Deleted file: /Users/adslv/Documents/LU/Term 3/Kiwi_TSP_Challenge/Code/Flight connections dataset/3.in_5_greedy_policy_ratio_k_0.5_100_UCB_0.5_5.pkl
