# %%
import numpy as np
import random
from copy import deepcopy

# %%
class data_preprocessing:
    def __init__(self,instance_path):
        self.instance_path=instance_path
        
        self.info, self.flights = self.read_file(f_name=self.instance_path)
        self.number_of_areas,self.starting_airport=int(self.info[0][0]),self.info[0][1]
        
        
        self.flights_by_day_dict = self.flights_by_day(flight_list=self.flights)
        
        self.flights_by_day_dict=self.remove_duplicate(flights_by_day=self.flights_by_day_dict)
        
        self.list_days= [k for k in range(1,self.number_of_areas)]
        
        self.airports_by_area = self.get_airports_by_areas()
        self.area_to_explore=self.which_area_to_explore(airports_by_area=self.airports_by_area)
        self.area_by_airport=self.invert_dict(original_dict=self.airports_by_area)
        
        self.starting_area=self.associated_area_to_airport(airport=self.starting_airport)
        self.list_airports=self.get_list_of_airports()
        self.list_areas=list(self.airports_by_area.keys())
        self.areas_connections_by_day=self.possible_flights_from_zone_to_zone_specific_day()
        
    def read_file(self,f_name):
        dist = []
        line_nu = -1
        with open(f_name) as infile:
            for line in infile:
                line_nu += 1
                if line_nu == 0:
                    index = int(line.split()[0]) * 2 + 1
                if line_nu >= index:
                    temp = line.split()
                    temp[2] = int(temp[2])
                    temp[3] = int(temp[3])
                    dist.append(temp)
                else:
                    dist.append(line.split())
            info = dist[:int(dist[0][0])*2+1]
            flights = dist[int(dist[0][0])*2+1:]
        return info, flights
    
    def flights_by_day(self,flight_list):
        # Create an empty dictionary to hold flights organized by day
        flights_by_day = {}

        # Iterate over each flight in the input list
        for flight in flight_list:
            # Extract the day from the flight entry
            day = flight[2]

            # Create a flight entry without the day
            flight_without_day = flight[:2] + flight[3:]

            # Add the flight to the corresponding day in the dictionary
            if day not in flights_by_day:
                flights_by_day[day] = []
            flights_by_day[day].append(flight_without_day)
            
        return flights_by_day
    
    def flights_from_airport(self,flights_by_day, from_airport, considered_day):
        flights_from_airport = []
        for day, flights in flights_by_day.items():
            if day==considered_day:
                for flight in flights:
                    if flight[0] == from_airport:
                        flights_from_airport.append(flight)
                return flights_from_airport
            else:
                return None

    def invert_dict(self,original_dict):
        inverted_dict = {}
        for key, value_list in original_dict.items():
            for value in value_list:
                if value in inverted_dict:
                    inverted_dict[value].append(key)
                else:
                    inverted_dict[value] = key
        return inverted_dict

    def get_cost(self, day, from_airport, to_airport):
        # Retrieve flights for the specified day and day 0
        flights_day = self.flights_by_day_dict.get(day, [])
        flights_day_0 = self.flights_by_day_dict.get(0, [])
        
        # Find the cost for the specified day
        cost_day = next(
            (flight[2]
            for flight in flights_day
            if flight[0] == from_airport and flight[1] == to_airport),
            float('inf')
        )
        
        # Find the cost for day 0
        cost_day_0 = next(
            (flight[2]
            for flight in flights_day_0
            if flight[0] == from_airport and flight[1] == to_airport),
            float('inf')
        )
        
        # Return the minimum cost if either exists, otherwise inf
        if cost_day == float('inf') and cost_day_0 == float('inf'):
            return float('inf')
        
        return min(cost_day, cost_day_0)

    def possible_flights_from_zone_to_zone_specific_day(self):
        areas_connections_by_day = {}

        for day, flights in self.flights_by_day_dict.items():
            areas_connections_list = []

            for flight in flights:
                connection = f"{self.area_by_airport.get(flight[0])} to {self.area_by_airport.get(flight[1])}"
                if connection not in areas_connections_list:
                    areas_connections_list.append(connection)

            areas_connections_by_day[day] = areas_connections_list

        return areas_connections_by_day

    def get_airports_by_areas(self):
        area_num = int(self.info[0][0])
        return {f"{i}": self.info[2+i * 2] for i in range(0, area_num)}
    
    def get_list_of_airports(self):
        unique_airports = set()

        # Iterate through each sublist and add elements to the set
        for sublist in self.airports_by_area.values():
            for airport in sublist:
                unique_airports.add(airport)
        
        return list(unique_airports)
                    
    def associated_area_to_airport(self,airport):
        return next(
            (
                area
                for area, airports in self.airports_by_area.items()
                if airport in airports
            ),
            "Airport not found",
        ) 
    
    def remove_duplicate(self,flights_by_day):
        for day, flights in flights_by_day.items():
            unique_flights = {}
            for flight in flights:
                flight_key = (flight[0], flight[1])
                if flight_key not in unique_flights:
                    unique_flights[flight_key] = flight
                else:
                    if flight[2] < unique_flights[flight_key][2]:
                        #print(flight[2],unique_flights[flight_key][2])
                        unique_flights[flight_key] = flight
                flights_by_day[day] = list(unique_flights.values())
        return flights_by_day
    
    def possible_flights_from_an_airport_at_a_specific_day(self,day,from_airport):
        daily_flights = self.flights_by_day_dict.get(day, [])
        
        flights_from_airport = []
        for flight in daily_flights:
            if flight[0] == from_airport:
                
                flights_from_airport.append([flight[1], flight[2]])

        return flights_from_airport
    
    def possible_flights_from_an_airport_at_a_specific_day_with_previous_areas(self,day,from_airport, visited_areas):
        daily_flights = self.flights_by_day_dict.get(day, [])
        
        flights_from_airport = []
        for flight in daily_flights:
            #print(self.associated_area_to_airport(airport=flight[0]))
            if (flight[0] == from_airport) and (self.associated_area_to_airport(airport=flight[1]) not in visited_areas):
                
                flights_from_airport.append([flight[1], flight[2]])

        return flights_from_airport
    
    def which_area_to_explore(self,airports_by_area):
        return list({key: len(value) for key, value in airports_by_area.items() if len(value) > 1})

# %%
class Node:
    def __init__(self, state, parent=None):
        self.state = state  # State is a dictionary representing the current situation
        self.parent = parent  # Parent node
        self.children = []  # List of child nodes
        self.visit_count = 0  # Number of times this node has been visited
        self.total_cost = 0  # Total cost accumulated in simulations from this node

    def add_child(self, child_state):
        child_node = Node(child_state, self)
        self.children.append(child_node)
        return child_node

    def is_fully_expanded(self):
        if self.parent is None:
            return False
        return len(self.children) > 0 and all(child.visit_count > 0 for child in self.children)
    
    def best_child(self, c_param=1.41):
        epsilon = 1e-6

        visited_children = [child for child in self.children if (child.visit_count > 0)]
        unvisited_children = [child for child in self.children if child.visit_count == 0]

        sorted_children = sorted(visited_children, key=lambda child: child.total_cost / (child.visit_count + epsilon))
        scores = {child: rank + 1 for rank, child in enumerate(sorted_children)}
        total_scores = sum(scores.values())

        def normalized_score(child):
            return scores[child] / total_scores

        choices_weights = [
            normalized_score(child) + c_param * ( np.log(self.visit_count + 1) / (child.visit_count + epsilon)) ** 0.5
            for child in visited_children
        ]

        print(f"UCT score {choices_weights}")
        best_child_node = self.children[np.argmin(choices_weights)]
        print(f"Selected Node: {best_child_node.state}, , Visit Count: {best_child_node.visit_count}, Total Cost: {best_child_node.total_cost}")  # Log the selected node
        print("Children picked on UCT critera")
        return best_child_node
    
    def update(self, result):
        self.visit_count += 1
        self.total_cost += result

# %%
class MCTS(data_preprocessing):
    def __init__(self, instance, root_state, iterations):
        super().__init__(instance_path=instance)
        self.root = Node(root_state)
        self.iterations = iterations
        self.best_leaf = None
        self.best_leaf_cost = float('inf')
        self.search()

    def expand_node(self, node):
        actions = self.possible_flights_from_an_airport_at_a_specific_day_with_previous_areas(
            node.state['current_day'], node.state['current_airport'], node.state['visited_zones'])

        print('\nExpansion \n')
        for action in actions:
            new_state = self.transition_function(node.state, action)
            child_node = node.add_child(new_state)
            print(f"Children: {child_node.state}, Visit count: {child_node.visit_count}, Total cost: {child_node.total_cost}")
        print('\nEnd Expansion \n')
        
    def transition_function(self, state, action):
        new_state = deepcopy(state)
        new_state['current_day'] += 1
        new_state['current_airport'] = action[0]
        new_state['total_cost'] += action[1]
        new_state['path'].append(action[0])
        new_state['remaining_zones'].remove(self.associated_area_to_airport(airport=new_state['current_airport']))
        new_state['visited_zones'].append(self.associated_area_to_airport(airport=action[0]))
        return new_state

    def random_policy(self, state):
        actions = self.possible_flights_from_an_airport_at_a_specific_day_with_previous_areas(
            day=state['current_day'], from_airport=state['current_airport'], visited_areas=state['visited_zones']
        )
        if not actions:
            return None
        return random.choice(actions)
    
    def select(self, node):
        while True:
            if not node.children:
                self.expand_node(node)
                
                if not node.children:  # No more children can be expanded
                        return node
                return random.choice(node.children)
            
            unvisited_children = self.get_unvisited_children(node)
            if unvisited_children:
                return random.choice(unvisited_children)
            print('\nNo more unvisited children')
            node = node.best_child()
        return node

    def get_unvisited_children(self, node):
        queue = [node]
        unvisited_children = []
        while queue:
            current_node = queue.pop(0)
            for child in current_node.children:
                if child.visit_count == 0:
                    unvisited_children.append(child)
                else:
                    queue.append(child)

        return unvisited_children
 
    def simulate(self, node):
        current_simulation_state = deepcopy(node.state)
        print(f"Selected node for simulation {current_simulation_state}")
        while current_simulation_state['current_day'] != self.number_of_areas:
            action = self.random_policy(current_simulation_state)
            if action is None:  # No valid actions available
                break
            current_simulation_state = self.transition_function(current_simulation_state, action)
        
        flights_to_go_back_initial_zone = self.possible_flights_from_an_airport_at_a_specific_day_with_previous_areas(
            day=current_simulation_state['current_day'], from_airport=current_simulation_state['current_airport'], 
            visited_areas=current_simulation_state['visited_zones'][1:])
        
        min_price = 1000000
        final_airport = None
        
        for flight in flights_to_go_back_initial_zone:
            if flight[1] < min_price:
                min_price = flight[1]
                final_airport = flight[0]

        current_simulation_state['total_cost'] += min_price

        if current_simulation_state['total_cost'] < self.best_leaf_cost:
            self.best_leaf = current_simulation_state
            self.best_leaf_cost = current_simulation_state['total_cost']
        
        print(f"Simulation result: {current_simulation_state}")
        return current_simulation_state['total_cost']

    def backpropagate(self, node, cost):
        while node is not None:
            node.update(cost)
            print(f"Backpropagating Node: {node.state}, Visit Count: {node.visit_count}, Total Cost: {node.total_cost}")

            node = node.parent

    def expand_and_select(self, node):
        if not node.is_fully_expanded():
            self.expand_node(node)
        unvisited_children = self.get_unvisited_children(node)
        if unvisited_children:
            return random.choice(unvisited_children)
        return node.best_child()
        
    def search(self):
        for _ in range(self.iterations):
            node_to_explore = self.select(self.root)
            if node_to_explore.is_fully_expanded():
                node_to_explore = self.expand_and_select(node_to_explore)
            cost = self.simulate(node_to_explore)
            self.backpropagate(node_to_explore, cost)
        
        

    def collect_all_nodes(self):
        nodes = []
        queue = [self.root]
        while queue:
            node = queue.pop(0)
            nodes.append(node)
            queue.extend(node.children)
        return nodes

    def display_all_nodes(self, nodes):
        for node in nodes:
            print(f"State: {node.state}, Visit Count: {node.visit_count}, Total Cost: {node.total_cost}")

# %%
instance_path = 'Flight connections dataset/1.in'
data_processor = data_preprocessing(instance_path=instance_path)

# Define root state
root_state = {
    'current_day': 1,
    'current_airport': data_processor.starting_airport,
    'remaining_zones': [x for x in data_processor.list_areas if x != data_processor.starting_area],  # Exclude the starting area
    'visited_zones': [data_processor.starting_area],  # Exclude the starting area
    'total_cost': 0,
    'path': [data_processor.starting_airport]
}

mcts = MCTS(instance=instance_path, root_state=root_state, iterations=30)
print('\n')
mcts.display_all_nodes(nodes=mcts.collect_all_nodes())
# Out:
# Expansion
#
# Children: {'current_day': 2, 'current_airport': 'AB1', 'remaining_zones': ['2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '1'], 'total_cost': 1, 'path': ['AB0', 'AB1']}, Visit count: 0, Total cost: 0
# Children: {'current_day': 2, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '2'], 'total_cost': 3619, 'path': ['AB0', 'AB2']}, Visit count: 0, Total cost: 0
# Children: {'current_day': 2, 'current_airport': 'AB3', 'remaining_zones': ['1', '2', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '3'], 'total_cost': 4618, 'path': ['AB0', 'AB3']}, Visit count: 0, Total cost: 0
# Children: {'current_day': 2, 'current_airport': 'AB4', 'remaining_zones': ['1', '2', '3', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '4'], 'total_cost': 2127, 'path': ['AB0', 'AB4']}, Visit count: 0, Total cost: 0
# Children: {'current_day': 2, 'current_airport': 'AB5', 'remaining_zones': ['1', '2', '3', '4', '6', '7', '8', '9'], 'visited_zones': ['0', '5'], 'total_cost': 173, 'path': ['AB0', 'AB5']}, Visit count: 0, Total cost: 0
# Children: {'current_day': 2, 'current_airport': 'AB6', 'remaining_zones': ['1', '2', '3', '4', '5', '7', '8', '9'], 'visited_zones': ['0', '6'], 'total_cost': 179, 'path': ['AB0', 'AB6']}, Visit count: 0, Total cost: 0
# Children: {'current_day': 2, 'current_airport': 'AB7', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '8', '9'], 'visited_zones': ['0', '7'], 'total_cost': 192, 'path': ['AB0', 'AB7']}, Visit count: 0, Total cost: 0
# Children: {'current_day': 2, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8'], 'total_cost': 283, 'path': ['AB0', 'AB8']}, Visit count: 0, Total cost: 0
# Children: {'current_day': 2, 'current_airport': 'AB9', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8'], 'visited_zones': ['0', '9'], 'total_cost': 103, 'path': ['AB0', 'AB9']}, Visit count: 0, Total cost: 0
#
# End Expansion
#
# Selected node for simulation {'current_day': 2, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8'], 'total_cost': 283, 'path': ['AB0', 'AB8']}
# Simulation result: {'current_day': 10, 'current_airport': 'AB6', 'remaining_zones': [], 'visited_zones': ['0', '8', '7', '3', '9', '4', '1', '5', '2', '6'], 'total_cost': 6934, 'path': ['AB0', 'AB8', 'AB7', 'AB3', 'AB9', 'AB4', 'AB1', 'AB5', 'AB2', 'AB6']}
# Backpropagating Node: {'current_day': 2, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8'], 'total_cost': 283, 'path': ['AB0', 'AB8']}, Visit Count: 1, Total Cost: 6934
# Backpropagating Node: {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}, Visit Count: 1, Total Cost: 6934
# Selected node for simulation {'current_day': 2, 'current_airport': 'AB1', 'remaining_zones': ['2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '1'], 'total_cost': 1, 'path': ['AB0', 'AB1']}
# Simulation result: {'current_day': 10, 'current_airport': 'AB5', 'remaining_zones': [], 'visited_zones': ['0', '1', '3', '8', '6', '4', '2', '9', '7', '5'], 'total_cost': 14801, 'path': ['AB0', 'AB1', 'AB3', 'AB8', 'AB6', 'AB4', 'AB2', 'AB9', 'AB7', 'AB5']}
# Backpropagating Node: {'current_day': 2, 'current_airport': 'AB1', 'remaining_zones': ['2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '1'], 'total_cost': 1, 'path': ['AB0', 'AB1']}, Visit Count: 1, Total Cost: 14801
# Backpropagating Node: {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}, Visit Count: 2, Total Cost: 21735
# Selected node for simulation {'current_day': 2, 'current_airport': 'AB7', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '8', '9'], 'visited_zones': ['0', '7'], 'total_cost': 192, 'path': ['AB0', 'AB7']}
# Simulation result: {'current_day': 10, 'current_airport': 'AB5', 'remaining_zones': [], 'visited_zones': ['0', '7', '6', '2', '3', '1', '8', '4', '9', '5'], 'total_cost': 10752, 'path': ['AB0', 'AB7', 'AB6', 'AB2', 'AB3', 'AB1', 'AB8', 'AB4', 'AB9', 'AB5']}
# Backpropagating Node: {'current_day': 2, 'current_airport': 'AB7', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '8', '9'], 'visited_zones': ['0', '7'], 'total_cost': 192, 'path': ['AB0', 'AB7']}, Visit Count: 1, Total Cost: 10752
# Backpropagating Node: {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}, Visit Count: 3, Total Cost: 32487
# Selected node for simulation {'current_day': 2, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '2'], 'total_cost': 3619, 'path': ['AB0', 'AB2']}
# Simulation result: {'current_day': 10, 'current_airport': 'AB4', 'remaining_zones': [], 'visited_zones': ['0', '2', '9', '6', '3', '7', '1', '5', '8', '4'], 'total_cost': 13056, 'path': ['AB0', 'AB2', 'AB9', 'AB6', 'AB3', 'AB7', 'AB1', 'AB5', 'AB8', 'AB4']}
# Backpropagating Node: {'current_day': 2, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '2'], 'total_cost': 3619, 'path': ['AB0', 'AB2']}, Visit Count: 1, Total Cost: 13056
# Backpropagating Node: {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}, Visit Count: 4, Total Cost: 45543
# Selected node for simulation {'current_day': 2, 'current_airport': 'AB4', 'remaining_zones': ['1', '2', '3', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '4'], 'total_cost': 2127, 'path': ['AB0', 'AB4']}
# Simulation result: {'current_day': 10, 'current_airport': 'AB1', 'remaining_zones': [], 'visited_zones': ['0', '4', '9', '7', '6', '8', '5', '3', '2', '1'], 'total_cost': 25510, 'path': ['AB0', 'AB4', 'AB9', 'AB7', 'AB6', 'AB8', 'AB5', 'AB3', 'AB2', 'AB1']}
# Backpropagating Node: {'current_day': 2, 'current_airport': 'AB4', 'remaining_zones': ['1', '2', '3', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '4'], 'total_cost': 2127, 'path': ['AB0', 'AB4']}, Visit Count: 1, Total Cost: 25510
# Backpropagating Node: {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}, Visit Count: 5, Total Cost: 71053
# Selected node for simulation {'current_day': 2, 'current_airport': 'AB5', 'remaining_zones': ['1', '2', '3', '4', '6', '7', '8', '9'], 'visited_zones': ['0', '5'], 'total_cost': 173, 'path': ['AB0', 'AB5']}
# Simulation result: {'current_day': 10, 'current_airport': 'AB4', 'remaining_zones': [], 'visited_zones': ['0', '5', '8', '7', '9', '3', '6', '2', '1', '4'], 'total_cost': 18883, 'path': ['AB0', 'AB5', 'AB8', 'AB7', 'AB9', 'AB3', 'AB6', 'AB2', 'AB1', 'AB4']}
# Backpropagating Node: {'current_day': 2, 'current_airport': 'AB5', 'remaining_zones': ['1', '2', '3', '4', '6', '7', '8', '9'], 'visited_zones': ['0', '5'], 'total_cost': 173, 'path': ['AB0', 'AB5']}, Visit Count: 1, Total Cost: 18883
# Backpropagating Node: {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}, Visit Count: 6, Total Cost: 89936
# Selected node for simulation {'current_day': 2, 'current_airport': 'AB3', 'remaining_zones': ['1', '2', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '3'], 'total_cost': 4618, 'path': ['AB0', 'AB3']}
# Simulation result: {'current_day': 10, 'current_airport': 'AB4', 'remaining_zones': [], 'visited_zones': ['0', '3', '2', '6', '7', '5', '9', '8', '1', '4'], 'total_cost': 21394, 'path': ['AB0', 'AB3', 'AB2', 'AB6', 'AB7', 'AB5', 'AB9', 'AB8', 'AB1', 'AB4']}
# Backpropagating Node: {'current_day': 2, 'current_airport': 'AB3', 'remaining_zones': ['1', '2', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '3'], 'total_cost': 4618, 'path': ['AB0', 'AB3']}, Visit Count: 1, Total Cost: 21394
# Backpropagating Node: {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}, Visit Count: 7, Total Cost: 111330
# Selected node for simulation {'current_day': 2, 'current_airport': 'AB9', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8'], 'visited_zones': ['0', '9'], 'total_cost': 103, 'path': ['AB0', 'AB9']}
# Simulation result: {'current_day': 10, 'current_airport': 'AB2', 'remaining_zones': [], 'visited_zones': ['0', '9', '6', '4', '1', '3', '5', '7', '8', '2'], 'total_cost': 28927, 'path': ['AB0', 'AB9', 'AB6', 'AB4', 'AB1', 'AB3', 'AB5', 'AB7', 'AB8', 'AB2']}
# Backpropagating Node: {'current_day': 2, 'current_airport': 'AB9', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8'], 'visited_zones': ['0', '9'], 'total_cost': 103, 'path': ['AB0', 'AB9']}, Visit Count: 1, Total Cost: 28927
# Backpropagating Node: {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}, Visit Count: 8, Total Cost: 140257
# Selected node for simulation {'current_day': 2, 'current_airport': 'AB6', 'remaining_zones': ['1', '2', '3', '4', '5', '7', '8', '9'], 'visited_zones': ['0', '6'], 'total_cost': 179, 'path': ['AB0', 'AB6']}
# Simulation result: {'current_day': 10, 'current_airport': 'AB7', 'remaining_zones': [], 'visited_zones': ['0', '6', '9', '5', '4', '2', '8', '3', '1', '7'], 'total_cost': 14777, 'path': ['AB0', 'AB6', 'AB9', 'AB5', 'AB4', 'AB2', 'AB8', 'AB3', 'AB1', 'AB7']}
# Backpropagating Node: {'current_day': 2, 'current_airport': 'AB6', 'remaining_zones': ['1', '2', '3', '4', '5', '7', '8', '9'], 'visited_zones': ['0', '6'], 'total_cost': 179, 'path': ['AB0', 'AB6']}, Visit Count: 1, Total Cost: 14777
# Backpropagating Node: {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}, Visit Count: 9, Total Cost: 155034
#
# No more unvisited children
# UCT score [2.2506822937588438, 2.2062378493143995, 2.295126738203288, 2.31734896042551, 2.272904515981066, 2.2284600715366216, 2.184015627092177, 2.1617934048699547, 2.339571182647733]
# Selected Node: {'current_day': 2, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8'], 'total_cost': 283, 'path': ['AB0', 'AB8']}, , Visit Count: 1, Total Cost: 6934
# Children picked on UCT critera
#
# Expansion
#
# Children: {'current_day': 3, 'current_airport': 'AB5', 'remaining_zones': ['1', '2', '3', '4', '6', '7', '9'], 'visited_zones': ['0', '8', '5'], 'total_cost': 4421, 'path': ['AB0', 'AB8', 'AB5']}, Visit count: 0, Total cost: 0
# Children: {'current_day': 3, 'current_airport': 'AB6', 'remaining_zones': ['1', '2', '3', '4', '5', '7', '9'], 'visited_zones': ['0', '8', '6'], 'total_cost': 5281, 'path': ['AB0', 'AB8', 'AB6']}, Visit count: 0, Total cost: 0
# Children: {'current_day': 3, 'current_airport': 'AB7', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '9'], 'visited_zones': ['0', '8', '7'], 'total_cost': 3893, 'path': ['AB0', 'AB8', 'AB7']}, Visit count: 0, Total cost: 0
# Children: {'current_day': 3, 'current_airport': 'AB9', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7'], 'visited_zones': ['0', '8', '9'], 'total_cost': 2794, 'path': ['AB0', 'AB8', 'AB9']}, Visit count: 0, Total cost: 0
# Children: {'current_day': 3, 'current_airport': 'AB1', 'remaining_zones': ['2', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '1'], 'total_cost': 457, 'path': ['AB0', 'AB8', 'AB1']}, Visit count: 0, Total cost: 0
# Children: {'current_day': 3, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '2'], 'total_cost': 462, 'path': ['AB0', 'AB8', 'AB2']}, Visit count: 0, Total cost: 0
# Children: {'current_day': 3, 'current_airport': 'AB3', 'remaining_zones': ['1', '2', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '3'], 'total_cost': 406, 'path': ['AB0', 'AB8', 'AB3']}, Visit count: 0, Total cost: 0
# Children: {'current_day': 3, 'current_airport': 'AB4', 'remaining_zones': ['1', '2', '3', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '4'], 'total_cost': 546, 'path': ['AB0', 'AB8', 'AB4']}, Visit count: 0, Total cost: 0
#
# End Expansion
#
# Selected node for simulation {'current_day': 3, 'current_airport': 'AB7', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '9'], 'visited_zones': ['0', '8', '7'], 'total_cost': 3893, 'path': ['AB0', 'AB8', 'AB7']}
# Simulation result: {'current_day': 10, 'current_airport': 'AB6', 'remaining_zones': [], 'visited_zones': ['0', '8', '7', '4', '2', '9', '1', '5', '3', '6'], 'total_cost': 11114, 'path': ['AB0', 'AB8', 'AB7', 'AB4', 'AB2', 'AB9', 'AB1', 'AB5', 'AB3', 'AB6']}
# Backpropagating Node: {'current_day': 3, 'current_airport': 'AB7', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '9'], 'visited_zones': ['0', '8', '7'], 'total_cost': 3893, 'path': ['AB0', 'AB8', 'AB7']}, Visit Count: 1, Total Cost: 11114
# Backpropagating Node: {'current_day': 2, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8'], 'total_cost': 283, 'path': ['AB0', 'AB8']}, Visit Count: 2, Total Cost: 18048
# Backpropagating Node: {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}, Visit Count: 10, Total Cost: 166148
# Selected node for simulation {'current_day': 3, 'current_airport': 'AB5', 'remaining_zones': ['1', '2', '3', '4', '6', '7', '9'], 'visited_zones': ['0', '8', '5'], 'total_cost': 4421, 'path': ['AB0', 'AB8', 'AB5']}
# Simulation result: {'current_day': 10, 'current_airport': 'AB4', 'remaining_zones': [], 'visited_zones': ['0', '8', '5', '7', '1', '2', '6', '9', '3', '4'], 'total_cost': 19271, 'path': ['AB0', 'AB8', 'AB5', 'AB7', 'AB1', 'AB2', 'AB6', 'AB9', 'AB3', 'AB4']}
# Backpropagating Node: {'current_day': 3, 'current_airport': 'AB5', 'remaining_zones': ['1', '2', '3', '4', '6', '7', '9'], 'visited_zones': ['0', '8', '5'], 'total_cost': 4421, 'path': ['AB0', 'AB8', 'AB5']}, Visit Count: 1, Total Cost: 19271
# Backpropagating Node: {'current_day': 2, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8'], 'total_cost': 283, 'path': ['AB0', 'AB8']}, Visit Count: 3, Total Cost: 37319
# Backpropagating Node: {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}, Visit Count: 11, Total Cost: 185419
# Selected node for simulation {'current_day': 3, 'current_airport': 'AB9', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7'], 'visited_zones': ['0', '8', '9'], 'total_cost': 2794, 'path': ['AB0', 'AB8', 'AB9']}
# Simulation result: {'current_day': 10, 'current_airport': 'AB6', 'remaining_zones': [], 'visited_zones': ['0', '8', '9', '3', '7', '5', '1', '2', '4', '6'], 'total_cost': 13885, 'path': ['AB0', 'AB8', 'AB9', 'AB3', 'AB7', 'AB5', 'AB1', 'AB2', 'AB4', 'AB6']}
# Backpropagating Node: {'current_day': 3, 'current_airport': 'AB9', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7'], 'visited_zones': ['0', '8', '9'], 'total_cost': 2794, 'path': ['AB0', 'AB8', 'AB9']}, Visit Count: 1, Total Cost: 13885
# Backpropagating Node: {'current_day': 2, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8'], 'total_cost': 283, 'path': ['AB0', 'AB8']}, Visit Count: 4, Total Cost: 51204
# Backpropagating Node: {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}, Visit Count: 12, Total Cost: 199304
# Selected node for simulation {'current_day': 3, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '2'], 'total_cost': 462, 'path': ['AB0', 'AB8', 'AB2']}
# Simulation result: {'current_day': 10, 'current_airport': 'AB3', 'remaining_zones': [], 'visited_zones': ['0', '8', '2', '7', '4', '5', '1', '9', '6', '3'], 'total_cost': 7693, 'path': ['AB0', 'AB8', 'AB2', 'AB7', 'AB4', 'AB5', 'AB1', 'AB9', 'AB6', 'AB3']}
# Backpropagating Node: {'current_day': 3, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '2'], 'total_cost': 462, 'path': ['AB0', 'AB8', 'AB2']}, Visit Count: 1, Total Cost: 7693
# Backpropagating Node: {'current_day': 2, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8'], 'total_cost': 283, 'path': ['AB0', 'AB8']}, Visit Count: 5, Total Cost: 58897
# Backpropagating Node: {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}, Visit Count: 13, Total Cost: 206997
# Selected node for simulation {'current_day': 3, 'current_airport': 'AB6', 'remaining_zones': ['1', '2', '3', '4', '5', '7', '9'], 'visited_zones': ['0', '8', '6'], 'total_cost': 5281, 'path': ['AB0', 'AB8', 'AB6']}
# Simulation result: {'current_day': 10, 'current_airport': 'AB4', 'remaining_zones': [], 'visited_zones': ['0', '8', '6', '1', '9', '7', '2', '5', '3', '4'], 'total_cost': 17559, 'path': ['AB0', 'AB8', 'AB6', 'AB1', 'AB9', 'AB7', 'AB2', 'AB5', 'AB3', 'AB4']}
# Backpropagating Node: {'current_day': 3, 'current_airport': 'AB6', 'remaining_zones': ['1', '2', '3', '4', '5', '7', '9'], 'visited_zones': ['0', '8', '6'], 'total_cost': 5281, 'path': ['AB0', 'AB8', 'AB6']}, Visit Count: 1, Total Cost: 17559
# Backpropagating Node: {'current_day': 2, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8'], 'total_cost': 283, 'path': ['AB0', 'AB8']}, Visit Count: 6, Total Cost: 76456
# Backpropagating Node: {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}, Visit Count: 14, Total Cost: 224556
# Selected node for simulation {'current_day': 3, 'current_airport': 'AB4', 'remaining_zones': ['1', '2', '3', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '4'], 'total_cost': 546, 'path': ['AB0', 'AB8', 'AB4']}
# Simulation result: {'current_day': 10, 'current_airport': 'AB5', 'remaining_zones': [], 'visited_zones': ['0', '8', '4', '2', '3', '9', '7', '6', '1', '5'], 'total_cost': 9160, 'path': ['AB0', 'AB8', 'AB4', 'AB2', 'AB3', 'AB9', 'AB7', 'AB6', 'AB1', 'AB5']}
# Backpropagating Node: {'current_day': 3, 'current_airport': 'AB4', 'remaining_zones': ['1', '2', '3', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '4'], 'total_cost': 546, 'path': ['AB0', 'AB8', 'AB4']}, Visit Count: 1, Total Cost: 9160
# Backpropagating Node: {'current_day': 2, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8'], 'total_cost': 283, 'path': ['AB0', 'AB8']}, Visit Count: 7, Total Cost: 85616
# Backpropagating Node: {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}, Visit Count: 15, Total Cost: 233716
# Selected node for simulation {'current_day': 3, 'current_airport': 'AB3', 'remaining_zones': ['1', '2', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '3'], 'total_cost': 406, 'path': ['AB0', 'AB8', 'AB3']}
# Simulation result: {'current_day': 10, 'current_airport': 'AB5', 'remaining_zones': [], 'visited_zones': ['0', '8', '3', '4', '7', '2', '9', '6', '1', '5'], 'total_cost': 11168, 'path': ['AB0', 'AB8', 'AB3', 'AB4', 'AB7', 'AB2', 'AB9', 'AB6', 'AB1', 'AB5']}
# Backpropagating Node: {'current_day': 3, 'current_airport': 'AB3', 'remaining_zones': ['1', '2', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '3'], 'total_cost': 406, 'path': ['AB0', 'AB8', 'AB3']}, Visit Count: 1, Total Cost: 11168
# Backpropagating Node: {'current_day': 2, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8'], 'total_cost': 283, 'path': ['AB0', 'AB8']}, Visit Count: 8, Total Cost: 96784
# Backpropagating Node: {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}, Visit Count: 16, Total Cost: 244884
# Selected node for simulation {'current_day': 3, 'current_airport': 'AB1', 'remaining_zones': ['2', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '1'], 'total_cost': 457, 'path': ['AB0', 'AB8', 'AB1']}
# Simulation result: {'current_day': 10, 'current_airport': 'AB3', 'remaining_zones': [], 'visited_zones': ['0', '8', '1', '9', '6', '2', '5', '4', '7', '3'], 'total_cost': 9571, 'path': ['AB0', 'AB8', 'AB1', 'AB9', 'AB6', 'AB2', 'AB5', 'AB4', 'AB7', 'AB3']}
# Backpropagating Node: {'current_day': 3, 'current_airport': 'AB1', 'remaining_zones': ['2', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '1'], 'total_cost': 457, 'path': ['AB0', 'AB8', 'AB1']}, Visit Count: 1, Total Cost: 9571
# Backpropagating Node: {'current_day': 2, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8'], 'total_cost': 283, 'path': ['AB0', 'AB8']}, Visit Count: 9, Total Cost: 106355
# Backpropagating Node: {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}, Visit Count: 17, Total Cost: 254455
#
# No more unvisited children
# UCT score [2.50826407776364, 2.4638196333191957, 2.5527085222080843, 2.5749307444303065, 2.530486299985862, 2.486041855541418, 2.419375188874751, 0.843495788462275, 2.597152966652529]
# Selected Node: {'current_day': 2, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8'], 'total_cost': 283, 'path': ['AB0', 'AB8']}, , Visit Count: 9, Total Cost: 106355
# Children picked on UCT critera
#
# No more unvisited children
# UCT score [2.361793404869955, 2.3340156270921772, 2.2506822937588438, 2.306237849314399, 2.222904515981066, 2.1673489604255103, 2.2784600715366214, 2.195126738203288]
# Selected Node: {'current_day': 3, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '2'], 'total_cost': 462, 'path': ['AB0', 'AB8', 'AB2']}, , Visit Count: 1, Total Cost: 7693
# Children picked on UCT critera
#
# Expansion
#
# Children: {'current_day': 4, 'current_airport': 'AB1', 'remaining_zones': ['3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '2', '1'], 'total_cost': 5896, 'path': ['AB0', 'AB8', 'AB2', 'AB1']}, Visit count: 0, Total cost: 0
# Children: {'current_day': 4, 'current_airport': 'AB3', 'remaining_zones': ['1', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '2', '3'], 'total_cost': 6232, 'path': ['AB0', 'AB8', 'AB2', 'AB3']}, Visit count: 0, Total cost: 0
# Children: {'current_day': 4, 'current_airport': 'AB4', 'remaining_zones': ['1', '3', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '2', '4'], 'total_cost': 5170, 'path': ['AB0', 'AB8', 'AB2', 'AB4']}, Visit count: 0, Total cost: 0
# Children: {'current_day': 4, 'current_airport': 'AB5', 'remaining_zones': ['1', '3', '4', '6', '7', '9'], 'visited_zones': ['0', '8', '2', '5'], 'total_cost': 618, 'path': ['AB0', 'AB8', 'AB2', 'AB5']}, Visit count: 0, Total cost: 0
# Children: {'current_day': 4, 'current_airport': 'AB6', 'remaining_zones': ['1', '3', '4', '5', '7', '9'], 'visited_zones': ['0', '8', '2', '6'], 'total_cost': 757, 'path': ['AB0', 'AB8', 'AB2', 'AB6']}, Visit count: 0, Total cost: 0
# Children: {'current_day': 4, 'current_airport': 'AB7', 'remaining_zones': ['1', '3', '4', '5', '6', '9'], 'visited_zones': ['0', '8', '2', '7'], 'total_cost': 729, 'path': ['AB0', 'AB8', 'AB2', 'AB7']}, Visit count: 0, Total cost: 0
# Children: {'current_day': 4, 'current_airport': 'AB9', 'remaining_zones': ['1', '3', '4', '5', '6', '7'], 'visited_zones': ['0', '8', '2', '9'], 'total_cost': 628, 'path': ['AB0', 'AB8', 'AB2', 'AB9']}, Visit count: 0, Total cost: 0
#
# End Expansion
#
# Selected node for simulation {'current_day': 4, 'current_airport': 'AB7', 'remaining_zones': ['1', '3', '4', '5', '6', '9'], 'visited_zones': ['0', '8', '2', '7'], 'total_cost': 729, 'path': ['AB0', 'AB8', 'AB2', 'AB7']}
# Simulation result: {'current_day': 10, 'current_airport': 'AB3', 'remaining_zones': [], 'visited_zones': ['0', '8', '2', '7', '6', '5', '9', '4', '1', '3'], 'total_cost': 24878, 'path': ['AB0', 'AB8', 'AB2', 'AB7', 'AB6', 'AB5', 'AB9', 'AB4', 'AB1', 'AB3']}
# Backpropagating Node: {'current_day': 4, 'current_airport': 'AB7', 'remaining_zones': ['1', '3', '4', '5', '6', '9'], 'visited_zones': ['0', '8', '2', '7'], 'total_cost': 729, 'path': ['AB0', 'AB8', 'AB2', 'AB7']}, Visit Count: 1, Total Cost: 24878
# Backpropagating Node: {'current_day': 3, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '2'], 'total_cost': 462, 'path': ['AB0', 'AB8', 'AB2']}, Visit Count: 2, Total Cost: 32571
# Backpropagating Node: {'current_day': 2, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8'], 'total_cost': 283, 'path': ['AB0', 'AB8']}, Visit Count: 10, Total Cost: 131233
# Backpropagating Node: {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}, Visit Count: 18, Total Cost: 279333
# Selected node for simulation {'current_day': 4, 'current_airport': 'AB3', 'remaining_zones': ['1', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '2', '3'], 'total_cost': 6232, 'path': ['AB0', 'AB8', 'AB2', 'AB3']}
# Simulation result: {'current_day': 10, 'current_airport': 'AB6', 'remaining_zones': [], 'visited_zones': ['0', '8', '2', '3', '4', '1', '9', '7', '5', '6'], 'total_cost': 22222, 'path': ['AB0', 'AB8', 'AB2', 'AB3', 'AB4', 'AB1', 'AB9', 'AB7', 'AB5', 'AB6']}
# Backpropagating Node: {'current_day': 4, 'current_airport': 'AB3', 'remaining_zones': ['1', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '2', '3'], 'total_cost': 6232, 'path': ['AB0', 'AB8', 'AB2', 'AB3']}, Visit Count: 1, Total Cost: 22222
# Backpropagating Node: {'current_day': 3, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '2'], 'total_cost': 462, 'path': ['AB0', 'AB8', 'AB2']}, Visit Count: 3, Total Cost: 54793
# Backpropagating Node: {'current_day': 2, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8'], 'total_cost': 283, 'path': ['AB0', 'AB8']}, Visit Count: 11, Total Cost: 153455
# Backpropagating Node: {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}, Visit Count: 19, Total Cost: 301555
# Selected node for simulation {'current_day': 4, 'current_airport': 'AB9', 'remaining_zones': ['1', '3', '4', '5', '6', '7'], 'visited_zones': ['0', '8', '2', '9'], 'total_cost': 628, 'path': ['AB0', 'AB8', 'AB2', 'AB9']}
# Simulation result: {'current_day': 10, 'current_airport': 'AB4', 'remaining_zones': [], 'visited_zones': ['0', '8', '2', '9', '1', '3', '5', '7', '6', '4'], 'total_cost': 14491, 'path': ['AB0', 'AB8', 'AB2', 'AB9', 'AB1', 'AB3', 'AB5', 'AB7', 'AB6', 'AB4']}
# Backpropagating Node: {'current_day': 4, 'current_airport': 'AB9', 'remaining_zones': ['1', '3', '4', '5', '6', '7'], 'visited_zones': ['0', '8', '2', '9'], 'total_cost': 628, 'path': ['AB0', 'AB8', 'AB2', 'AB9']}, Visit Count: 1, Total Cost: 14491
# Backpropagating Node: {'current_day': 3, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '2'], 'total_cost': 462, 'path': ['AB0', 'AB8', 'AB2']}, Visit Count: 4, Total Cost: 69284
# Backpropagating Node: {'current_day': 2, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8'], 'total_cost': 283, 'path': ['AB0', 'AB8']}, Visit Count: 12, Total Cost: 167946
# Backpropagating Node: {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}, Visit Count: 20, Total Cost: 316046
# Selected node for simulation {'current_day': 4, 'current_airport': 'AB1', 'remaining_zones': ['3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '2', '1'], 'total_cost': 5896, 'path': ['AB0', 'AB8', 'AB2', 'AB1']}
# Simulation result: {'current_day': 10, 'current_airport': 'AB6', 'remaining_zones': [], 'visited_zones': ['0', '8', '2', '1', '9', '7', '4', '3', '5', '6'], 'total_cost': 19394, 'path': ['AB0', 'AB8', 'AB2', 'AB1', 'AB9', 'AB7', 'AB4', 'AB3', 'AB5', 'AB6']}
# Backpropagating Node: {'current_day': 4, 'current_airport': 'AB1', 'remaining_zones': ['3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '2', '1'], 'total_cost': 5896, 'path': ['AB0', 'AB8', 'AB2', 'AB1']}, Visit Count: 1, Total Cost: 19394
# Backpropagating Node: {'current_day': 3, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '2'], 'total_cost': 462, 'path': ['AB0', 'AB8', 'AB2']}, Visit Count: 5, Total Cost: 88678
# Backpropagating Node: {'current_day': 2, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8'], 'total_cost': 283, 'path': ['AB0', 'AB8']}, Visit Count: 13, Total Cost: 187340
# Backpropagating Node: {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}, Visit Count: 21, Total Cost: 335440
# Selected node for simulation {'current_day': 4, 'current_airport': 'AB4', 'remaining_zones': ['1', '3', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '2', '4'], 'total_cost': 5170, 'path': ['AB0', 'AB8', 'AB2', 'AB4']}
# Simulation result: {'current_day': 10, 'current_airport': 'AB1', 'remaining_zones': [], 'visited_zones': ['0', '8', '2', '4', '5', '3', '7', '9', '6', '1'], 'total_cost': 13572, 'path': ['AB0', 'AB8', 'AB2', 'AB4', 'AB5', 'AB3', 'AB7', 'AB9', 'AB6', 'AB1']}
# Backpropagating Node: {'current_day': 4, 'current_airport': 'AB4', 'remaining_zones': ['1', '3', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '2', '4'], 'total_cost': 5170, 'path': ['AB0', 'AB8', 'AB2', 'AB4']}, Visit Count: 1, Total Cost: 13572
# Backpropagating Node: {'current_day': 3, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '2'], 'total_cost': 462, 'path': ['AB0', 'AB8', 'AB2']}, Visit Count: 6, Total Cost: 102250
# Backpropagating Node: {'current_day': 2, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8'], 'total_cost': 283, 'path': ['AB0', 'AB8']}, Visit Count: 14, Total Cost: 200912
# Backpropagating Node: {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}, Visit Count: 22, Total Cost: 349012
# Selected node for simulation {'current_day': 4, 'current_airport': 'AB6', 'remaining_zones': ['1', '3', '4', '5', '7', '9'], 'visited_zones': ['0', '8', '2', '6'], 'total_cost': 757, 'path': ['AB0', 'AB8', 'AB2', 'AB6']}
# Simulation result: {'current_day': 10, 'current_airport': 'AB1', 'remaining_zones': [], 'visited_zones': ['0', '8', '2', '6', '5', '9', '7', '3', '4', '1'], 'total_cost': 24727, 'path': ['AB0', 'AB8', 'AB2', 'AB6', 'AB5', 'AB9', 'AB7', 'AB3', 'AB4', 'AB1']}
# Backpropagating Node: {'current_day': 4, 'current_airport': 'AB6', 'remaining_zones': ['1', '3', '4', '5', '7', '9'], 'visited_zones': ['0', '8', '2', '6'], 'total_cost': 757, 'path': ['AB0', 'AB8', 'AB2', 'AB6']}, Visit Count: 1, Total Cost: 24727
# Backpropagating Node: {'current_day': 3, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '2'], 'total_cost': 462, 'path': ['AB0', 'AB8', 'AB2']}, Visit Count: 7, Total Cost: 126977
# Backpropagating Node: {'current_day': 2, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8'], 'total_cost': 283, 'path': ['AB0', 'AB8']}, Visit Count: 15, Total Cost: 225639
# Backpropagating Node: {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}, Visit Count: 23, Total Cost: 373739
# Selected node for simulation {'current_day': 4, 'current_airport': 'AB5', 'remaining_zones': ['1', '3', '4', '6', '7', '9'], 'visited_zones': ['0', '8', '2', '5'], 'total_cost': 618, 'path': ['AB0', 'AB8', 'AB2', 'AB5']}
# Simulation result: {'current_day': 10, 'current_airport': 'AB1', 'remaining_zones': [], 'visited_zones': ['0', '8', '2', '5', '3', '9', '7', '4', '6', '1'], 'total_cost': 6774, 'path': ['AB0', 'AB8', 'AB2', 'AB5', 'AB3', 'AB9', 'AB7', 'AB4', 'AB6', 'AB1']}
# Backpropagating Node: {'current_day': 4, 'current_airport': 'AB5', 'remaining_zones': ['1', '3', '4', '6', '7', '9'], 'visited_zones': ['0', '8', '2', '5'], 'total_cost': 618, 'path': ['AB0', 'AB8', 'AB2', 'AB5']}, Visit Count: 1, Total Cost: 6774
# Backpropagating Node: {'current_day': 3, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '2'], 'total_cost': 462, 'path': ['AB0', 'AB8', 'AB2']}, Visit Count: 8, Total Cost: 133751
# Backpropagating Node: {'current_day': 2, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8'], 'total_cost': 283, 'path': ['AB0', 'AB8']}, Visit Count: 16, Total Cost: 232413
# Backpropagating Node: {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}, Visit Count: 24, Total Cost: 380513
#
# No more unvisited children
# UCT score [2.640822681227325, 2.5741560145606583, 2.6852671256717695, 2.7074893478939916, 2.6630449034495474, 2.618600459005103, 2.551933792338436, 0.6990948556462068, 2.7297115701162142]
# Selected Node: {'current_day': 2, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8'], 'total_cost': 283, 'path': ['AB0', 'AB8']}, , Visit Count: 16, Total Cost: 232413
# Children picked on UCT critera
#
# No more unvisited children
# UCT score [2.595554440141228, 2.56777666236345, 2.456665551252339, 2.5122211068078943, 2.428887773474561, 1.0057666864221575, 2.4844433290301167, 2.401109995696783]
# Selected Node: {'current_day': 3, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '2'], 'total_cost': 462, 'path': ['AB0', 'AB8', 'AB2']}, , Visit Count: 8, Total Cost: 133751
# Children picked on UCT critera
#
# No more unvisited children
# UCT score [2.232904466221933, 2.2686187519362186, 2.161475894793362, 2.125761609079076, 2.3043330376505047, 2.3400473233647903, 2.1971901805076475]
# Selected Node: {'current_day': 4, 'current_airport': 'AB5', 'remaining_zones': ['1', '3', '4', '6', '7', '9'], 'visited_zones': ['0', '8', '2', '5'], 'total_cost': 618, 'path': ['AB0', 'AB8', 'AB2', 'AB5']}, , Visit Count: 1, Total Cost: 6774
# Children picked on UCT critera
#
# Expansion
#
# Children: {'current_day': 5, 'current_airport': 'AB6', 'remaining_zones': ['1', '3', '4', '7', '9'], 'visited_zones': ['0', '8', '2', '5', '6'], 'total_cost': 5672, 'path': ['AB0', 'AB8', 'AB2', 'AB5', 'AB6']}, Visit count: 0, Total cost: 0
# Children: {'current_day': 5, 'current_airport': 'AB7', 'remaining_zones': ['1', '3', '4', '6', '9'], 'visited_zones': ['0', '8', '2', '5', '7'], 'total_cost': 6271, 'path': ['AB0', 'AB8', 'AB2', 'AB5', 'AB7']}, Visit count: 0, Total cost: 0
# Children: {'current_day': 5, 'current_airport': 'AB9', 'remaining_zones': ['1', '3', '4', '6', '7'], 'visited_zones': ['0', '8', '2', '5', '9'], 'total_cost': 5585, 'path': ['AB0', 'AB8', 'AB2', 'AB5', 'AB9']}, Visit count: 0, Total cost: 0
# Children: {'current_day': 5, 'current_airport': 'AB1', 'remaining_zones': ['3', '4', '6', '7', '9'], 'visited_zones': ['0', '8', '2', '5', '1'], 'total_cost': 797, 'path': ['AB0', 'AB8', 'AB2', 'AB5', 'AB1']}, Visit count: 0, Total cost: 0
# Children: {'current_day': 5, 'current_airport': 'AB3', 'remaining_zones': ['1', '4', '6', '7', '9'], 'visited_zones': ['0', '8', '2', '5', '3'], 'total_cost': 842, 'path': ['AB0', 'AB8', 'AB2', 'AB5', 'AB3']}, Visit count: 0, Total cost: 0
# Children: {'current_day': 5, 'current_airport': 'AB4', 'remaining_zones': ['1', '3', '6', '7', '9'], 'visited_zones': ['0', '8', '2', '5', '4'], 'total_cost': 750, 'path': ['AB0', 'AB8', 'AB2', 'AB5', 'AB4']}, Visit count: 0, Total cost: 0
#
# End Expansion
#
# Selected node for simulation {'current_day': 5, 'current_airport': 'AB6', 'remaining_zones': ['1', '3', '4', '7', '9'], 'visited_zones': ['0', '8', '2', '5', '6'], 'total_cost': 5672, 'path': ['AB0', 'AB8', 'AB2', 'AB5', 'AB6']}
# Simulation result: {'current_day': 10, 'current_airport': 'AB9', 'remaining_zones': [], 'visited_zones': ['0', '8', '2', '5', '6', '1', '7', '3', '4', '9'], 'total_cost': 10988, 'path': ['AB0', 'AB8', 'AB2', 'AB5', 'AB6', 'AB1', 'AB7', 'AB3', 'AB4', 'AB9']}
# Backpropagating Node: {'current_day': 5, 'current_airport': 'AB6', 'remaining_zones': ['1', '3', '4', '7', '9'], 'visited_zones': ['0', '8', '2', '5', '6'], 'total_cost': 5672, 'path': ['AB0', 'AB8', 'AB2', 'AB5', 'AB6']}, Visit Count: 1, Total Cost: 10988
# Backpropagating Node: {'current_day': 4, 'current_airport': 'AB5', 'remaining_zones': ['1', '3', '4', '6', '7', '9'], 'visited_zones': ['0', '8', '2', '5'], 'total_cost': 618, 'path': ['AB0', 'AB8', 'AB2', 'AB5']}, Visit Count: 2, Total Cost: 17762
# Backpropagating Node: {'current_day': 3, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '2'], 'total_cost': 462, 'path': ['AB0', 'AB8', 'AB2']}, Visit Count: 9, Total Cost: 144739
# Backpropagating Node: {'current_day': 2, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8'], 'total_cost': 283, 'path': ['AB0', 'AB8']}, Visit Count: 17, Total Cost: 243401
# Backpropagating Node: {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}, Visit Count: 25, Total Cost: 391501
# Selected node for simulation {'current_day': 5, 'current_airport': 'AB4', 'remaining_zones': ['1', '3', '6', '7', '9'], 'visited_zones': ['0', '8', '2', '5', '4'], 'total_cost': 750, 'path': ['AB0', 'AB8', 'AB2', 'AB5', 'AB4']}
# Simulation result: {'current_day': 10, 'current_airport': 'AB7', 'remaining_zones': [], 'visited_zones': ['0', '8', '2', '5', '4', '9', '6', '3', '1', '7'], 'total_cost': 6611, 'path': ['AB0', 'AB8', 'AB2', 'AB5', 'AB4', 'AB9', 'AB6', 'AB3', 'AB1', 'AB7']}
# Backpropagating Node: {'current_day': 5, 'current_airport': 'AB4', 'remaining_zones': ['1', '3', '6', '7', '9'], 'visited_zones': ['0', '8', '2', '5', '4'], 'total_cost': 750, 'path': ['AB0', 'AB8', 'AB2', 'AB5', 'AB4']}, Visit Count: 1, Total Cost: 6611
# Backpropagating Node: {'current_day': 4, 'current_airport': 'AB5', 'remaining_zones': ['1', '3', '4', '6', '7', '9'], 'visited_zones': ['0', '8', '2', '5'], 'total_cost': 618, 'path': ['AB0', 'AB8', 'AB2', 'AB5']}, Visit Count: 3, Total Cost: 24373
# Backpropagating Node: {'current_day': 3, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '2'], 'total_cost': 462, 'path': ['AB0', 'AB8', 'AB2']}, Visit Count: 10, Total Cost: 151350
# Backpropagating Node: {'current_day': 2, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8'], 'total_cost': 283, 'path': ['AB0', 'AB8']}, Visit Count: 18, Total Cost: 250012
# Backpropagating Node: {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}, Visit Count: 26, Total Cost: 398112
# Selected node for simulation {'current_day': 5, 'current_airport': 'AB9', 'remaining_zones': ['1', '3', '4', '6', '7'], 'visited_zones': ['0', '8', '2', '5', '9'], 'total_cost': 5585, 'path': ['AB0', 'AB8', 'AB2', 'AB5', 'AB9']}
# Simulation result: {'current_day': 10, 'current_airport': 'AB1', 'remaining_zones': [], 'visited_zones': ['0', '8', '2', '5', '9', '7', '6', '4', '3', '1'], 'total_cost': 20731, 'path': ['AB0', 'AB8', 'AB2', 'AB5', 'AB9', 'AB7', 'AB6', 'AB4', 'AB3', 'AB1']}
# Backpropagating Node: {'current_day': 5, 'current_airport': 'AB9', 'remaining_zones': ['1', '3', '4', '6', '7'], 'visited_zones': ['0', '8', '2', '5', '9'], 'total_cost': 5585, 'path': ['AB0', 'AB8', 'AB2', 'AB5', 'AB9']}, Visit Count: 1, Total Cost: 20731
# Backpropagating Node: {'current_day': 4, 'current_airport': 'AB5', 'remaining_zones': ['1', '3', '4', '6', '7', '9'], 'visited_zones': ['0', '8', '2', '5'], 'total_cost': 618, 'path': ['AB0', 'AB8', 'AB2', 'AB5']}, Visit Count: 4, Total Cost: 45104
# Backpropagating Node: {'current_day': 3, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '2'], 'total_cost': 462, 'path': ['AB0', 'AB8', 'AB2']}, Visit Count: 11, Total Cost: 172081
# Backpropagating Node: {'current_day': 2, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8'], 'total_cost': 283, 'path': ['AB0', 'AB8']}, Visit Count: 19, Total Cost: 270743
# Backpropagating Node: {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}, Visit Count: 27, Total Cost: 418843
# Selected node for simulation {'current_day': 5, 'current_airport': 'AB1', 'remaining_zones': ['3', '4', '6', '7', '9'], 'visited_zones': ['0', '8', '2', '5', '1'], 'total_cost': 797, 'path': ['AB0', 'AB8', 'AB2', 'AB5', 'AB1']}
# Simulation result: {'current_day': 10, 'current_airport': 'AB7', 'remaining_zones': [], 'visited_zones': ['0', '8', '2', '5', '1', '9', '3', '6', '4', '7'], 'total_cost': 1872, 'path': ['AB0', 'AB8', 'AB2', 'AB5', 'AB1', 'AB9', 'AB3', 'AB6', 'AB4', 'AB7']}
# Backpropagating Node: {'current_day': 5, 'current_airport': 'AB1', 'remaining_zones': ['3', '4', '6', '7', '9'], 'visited_zones': ['0', '8', '2', '5', '1'], 'total_cost': 797, 'path': ['AB0', 'AB8', 'AB2', 'AB5', 'AB1']}, Visit Count: 1, Total Cost: 1872
# Backpropagating Node: {'current_day': 4, 'current_airport': 'AB5', 'remaining_zones': ['1', '3', '4', '6', '7', '9'], 'visited_zones': ['0', '8', '2', '5'], 'total_cost': 618, 'path': ['AB0', 'AB8', 'AB2', 'AB5']}, Visit Count: 5, Total Cost: 46976
# Backpropagating Node: {'current_day': 3, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '2'], 'total_cost': 462, 'path': ['AB0', 'AB8', 'AB2']}, Visit Count: 12, Total Cost: 173953
# Backpropagating Node: {'current_day': 2, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8'], 'total_cost': 283, 'path': ['AB0', 'AB8']}, Visit Count: 20, Total Cost: 272615
# Backpropagating Node: {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}, Visit Count: 28, Total Cost: 420715
# Selected node for simulation {'current_day': 5, 'current_airport': 'AB7', 'remaining_zones': ['1', '3', '4', '6', '9'], 'visited_zones': ['0', '8', '2', '5', '7'], 'total_cost': 6271, 'path': ['AB0', 'AB8', 'AB2', 'AB5', 'AB7']}
# Simulation result: {'current_day': 10, 'current_airport': 'AB3', 'remaining_zones': [], 'visited_zones': ['0', '8', '2', '5', '7', '6', '1', '9', '4', '3'], 'total_cost': 17665, 'path': ['AB0', 'AB8', 'AB2', 'AB5', 'AB7', 'AB6', 'AB1', 'AB9', 'AB4', 'AB3']}
# Backpropagating Node: {'current_day': 5, 'current_airport': 'AB7', 'remaining_zones': ['1', '3', '4', '6', '9'], 'visited_zones': ['0', '8', '2', '5', '7'], 'total_cost': 6271, 'path': ['AB0', 'AB8', 'AB2', 'AB5', 'AB7']}, Visit Count: 1, Total Cost: 17665
# Backpropagating Node: {'current_day': 4, 'current_airport': 'AB5', 'remaining_zones': ['1', '3', '4', '6', '7', '9'], 'visited_zones': ['0', '8', '2', '5'], 'total_cost': 618, 'path': ['AB0', 'AB8', 'AB2', 'AB5']}, Visit Count: 6, Total Cost: 64641
# Backpropagating Node: {'current_day': 3, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '2'], 'total_cost': 462, 'path': ['AB0', 'AB8', 'AB2']}, Visit Count: 13, Total Cost: 191618
# Backpropagating Node: {'current_day': 2, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8'], 'total_cost': 283, 'path': ['AB0', 'AB8']}, Visit Count: 21, Total Cost: 290280
# Backpropagating Node: {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}, Visit Count: 29, Total Cost: 438380
# Selected node for simulation {'current_day': 5, 'current_airport': 'AB3', 'remaining_zones': ['1', '4', '6', '7', '9'], 'visited_zones': ['0', '8', '2', '5', '3'], 'total_cost': 842, 'path': ['AB0', 'AB8', 'AB2', 'AB5', 'AB3']}
# Simulation result: {'current_day': 10, 'current_airport': 'AB7', 'remaining_zones': [], 'visited_zones': ['0', '8', '2', '5', '3', '9', '6', '1', '4', '7'], 'total_cost': 6830, 'path': ['AB0', 'AB8', 'AB2', 'AB5', 'AB3', 'AB9', 'AB6', 'AB1', 'AB4', 'AB7']}
# Backpropagating Node: {'current_day': 5, 'current_airport': 'AB3', 'remaining_zones': ['1', '4', '6', '7', '9'], 'visited_zones': ['0', '8', '2', '5', '3'], 'total_cost': 842, 'path': ['AB0', 'AB8', 'AB2', 'AB5', 'AB3']}, Visit Count: 1, Total Cost: 6830
# Backpropagating Node: {'current_day': 4, 'current_airport': 'AB5', 'remaining_zones': ['1', '3', '4', '6', '7', '9'], 'visited_zones': ['0', '8', '2', '5'], 'total_cost': 618, 'path': ['AB0', 'AB8', 'AB2', 'AB5']}, Visit Count: 7, Total Cost: 71471
# Backpropagating Node: {'current_day': 3, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '2'], 'total_cost': 462, 'path': ['AB0', 'AB8', 'AB2']}, Visit Count: 14, Total Cost: 198448
# Backpropagating Node: {'current_day': 2, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8'], 'total_cost': 283, 'path': ['AB0', 'AB8']}, Visit Count: 22, Total Cost: 297110
# Backpropagating Node: {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}, Visit Count: 30, Total Cost: 445210
#
#
# State: {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}, Visit Count: 30, Total Cost: 445210
# State: {'current_day': 2, 'current_airport': 'AB1', 'remaining_zones': ['2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '1'], 'total_cost': 1, 'path': ['AB0', 'AB1']}, Visit Count: 1, Total Cost: 14801
# State: {'current_day': 2, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '2'], 'total_cost': 3619, 'path': ['AB0', 'AB2']}, Visit Count: 1, Total Cost: 13056
# State: {'current_day': 2, 'current_airport': 'AB3', 'remaining_zones': ['1', '2', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '3'], 'total_cost': 4618, 'path': ['AB0', 'AB3']}, Visit Count: 1, Total Cost: 21394
# State: {'current_day': 2, 'current_airport': 'AB4', 'remaining_zones': ['1', '2', '3', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '4'], 'total_cost': 2127, 'path': ['AB0', 'AB4']}, Visit Count: 1, Total Cost: 25510
# State: {'current_day': 2, 'current_airport': 'AB5', 'remaining_zones': ['1', '2', '3', '4', '6', '7', '8', '9'], 'visited_zones': ['0', '5'], 'total_cost': 173, 'path': ['AB0', 'AB5']}, Visit Count: 1, Total Cost: 18883
# State: {'current_day': 2, 'current_airport': 'AB6', 'remaining_zones': ['1', '2', '3', '4', '5', '7', '8', '9'], 'visited_zones': ['0', '6'], 'total_cost': 179, 'path': ['AB0', 'AB6']}, Visit Count: 1, Total Cost: 14777
# State: {'current_day': 2, 'current_airport': 'AB7', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '8', '9'], 'visited_zones': ['0', '7'], 'total_cost': 192, 'path': ['AB0', 'AB7']}, Visit Count: 1, Total Cost: 10752
# State: {'current_day': 2, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8'], 'total_cost': 283, 'path': ['AB0', 'AB8']}, Visit Count: 22, Total Cost: 297110
# State: {'current_day': 2, 'current_airport': 'AB9', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8'], 'visited_zones': ['0', '9'], 'total_cost': 103, 'path': ['AB0', 'AB9']}, Visit Count: 1, Total Cost: 28927
# State: {'current_day': 3, 'current_airport': 'AB5', 'remaining_zones': ['1', '2', '3', '4', '6', '7', '9'], 'visited_zones': ['0', '8', '5'], 'total_cost': 4421, 'path': ['AB0', 'AB8', 'AB5']}, Visit Count: 1, Total Cost: 19271
# State: {'current_day': 3, 'current_airport': 'AB6', 'remaining_zones': ['1', '2', '3', '4', '5', '7', '9'], 'visited_zones': ['0', '8', '6'], 'total_cost': 5281, 'path': ['AB0', 'AB8', 'AB6']}, Visit Count: 1, Total Cost: 17559
# State: {'current_day': 3, 'current_airport': 'AB7', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '9'], 'visited_zones': ['0', '8', '7'], 'total_cost': 3893, 'path': ['AB0', 'AB8', 'AB7']}, Visit Count: 1, Total Cost: 11114
# State: {'current_day': 3, 'current_airport': 'AB9', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7'], 'visited_zones': ['0', '8', '9'], 'total_cost': 2794, 'path': ['AB0', 'AB8', 'AB9']}, Visit Count: 1, Total Cost: 13885
# State: {'current_day': 3, 'current_airport': 'AB1', 'remaining_zones': ['2', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '1'], 'total_cost': 457, 'path': ['AB0', 'AB8', 'AB1']}, Visit Count: 1, Total Cost: 9571
# State: {'current_day': 3, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '2'], 'total_cost': 462, 'path': ['AB0', 'AB8', 'AB2']}, Visit Count: 14, Total Cost: 198448
# State: {'current_day': 3, 'current_airport': 'AB3', 'remaining_zones': ['1', '2', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '3'], 'total_cost': 406, 'path': ['AB0', 'AB8', 'AB3']}, Visit Count: 1, Total Cost: 11168
# State: {'current_day': 3, 'current_airport': 'AB4', 'remaining_zones': ['1', '2', '3', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '4'], 'total_cost': 546, 'path': ['AB0', 'AB8', 'AB4']}, Visit Count: 1, Total Cost: 9160
# State: {'current_day': 4, 'current_airport': 'AB1', 'remaining_zones': ['3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '2', '1'], 'total_cost': 5896, 'path': ['AB0', 'AB8', 'AB2', 'AB1']}, Visit Count: 1, Total Cost: 19394
# State: {'current_day': 4, 'current_airport': 'AB3', 'remaining_zones': ['1', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '2', '3'], 'total_cost': 6232, 'path': ['AB0', 'AB8', 'AB2', 'AB3']}, Visit Count: 1, Total Cost: 22222
# State: {'current_day': 4, 'current_airport': 'AB4', 'remaining_zones': ['1', '3', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '2', '4'], 'total_cost': 5170, 'path': ['AB0', 'AB8', 'AB2', 'AB4']}, Visit Count: 1, Total Cost: 13572
# State: {'current_day': 4, 'current_airport': 'AB5', 'remaining_zones': ['1', '3', '4', '6', '7', '9'], 'visited_zones': ['0', '8', '2', '5'], 'total_cost': 618, 'path': ['AB0', 'AB8', 'AB2', 'AB5']}, Visit Count: 7, Total Cost: 71471
# State: {'current_day': 4, 'current_airport': 'AB6', 'remaining_zones': ['1', '3', '4', '5', '7', '9'], 'visited_zones': ['0', '8', '2', '6'], 'total_cost': 757, 'path': ['AB0', 'AB8', 'AB2', 'AB6']}, Visit Count: 1, Total Cost: 24727
# State: {'current_day': 4, 'current_airport': 'AB7', 'remaining_zones': ['1', '3', '4', '5', '6', '9'], 'visited_zones': ['0', '8', '2', '7'], 'total_cost': 729, 'path': ['AB0', 'AB8', 'AB2', 'AB7']}, Visit Count: 1, Total Cost: 24878
# State: {'current_day': 4, 'current_airport': 'AB9', 'remaining_zones': ['1', '3', '4', '5', '6', '7'], 'visited_zones': ['0', '8', '2', '9'], 'total_cost': 628, 'path': ['AB0', 'AB8', 'AB2', 'AB9']}, Visit Count: 1, Total Cost: 14491
# State: {'current_day': 5, 'current_airport': 'AB6', 'remaining_zones': ['1', '3', '4', '7', '9'], 'visited_zones': ['0', '8', '2', '5', '6'], 'total_cost': 5672, 'path': ['AB0', 'AB8', 'AB2', 'AB5', 'AB6']}, Visit Count: 1, Total Cost: 10988
# State: {'current_day': 5, 'current_airport': 'AB7', 'remaining_zones': ['1', '3', '4', '6', '9'], 'visited_zones': ['0', '8', '2', '5', '7'], 'total_cost': 6271, 'path': ['AB0', 'AB8', 'AB2', 'AB5', 'AB7']}, Visit Count: 1, Total Cost: 17665
# State: {'current_day': 5, 'current_airport': 'AB9', 'remaining_zones': ['1', '3', '4', '6', '7'], 'visited_zones': ['0', '8', '2', '5', '9'], 'total_cost': 5585, 'path': ['AB0', 'AB8', 'AB2', 'AB5', 'AB9']}, Visit Count: 1, Total Cost: 20731
# State: {'current_day': 5, 'current_airport': 'AB1', 'remaining_zones': ['3', '4', '6', '7', '9'], 'visited_zones': ['0', '8', '2', '5', '1'], 'total_cost': 797, 'path': ['AB0', 'AB8', 'AB2', 'AB5', 'AB1']}, Visit Count: 1, Total Cost: 1872
# State: {'current_day': 5, 'current_airport': 'AB3', 'remaining_zones': ['1', '4', '6', '7', '9'], 'visited_zones': ['0', '8', '2', '5', '3'], 'total_cost': 842, 'path': ['AB0', 'AB8', 'AB2', 'AB5', 'AB3']}, Visit Count: 1, Total Cost: 6830
# State: {'current_day': 5, 'current_airport': 'AB4', 'remaining_zones': ['1', '3', '6', '7', '9'], 'visited_zones': ['0', '8', '2', '5', '4'], 'total_cost': 750, 'path': ['AB0', 'AB8', 'AB2', 'AB5', 'AB4']}, Visit Count: 1, Total Cost: 6611
