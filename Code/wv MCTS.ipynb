# %%
import numpy as np
import random
from copy import deepcopy

# %%
class data_preprocessing:
    def __init__(self,instance_path):
        self.instance_path=instance_path
        
        self.info, self.flights = self.read_file(f_name=self.instance_path)
        self.number_of_areas,self.starting_airport=int(self.info[0][0]),self.info[0][1]
        
        
        self.flights_by_day_dict = self.flights_by_day(flight_list=self.flights)
        
        self.flights_by_day_dict=self.remove_duplicate(flights_by_day=self.flights_by_day_dict)
        
        self.list_days= [k for k in range(1,self.number_of_areas)]
        
        self.airports_by_area = self.get_airports_by_areas()
        self.area_to_explore=self.which_area_to_explore(airports_by_area=self.airports_by_area)
        self.area_by_airport=self.invert_dict(original_dict=self.airports_by_area)
        
        self.starting_area=self.associated_area_to_airport(airport=self.starting_airport)
        self.list_airports=self.get_list_of_airports()
        self.list_areas=list(self.airports_by_area.keys())
        self.areas_connections_by_day=self.possible_flights_from_zone_to_zone_specific_day()
        
    def read_file(self,f_name):
        dist = []
        line_nu = -1
        with open(f_name) as infile:
            for line in infile:
                line_nu += 1
                if line_nu == 0:
                    index = int(line.split()[0]) * 2 + 1
                if line_nu >= index:
                    temp = line.split()
                    temp[2] = int(temp[2])
                    temp[3] = int(temp[3])
                    dist.append(temp)
                else:
                    dist.append(line.split())
            info = dist[:int(dist[0][0])*2+1]
            flights = dist[int(dist[0][0])*2+1:]
        return info, flights
    
    def flights_by_day(self,flight_list):
        # Create an empty dictionary to hold flights organized by day
        flights_by_day = {}

        # Iterate over each flight in the input list
        for flight in flight_list:
            # Extract the day from the flight entry
            day = flight[2]

            # Create a flight entry without the day
            flight_without_day = flight[:2] + flight[3:]

            # Add the flight to the corresponding day in the dictionary
            if day not in flights_by_day:
                flights_by_day[day] = []
            flights_by_day[day].append(flight_without_day)
            
        return flights_by_day
    
    def flights_from_airport(self,flights_by_day, from_airport, considered_day):
        flights_from_airport = []
        for day, flights in flights_by_day.items():
            if day==considered_day:
                for flight in flights:
                    if flight[0] == from_airport:
                        flights_from_airport.append(flight)
                return flights_from_airport
            else:
                return None

    def invert_dict(self,original_dict):
        inverted_dict = {}
        for key, value_list in original_dict.items():
            for value in value_list:
                if value in inverted_dict:
                    inverted_dict[value].append(key)
                else:
                    inverted_dict[value] = key
        return inverted_dict

    def get_cost(self, day, from_airport, to_airport):
        # Retrieve flights for the specified day and day 0
        flights_day = self.flights_by_day_dict.get(day, [])
        flights_day_0 = self.flights_by_day_dict.get(0, [])
        
        # Find the cost for the specified day
        cost_day = next(
            (flight[2]
            for flight in flights_day
            if flight[0] == from_airport and flight[1] == to_airport),
            float('inf')
        )
        
        # Find the cost for day 0
        cost_day_0 = next(
            (flight[2]
            for flight in flights_day_0
            if flight[0] == from_airport and flight[1] == to_airport),
            float('inf')
        )
        
        # Return the minimum cost if either exists, otherwise inf
        if cost_day == float('inf') and cost_day_0 == float('inf'):
            return float('inf')
        
        return min(cost_day, cost_day_0)

    def possible_flights_from_zone_to_zone_specific_day(self):
        areas_connections_by_day = {}

        for day, flights in self.flights_by_day_dict.items():
            areas_connections_list = []

            for flight in flights:
                connection = f"{self.area_by_airport.get(flight[0])} to {self.area_by_airport.get(flight[1])}"
                if connection not in areas_connections_list:
                    areas_connections_list.append(connection)

            areas_connections_by_day[day] = areas_connections_list

        return areas_connections_by_day

    def get_airports_by_areas(self):
        area_num = int(self.info[0][0])
        return {f"{i}": self.info[2+i * 2] for i in range(0, area_num)}
    
    def get_list_of_airports(self):
        unique_airports = set()

        # Iterate through each sublist and add elements to the set
        for sublist in self.airports_by_area.values():
            for airport in sublist:
                unique_airports.add(airport)
        
        return list(unique_airports)
                    
    def associated_area_to_airport(self,airport):
        return next(
            (
                area
                for area, airports in self.airports_by_area.items()
                if airport in airports
            ),
            "Airport not found",
        ) 
    
    def remove_duplicate(self,flights_by_day):
        for day, flights in flights_by_day.items():
            unique_flights = {}
            for flight in flights:
                flight_key = (flight[0], flight[1])
                if flight_key not in unique_flights:
                    unique_flights[flight_key] = flight
                else:
                    if flight[2] < unique_flights[flight_key][2]:
                        #print(flight[2],unique_flights[flight_key][2])
                        unique_flights[flight_key] = flight
                flights_by_day[day] = list(unique_flights.values())
        return flights_by_day
    
    def possible_flights_from_an_airport_at_a_specific_day(self,day,from_airport):
        daily_flights = self.flights_by_day_dict.get(day, [])
        
        flights_from_airport = []
        for flight in daily_flights:
            if flight[0] == from_airport:
                
                flights_from_airport.append([flight[1], flight[2]])

        return flights_from_airport
    
    def possible_flights_from_an_airport_at_a_specific_day_with_previous_areas(self,day,from_airport, visited_areas):
        daily_flights = self.flights_by_day_dict.get(day, [])
        
        flights_from_airport = []
        for flight in daily_flights:
            #print(self.associated_area_to_airport(airport=flight[0]))
            if (flight[0] == from_airport) and (self.associated_area_to_airport(airport=flight[1]) not in visited_areas):
                
                flights_from_airport.append([flight[1], flight[2]])

        return flights_from_airport
    
    def which_area_to_explore(self,airports_by_area):
        return list({key: len(value) for key, value in airports_by_area.items() if len(value) > 1})

# %%
class Node:
    def __init__(self, state, parent=None):
        self.state = state  # State is a dictionary representing the current situation
        self.parent = parent  # Parent node
        self.children = []  # List of child nodes
        self.visit_count = 0  # Number of times this node has been visited
        self.total_cost = 0  # Total cost accumulated in simulations from this node

    def add_child(self, child_state):
        child_node = Node(child_state, self)
        self.children.append(child_node)
        return child_node

    def is_fully_expanded(self):
        return len(self.children) > 0 and all(child.visit_count > 0 for child in self.children)

    def best_child(self, c_param=1.41):
        epsilon=1e-6
        choices_weights = [
            (child.total_cost / (child.visit_count + epsilon)) + 
            c_param * (2 * np.log(self.visit_count + 1) / (child.visit_count + epsilon)) ** 0.5
            for child in self.children
        ]
        #return choices_weights
        return self.children[np.argmin(choices_weights)]

# %% [markdown]
# #### TEST

# %%
class MCTS(data_preprocessing):
    def __init__(self, instance, root_state, iterations):
        super().__init__(instance_path=instance)
        self.root = Node(root_state)
        self.iterations = iterations
        self.best_leaf = None
        self.best_leaf_cost = float('inf')
        self.search()
        
    def expand_node(self, node):
        actions = self.possible_flights_from_an_airport_at_a_specific_day_with_previous_areas(
            node.state['current_day'], node.state['current_airport'],node.state['visited_zones'])

        for action in actions:
            #print(action)
            new_state = self.transition_function(node.state, action)
            node.add_child(new_state)
            #print(new_state)
            
    def transition_function(self, state, action):
        new_state = deepcopy(state)  # Deep copy to avoid side effects
        new_state['current_day'] += 1
        new_state['current_airport'] = action[0]
        new_state['total_cost'] += action[1]
        new_state['path'].append(action[0])
        #print(f"Remove {self.associated_area_to_airport(airport=new_state['current_airport'])}")
        new_state['remaining_zones'].remove(self.associated_area_to_airport(airport=new_state['current_airport']))
        new_state['visited_zones'].append(self.associated_area_to_airport(airport=action[0]))
        return new_state

    def random_policy(self, state):
        actions = self.possible_flights_from_an_airport_at_a_specific_day_with_previous_areas(
            day=state['current_day'], from_airport=state['current_airport'],visited_areas=state['visited_zones']
        )
        return random.choice(actions)
    
    def select(self, node):
        current_node = node
        while current_node.is_fully_expanded() and current_node.children:
            current_node = current_node.best_child()
            #print(current_node)
        return current_node

    def simulate(self, node):
        current_simulation_state = deepcopy(node.state)
        while current_simulation_state['current_day']!=self.number_of_areas:
            print(current_simulation_state)
            action = self.random_policy(current_simulation_state)
            current_simulation_state = self.transition_function(current_simulation_state, action)
        
        #current_simulation_state['remaining_zones'].append(self.starting_area)
        #action = self.random_policy(current_simulation_state)
        #current_simulation_state = self.transition_function(current_simulation_state, action)
        print(current_simulation_state['total_cost'])
        
        if current_simulation_state['total_cost'] < self.best_leaf_cost:
            self.best_leaf = current_simulation_state
            self.best_leaf_cost = current_simulation_state['total_cost']
                
        return current_simulation_state['total_cost']

    def backpropagate(self, node, cost):
        current_node = node
        while current_node is not None:
            current_node.visit_count += 1
            current_node.total_cost += cost
            current_node = current_node.parent

    def search(self):
        for _ in range(self.iterations):
            node_to_explore = self.select(self.root)
            if not node_to_explore.is_fully_expanded():
                self.expand_node(node_to_explore)
            cost = self.simulate(node_to_explore)
            self.backpropagate(node_to_explore, cost)
        best_node = self.root.best_child(c_param=0)
        
        return self.root.best_child(c_param=0).state['path'], self.root.best_child(c_param=0).state['total_cost']

# %%
instance_path = 'Flight connections dataset/1.in'
data_processor = data_preprocessing(instance_path=instance_path)

# Define root state
root_state = {
    'current_day': 1,
    'current_airport': data_processor.starting_airport,
    'remaining_zones': [x for x in data_processor.list_areas if x != data_processor.starting_area],  # Exclude the starting area
    'visited_zones': [data_processor.starting_area],  # Exclude the starting area
    'total_cost': 0,
    'path': [data_processor.starting_airport]
}

mcts = MCTS(instance=instance_path, root_state=root_state, iterations=1000)

print(mcts.best_leaf,mcts.best_leaf_cost)
# Out:
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '2'], 'total_cost': 3619, 'path': ['AB0', 'AB2']}
# {'current_day': 3, 'current_airport': 'AB3', 'remaining_zones': ['1', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '2', '3'], 'total_cost': 7827, 'path': ['AB0', 'AB2', 'AB3']}
# {'current_day': 4, 'current_airport': 'AB5', 'remaining_zones': ['1', '4', '6', '7', '8', '9'], 'visited_zones': ['0', '2', '3', '5'], 'total_cost': 7987, 'path': ['AB0', 'AB2', 'AB3', 'AB5']}
# {'current_day': 5, 'current_airport': 'AB7', 'remaining_zones': ['1', '4', '6', '8', '9'], 'visited_zones': ['0', '2', '3', '5', '7'], 'total_cost': 13640, 'path': ['AB0', 'AB2', 'AB3', 'AB5', 'AB7']}
# {'current_day': 6, 'current_airport': 'AB8', 'remaining_zones': ['1', '4', '6', '9'], 'visited_zones': ['0', '2', '3', '5', '7', '8'], 'total_cost': 17044, 'path': ['AB0', 'AB2', 'AB3', 'AB5', 'AB7', 'AB8']}
# {'current_day': 7, 'current_airport': 'AB4', 'remaining_zones': ['1', '6', '9'], 'visited_zones': ['0', '2', '3', '5', '7', '8', '4'], 'total_cost': 17310, 'path': ['AB0', 'AB2', 'AB3', 'AB5', 'AB7', 'AB8', 'AB4']}
# {'current_day': 8, 'current_airport': 'AB9', 'remaining_zones': ['1', '6'], 'visited_zones': ['0', '2', '3', '5', '7', '8', '4', '9'], 'total_cost': 17473, 'path': ['AB0', 'AB2', 'AB3', 'AB5', 'AB7', 'AB8', 'AB4', 'AB9']}
# {'current_day': 9, 'current_airport': 'AB6', 'remaining_zones': ['1'], 'visited_zones': ['0', '2', '3', '5', '7', '8', '4', '9', '6'], 'total_cost': 18863, 'path': ['AB0', 'AB2', 'AB3', 'AB5', 'AB7', 'AB8', 'AB4', 'AB9', 'AB6']}
# 19155
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB1', 'remaining_zones': ['2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '1'], 'total_cost': 1, 'path': ['AB0', 'AB1']}
# {'current_day': 3, 'current_airport': 'AB6', 'remaining_zones': ['2', '3', '4', '5', '7', '8', '9'], 'visited_zones': ['0', '1', '6'], 'total_cost': 164, 'path': ['AB0', 'AB1', 'AB6']}
# {'current_day': 4, 'current_airport': 'AB5', 'remaining_zones': ['2', '3', '4', '7', '8', '9'], 'visited_zones': ['0', '1', '6', '5'], 'total_cost': 4303, 'path': ['AB0', 'AB1', 'AB6', 'AB5']}
# {'current_day': 5, 'current_airport': 'AB3', 'remaining_zones': ['2', '4', '7', '8', '9'], 'visited_zones': ['0', '1', '6', '5', '3'], 'total_cost': 4527, 'path': ['AB0', 'AB1', 'AB6', 'AB5', 'AB3']}
# {'current_day': 6, 'current_airport': 'AB2', 'remaining_zones': ['4', '7', '8', '9'], 'visited_zones': ['0', '1', '6', '5', '3', '2'], 'total_cost': 7039, 'path': ['AB0', 'AB1', 'AB6', 'AB5', 'AB3', 'AB2']}
# {'current_day': 7, 'current_airport': 'AB8', 'remaining_zones': ['4', '7', '9'], 'visited_zones': ['0', '1', '6', '5', '3', '2', '8'], 'total_cost': 7262, 'path': ['AB0', 'AB1', 'AB6', 'AB5', 'AB3', 'AB2', 'AB8']}
# {'current_day': 8, 'current_airport': 'AB4', 'remaining_zones': ['7', '9'], 'visited_zones': ['0', '1', '6', '5', '3', '2', '8', '4'], 'total_cost': 7508, 'path': ['AB0', 'AB1', 'AB6', 'AB5', 'AB3', 'AB2', 'AB8', 'AB4']}
# {'current_day': 9, 'current_airport': 'AB7', 'remaining_zones': ['9'], 'visited_zones': ['0', '1', '6', '5', '3', '2', '8', '4', '7'], 'total_cost': 7787, 'path': ['AB0', 'AB1', 'AB6', 'AB5', 'AB3', 'AB2', 'AB8', 'AB4', 'AB7']}
# 12226
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB1', 'remaining_zones': ['2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '1'], 'total_cost': 1, 'path': ['AB0', 'AB1']}
# {'current_day': 3, 'current_airport': 'AB6', 'remaining_zones': ['2', '3', '4', '5', '7', '8', '9'], 'visited_zones': ['0', '1', '6'], 'total_cost': 164, 'path': ['AB0', 'AB1', 'AB6']}
# {'current_day': 4, 'current_airport': 'AB3', 'remaining_zones': ['2', '4', '5', '7', '8', '9'], 'visited_zones': ['0', '1', '6', '3'], 'total_cost': 285, 'path': ['AB0', 'AB1', 'AB6', 'AB3']}
# {'current_day': 5, 'current_airport': 'AB4', 'remaining_zones': ['2', '5', '7', '8', '9'], 'visited_zones': ['0', '1', '6', '3', '4'], 'total_cost': 3565, 'path': ['AB0', 'AB1', 'AB6', 'AB3', 'AB4']}
# {'current_day': 6, 'current_airport': 'AB8', 'remaining_zones': ['2', '5', '7', '9'], 'visited_zones': ['0', '1', '6', '3', '4', '8'], 'total_cost': 3863, 'path': ['AB0', 'AB1', 'AB6', 'AB3', 'AB4', 'AB8']}
# {'current_day': 7, 'current_airport': 'AB5', 'remaining_zones': ['2', '7', '9'], 'visited_zones': ['0', '1', '6', '3', '4', '8', '5'], 'total_cost': 9399, 'path': ['AB0', 'AB1', 'AB6', 'AB3', 'AB4', 'AB8', 'AB5']}
# {'current_day': 8, 'current_airport': 'AB9', 'remaining_zones': ['2', '7'], 'visited_zones': ['0', '1', '6', '3', '4', '8', '5', '9'], 'total_cost': 13460, 'path': ['AB0', 'AB1', 'AB6', 'AB3', 'AB4', 'AB8', 'AB5', 'AB9']}
# {'current_day': 9, 'current_airport': 'AB7', 'remaining_zones': ['2'], 'visited_zones': ['0', '1', '6', '3', '4', '8', '5', '9', '7'], 'total_cost': 15980, 'path': ['AB0', 'AB1', 'AB6', 'AB3', 'AB4', 'AB8', 'AB5', 'AB9', 'AB7']}
# 16219
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8'], 'total_cost': 283, 'path': ['AB0', 'AB8']}
# {'current_day': 3, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '2'], 'total_cost': 462, 'path': ['AB0', 'AB8', 'AB2']}
# {'current_day': 4, 'current_airport': 'AB3', 'remaining_zones': ['1', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '2', '3'], 'total_cost': 6232, 'path': ['AB0', 'AB8', 'AB2', 'AB3']}
# {'current_day': 5, 'current_airport': 'AB6', 'remaining_zones': ['1', '4', '5', '7', '9'], 'visited_zones': ['0', '8', '2', '3', '6'], 'total_cost': 6507, 'path': ['AB0', 'AB8', 'AB2', 'AB3', 'AB6']}
# {'current_day': 6, 'current_airport': 'AB1', 'remaining_zones': ['4', '5', '7', '9'], 'visited_zones': ['0', '8', '2', '3', '6', '1'], 'total_cost': 6672, 'path': ['AB0', 'AB8', 'AB2', 'AB3', 'AB6', 'AB1']}
# {'current_day': 7, 'current_airport': 'AB4', 'remaining_zones': ['5', '7', '9'], 'visited_zones': ['0', '8', '2', '3', '6', '1', '4'], 'total_cost': 9822, 'path': ['AB0', 'AB8', 'AB2', 'AB3', 'AB6', 'AB1', 'AB4']}
# {'current_day': 8, 'current_airport': 'AB9', 'remaining_zones': ['5', '7'], 'visited_zones': ['0', '8', '2', '3', '6', '1', '4', '9'], 'total_cost': 9985, 'path': ['AB0', 'AB8', 'AB2', 'AB3', 'AB6', 'AB1', 'AB4', 'AB9']}
# {'current_day': 9, 'current_airport': 'AB7', 'remaining_zones': ['5'], 'visited_zones': ['0', '8', '2', '3', '6', '1', '4', '9', '7'], 'total_cost': 12505, 'path': ['AB0', 'AB8', 'AB2', 'AB3', 'AB6', 'AB1', 'AB4', 'AB9', 'AB7']}
# 15102
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB6', 'remaining_zones': ['1', '2', '3', '4', '5', '7', '8', '9'], 'visited_zones': ['0', '6'], 'total_cost': 179, 'path': ['AB0', 'AB6']}
# {'current_day': 3, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '3', '4', '5', '7', '9'], 'visited_zones': ['0', '6', '8'], 'total_cost': 2721, 'path': ['AB0', 'AB6', 'AB8']}
# {'current_day': 4, 'current_airport': 'AB5', 'remaining_zones': ['1', '2', '3', '4', '7', '9'], 'visited_zones': ['0', '6', '8', '5'], 'total_cost': 5607, 'path': ['AB0', 'AB6', 'AB8', 'AB5']}
# {'current_day': 5, 'current_airport': 'AB9', 'remaining_zones': ['1', '2', '3', '4', '7'], 'visited_zones': ['0', '6', '8', '5', '9'], 'total_cost': 10574, 'path': ['AB0', 'AB6', 'AB8', 'AB5', 'AB9']}
# {'current_day': 6, 'current_airport': 'AB3', 'remaining_zones': ['1', '2', '4', '7'], 'visited_zones': ['0', '6', '8', '5', '9', '3'], 'total_cost': 10788, 'path': ['AB0', 'AB6', 'AB8', 'AB5', 'AB9', 'AB3']}
# {'current_day': 7, 'current_airport': 'AB1', 'remaining_zones': ['2', '4', '7'], 'visited_zones': ['0', '6', '8', '5', '9', '3', '1'], 'total_cost': 12997, 'path': ['AB0', 'AB6', 'AB8', 'AB5', 'AB9', 'AB3', 'AB1']}
# {'current_day': 8, 'current_airport': 'AB2', 'remaining_zones': ['4', '7'], 'visited_zones': ['0', '6', '8', '5', '9', '3', '1', '2'], 'total_cost': 18624, 'path': ['AB0', 'AB6', 'AB8', 'AB5', 'AB9', 'AB3', 'AB1', 'AB2']}
# {'current_day': 9, 'current_airport': 'AB7', 'remaining_zones': ['4'], 'visited_zones': ['0', '6', '8', '5', '9', '3', '1', '2', '7'], 'total_cost': 18869, 'path': ['AB0', 'AB6', 'AB8', 'AB5', 'AB9', 'AB3', 'AB1', 'AB2', 'AB7']}
# 18994
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB3', 'remaining_zones': ['1', '2', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '3'], 'total_cost': 4618, 'path': ['AB0', 'AB3']}
# {'current_day': 3, 'current_airport': 'AB1', 'remaining_zones': ['2', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '3', '1'], 'total_cost': 6231, 'path': ['AB0', 'AB3', 'AB1']}
# {'current_day': 4, 'current_airport': 'AB6', 'remaining_zones': ['2', '4', '5', '7', '8', '9'], 'visited_zones': ['0', '3', '1', '6'], 'total_cost': 6436, 'path': ['AB0', 'AB3', 'AB1', 'AB6']}
# {'current_day': 5, 'current_airport': 'AB4', 'remaining_zones': ['2', '5', '7', '8', '9'], 'visited_zones': ['0', '3', '1', '6', '4'], 'total_cost': 6710, 'path': ['AB0', 'AB3', 'AB1', 'AB6', 'AB4']}
# {'current_day': 6, 'current_airport': 'AB8', 'remaining_zones': ['2', '5', '7', '9'], 'visited_zones': ['0', '3', '1', '6', '4', '8'], 'total_cost': 7008, 'path': ['AB0', 'AB3', 'AB1', 'AB6', 'AB4', 'AB8']}
# {'current_day': 7, 'current_airport': 'AB2', 'remaining_zones': ['5', '7', '9'], 'visited_zones': ['0', '3', '1', '6', '4', '8', '2'], 'total_cost': 7258, 'path': ['AB0', 'AB3', 'AB1', 'AB6', 'AB4', 'AB8', 'AB2']}
# {'current_day': 8, 'current_airport': 'AB7', 'remaining_zones': ['5', '9'], 'visited_zones': ['0', '3', '1', '6', '4', '8', '2', '7'], 'total_cost': 7404, 'path': ['AB0', 'AB3', 'AB1', 'AB6', 'AB4', 'AB8', 'AB2', 'AB7']}
# {'current_day': 9, 'current_airport': 'AB9', 'remaining_zones': ['5'], 'visited_zones': ['0', '3', '1', '6', '4', '8', '2', '7', '9'], 'total_cost': 8414, 'path': ['AB0', 'AB3', 'AB1', 'AB6', 'AB4', 'AB8', 'AB2', 'AB7', 'AB9']}
# 9523
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB6', 'remaining_zones': ['1', '2', '3', '4', '5', '7', '8', '9'], 'visited_zones': ['0', '6'], 'total_cost': 179, 'path': ['AB0', 'AB6']}
# {'current_day': 3, 'current_airport': 'AB3', 'remaining_zones': ['1', '2', '4', '5', '7', '8', '9'], 'visited_zones': ['0', '6', '3'], 'total_cost': 305, 'path': ['AB0', 'AB6', 'AB3']}
# {'current_day': 4, 'current_airport': 'AB5', 'remaining_zones': ['1', '2', '4', '7', '8', '9'], 'visited_zones': ['0', '6', '3', '5'], 'total_cost': 465, 'path': ['AB0', 'AB6', 'AB3', 'AB5']}
# {'current_day': 5, 'current_airport': 'AB4', 'remaining_zones': ['1', '2', '7', '8', '9'], 'visited_zones': ['0', '6', '3', '5', '4'], 'total_cost': 597, 'path': ['AB0', 'AB6', 'AB3', 'AB5', 'AB4']}
# {'current_day': 6, 'current_airport': 'AB1', 'remaining_zones': ['2', '7', '8', '9'], 'visited_zones': ['0', '6', '3', '5', '4', '1'], 'total_cost': 3028, 'path': ['AB0', 'AB6', 'AB3', 'AB5', 'AB4', 'AB1']}
# {'current_day': 7, 'current_airport': 'AB8', 'remaining_zones': ['2', '7', '9'], 'visited_zones': ['0', '6', '3', '5', '4', '1', '8'], 'total_cost': 3129, 'path': ['AB0', 'AB6', 'AB3', 'AB5', 'AB4', 'AB1', 'AB8']}
# {'current_day': 8, 'current_airport': 'AB9', 'remaining_zones': ['2', '7'], 'visited_zones': ['0', '6', '3', '5', '4', '1', '8', '9'], 'total_cost': 8676, 'path': ['AB0', 'AB6', 'AB3', 'AB5', 'AB4', 'AB1', 'AB8', 'AB9']}
# {'current_day': 9, 'current_airport': 'AB2', 'remaining_zones': ['7'], 'visited_zones': ['0', '6', '3', '5', '4', '1', '8', '9', '2'], 'total_cost': 8875, 'path': ['AB0', 'AB6', 'AB3', 'AB5', 'AB4', 'AB1', 'AB8', 'AB9', 'AB2']}
# 9072
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB6', 'remaining_zones': ['1', '2', '3', '4', '5', '7', '8', '9'], 'visited_zones': ['0', '6'], 'total_cost': 179, 'path': ['AB0', 'AB6']}
# {'current_day': 3, 'current_airport': 'AB1', 'remaining_zones': ['2', '3', '4', '5', '7', '8', '9'], 'visited_zones': ['0', '6', '1'], 'total_cost': 314, 'path': ['AB0', 'AB6', 'AB1']}
# {'current_day': 4, 'current_airport': 'AB8', 'remaining_zones': ['2', '3', '4', '5', '7', '9'], 'visited_zones': ['0', '6', '1', '8'], 'total_cost': 431, 'path': ['AB0', 'AB6', 'AB1', 'AB8']}
# {'current_day': 5, 'current_airport': 'AB7', 'remaining_zones': ['2', '3', '4', '5', '9'], 'visited_zones': ['0', '6', '1', '8', '7'], 'total_cost': 5059, 'path': ['AB0', 'AB6', 'AB1', 'AB8', 'AB7']}
# {'current_day': 6, 'current_airport': 'AB5', 'remaining_zones': ['2', '3', '4', '9'], 'visited_zones': ['0', '6', '1', '8', '7', '5'], 'total_cost': 6456, 'path': ['AB0', 'AB6', 'AB1', 'AB8', 'AB7', 'AB5']}
# {'current_day': 7, 'current_airport': 'AB9', 'remaining_zones': ['2', '3', '4'], 'visited_zones': ['0', '6', '1', '8', '7', '5', '9'], 'total_cost': 8775, 'path': ['AB0', 'AB6', 'AB1', 'AB8', 'AB7', 'AB5', 'AB9']}
# {'current_day': 8, 'current_airport': 'AB3', 'remaining_zones': ['2', '4'], 'visited_zones': ['0', '6', '1', '8', '7', '5', '9', '3'], 'total_cost': 9062, 'path': ['AB0', 'AB6', 'AB1', 'AB8', 'AB7', 'AB5', 'AB9', 'AB3']}
# {'current_day': 9, 'current_airport': 'AB2', 'remaining_zones': ['4'], 'visited_zones': ['0', '6', '1', '8', '7', '5', '9', '3', '2'], 'total_cost': 14336, 'path': ['AB0', 'AB6', 'AB1', 'AB8', 'AB7', 'AB5', 'AB9', 'AB3', 'AB2']}
# 16033
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB3', 'remaining_zones': ['1', '2', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '3'], 'total_cost': 4618, 'path': ['AB0', 'AB3']}
# {'current_day': 3, 'current_airport': 'AB7', 'remaining_zones': ['1', '2', '4', '5', '6', '8', '9'], 'visited_zones': ['0', '3', '7'], 'total_cost': 4826, 'path': ['AB0', 'AB3', 'AB7']}
# {'current_day': 4, 'current_airport': 'AB5', 'remaining_zones': ['1', '2', '4', '6', '8', '9'], 'visited_zones': ['0', '3', '7', '5'], 'total_cost': 7824, 'path': ['AB0', 'AB3', 'AB7', 'AB5']}
# {'current_day': 5, 'current_airport': 'AB4', 'remaining_zones': ['1', '2', '6', '8', '9'], 'visited_zones': ['0', '3', '7', '5', '4'], 'total_cost': 7956, 'path': ['AB0', 'AB3', 'AB7', 'AB5', 'AB4']}
# {'current_day': 6, 'current_airport': 'AB9', 'remaining_zones': ['1', '2', '6', '8'], 'visited_zones': ['0', '3', '7', '5', '4', '9'], 'total_cost': 8151, 'path': ['AB0', 'AB3', 'AB7', 'AB5', 'AB4', 'AB9']}
# {'current_day': 7, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '6'], 'visited_zones': ['0', '3', '7', '5', '4', '9', '8'], 'total_cost': 9983, 'path': ['AB0', 'AB3', 'AB7', 'AB5', 'AB4', 'AB9', 'AB8']}
# {'current_day': 8, 'current_airport': 'AB2', 'remaining_zones': ['1', '6'], 'visited_zones': ['0', '3', '7', '5', '4', '9', '8', '2'], 'total_cost': 10195, 'path': ['AB0', 'AB3', 'AB7', 'AB5', 'AB4', 'AB9', 'AB8', 'AB2']}
# {'current_day': 9, 'current_airport': 'AB1', 'remaining_zones': ['6'], 'visited_zones': ['0', '3', '7', '5', '4', '9', '8', '2', '1'], 'total_cost': 15962, 'path': ['AB0', 'AB3', 'AB7', 'AB5', 'AB4', 'AB9', 'AB8', 'AB2', 'AB1']}
# 16204
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB3', 'remaining_zones': ['1', '2', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '3'], 'total_cost': 4618, 'path': ['AB0', 'AB3']}
# {'current_day': 3, 'current_airport': 'AB1', 'remaining_zones': ['2', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '3', '1'], 'total_cost': 6231, 'path': ['AB0', 'AB3', 'AB1']}
# {'current_day': 4, 'current_airport': 'AB8', 'remaining_zones': ['2', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '3', '1', '8'], 'total_cost': 6348, 'path': ['AB0', 'AB3', 'AB1', 'AB8']}
# {'current_day': 5, 'current_airport': 'AB6', 'remaining_zones': ['2', '4', '5', '7', '9'], 'visited_zones': ['0', '3', '1', '8', '6'], 'total_cost': 11752, 'path': ['AB0', 'AB3', 'AB1', 'AB8', 'AB6']}
# {'current_day': 6, 'current_airport': 'AB4', 'remaining_zones': ['2', '5', '7', '9'], 'visited_zones': ['0', '3', '1', '8', '6', '4'], 'total_cost': 12044, 'path': ['AB0', 'AB3', 'AB1', 'AB8', 'AB6', 'AB4']}
# {'current_day': 7, 'current_airport': 'AB2', 'remaining_zones': ['5', '7', '9'], 'visited_zones': ['0', '3', '1', '8', '6', '4', '2'], 'total_cost': 14243, 'path': ['AB0', 'AB3', 'AB1', 'AB8', 'AB6', 'AB4', 'AB2']}
# {'current_day': 8, 'current_airport': 'AB7', 'remaining_zones': ['5', '9'], 'visited_zones': ['0', '3', '1', '8', '6', '4', '2', '7'], 'total_cost': 14389, 'path': ['AB0', 'AB3', 'AB1', 'AB8', 'AB6', 'AB4', 'AB2', 'AB7']}
# {'current_day': 9, 'current_airport': 'AB9', 'remaining_zones': ['5'], 'visited_zones': ['0', '3', '1', '8', '6', '4', '2', '7', '9'], 'total_cost': 15399, 'path': ['AB0', 'AB3', 'AB1', 'AB8', 'AB6', 'AB4', 'AB2', 'AB7', 'AB9']}
# 16508
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB6', 'remaining_zones': ['1', '2', '3', '4', '5', '7', '8', '9'], 'visited_zones': ['0', '6'], 'total_cost': 179, 'path': ['AB0', 'AB6']}
# {'current_day': 3, 'current_airport': 'AB1', 'remaining_zones': ['2', '3', '4', '5', '7', '8', '9'], 'visited_zones': ['0', '6', '1'], 'total_cost': 314, 'path': ['AB0', 'AB6', 'AB1']}
# {'current_day': 4, 'current_airport': 'AB5', 'remaining_zones': ['2', '3', '4', '7', '8', '9'], 'visited_zones': ['0', '6', '1', '5'], 'total_cost': 490, 'path': ['AB0', 'AB6', 'AB1', 'AB5']}
# {'current_day': 5, 'current_airport': 'AB3', 'remaining_zones': ['2', '4', '7', '8', '9'], 'visited_zones': ['0', '6', '1', '5', '3'], 'total_cost': 714, 'path': ['AB0', 'AB6', 'AB1', 'AB5', 'AB3']}
# {'current_day': 6, 'current_airport': 'AB9', 'remaining_zones': ['2', '4', '7', '8'], 'visited_zones': ['0', '6', '1', '5', '3', '9'], 'total_cost': 907, 'path': ['AB0', 'AB6', 'AB1', 'AB5', 'AB3', 'AB9']}
# {'current_day': 7, 'current_airport': 'AB8', 'remaining_zones': ['2', '4', '7'], 'visited_zones': ['0', '6', '1', '5', '3', '9', '8'], 'total_cost': 2739, 'path': ['AB0', 'AB6', 'AB1', 'AB5', 'AB3', 'AB9', 'AB8']}
# {'current_day': 8, 'current_airport': 'AB7', 'remaining_zones': ['2', '4'], 'visited_zones': ['0', '6', '1', '5', '3', '9', '8', '7'], 'total_cost': 7568, 'path': ['AB0', 'AB6', 'AB1', 'AB5', 'AB3', 'AB9', 'AB8', 'AB7']}
# {'current_day': 9, 'current_airport': 'AB2', 'remaining_zones': ['4'], 'visited_zones': ['0', '6', '1', '5', '3', '9', '8', '7', '2'], 'total_cost': 7767, 'path': ['AB0', 'AB6', 'AB1', 'AB5', 'AB3', 'AB9', 'AB8', 'AB7', 'AB2']}
# 9464
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB4', 'remaining_zones': ['1', '2', '3', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '4'], 'total_cost': 2127, 'path': ['AB0', 'AB4']}
# {'current_day': 3, 'current_airport': 'AB9', 'remaining_zones': ['1', '2', '3', '5', '6', '7', '8'], 'visited_zones': ['0', '4', '9'], 'total_cost': 2315, 'path': ['AB0', 'AB4', 'AB9']}
# {'current_day': 4, 'current_airport': 'AB3', 'remaining_zones': ['1', '2', '5', '6', '7', '8'], 'visited_zones': ['0', '4', '9', '3'], 'total_cost': 2609, 'path': ['AB0', 'AB4', 'AB9', 'AB3']}
# {'current_day': 5, 'current_airport': 'AB1', 'remaining_zones': ['2', '5', '6', '7', '8'], 'visited_zones': ['0', '4', '9', '3', '1'], 'total_cost': 8239, 'path': ['AB0', 'AB4', 'AB9', 'AB3', 'AB1']}
# {'current_day': 6, 'current_airport': 'AB5', 'remaining_zones': ['2', '6', '7', '8'], 'visited_zones': ['0', '4', '9', '3', '1', '5'], 'total_cost': 8490, 'path': ['AB0', 'AB4', 'AB9', 'AB3', 'AB1', 'AB5']}
# {'current_day': 7, 'current_airport': 'AB2', 'remaining_zones': ['6', '7', '8'], 'visited_zones': ['0', '4', '9', '3', '1', '5', '2'], 'total_cost': 8782, 'path': ['AB0', 'AB4', 'AB9', 'AB3', 'AB1', 'AB5', 'AB2']}
# {'current_day': 8, 'current_airport': 'AB7', 'remaining_zones': ['6', '8'], 'visited_zones': ['0', '4', '9', '3', '1', '5', '2', '7'], 'total_cost': 8928, 'path': ['AB0', 'AB4', 'AB9', 'AB3', 'AB1', 'AB5', 'AB2', 'AB7']}
# {'current_day': 9, 'current_airport': 'AB6', 'remaining_zones': ['8'], 'visited_zones': ['0', '4', '9', '3', '1', '5', '2', '7', '6'], 'total_cost': 10504, 'path': ['AB0', 'AB4', 'AB9', 'AB3', 'AB1', 'AB5', 'AB2', 'AB7', 'AB6']}
# 11648
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB6', 'remaining_zones': ['1', '2', '3', '4', '5', '7', '8', '9'], 'visited_zones': ['0', '6'], 'total_cost': 179, 'path': ['AB0', 'AB6']}
# {'current_day': 3, 'current_airport': 'AB3', 'remaining_zones': ['1', '2', '4', '5', '7', '8', '9'], 'visited_zones': ['0', '6', '3'], 'total_cost': 305, 'path': ['AB0', 'AB6', 'AB3']}
# {'current_day': 4, 'current_airport': 'AB5', 'remaining_zones': ['1', '2', '4', '7', '8', '9'], 'visited_zones': ['0', '6', '3', '5'], 'total_cost': 465, 'path': ['AB0', 'AB6', 'AB3', 'AB5']}
# {'current_day': 5, 'current_airport': 'AB2', 'remaining_zones': ['1', '4', '7', '8', '9'], 'visited_zones': ['0', '6', '3', '5', '2'], 'total_cost': 699, 'path': ['AB0', 'AB6', 'AB3', 'AB5', 'AB2']}
# {'current_day': 6, 'current_airport': 'AB8', 'remaining_zones': ['1', '4', '7', '9'], 'visited_zones': ['0', '6', '3', '5', '2', '8'], 'total_cost': 940, 'path': ['AB0', 'AB6', 'AB3', 'AB5', 'AB2', 'AB8']}
# {'current_day': 7, 'current_airport': 'AB9', 'remaining_zones': ['1', '4', '7'], 'visited_zones': ['0', '6', '3', '5', '2', '8', '9'], 'total_cost': 6655, 'path': ['AB0', 'AB6', 'AB3', 'AB5', 'AB2', 'AB8', 'AB9']}
# {'current_day': 8, 'current_airport': 'AB7', 'remaining_zones': ['1', '4'], 'visited_zones': ['0', '6', '3', '5', '2', '8', '9', '7'], 'total_cost': 10015, 'path': ['AB0', 'AB6', 'AB3', 'AB5', 'AB2', 'AB8', 'AB9', 'AB7']}
# {'current_day': 9, 'current_airport': 'AB1', 'remaining_zones': ['4'], 'visited_zones': ['0', '6', '3', '5', '2', '8', '9', '7', '1'], 'total_cost': 10158, 'path': ['AB0', 'AB6', 'AB3', 'AB5', 'AB2', 'AB8', 'AB9', 'AB7', 'AB1']}
# 12878
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '2'], 'total_cost': 3619, 'path': ['AB0', 'AB2']}
# {'current_day': 3, 'current_airport': 'AB8', 'remaining_zones': ['1', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '2', '8'], 'total_cost': 3829, 'path': ['AB0', 'AB2', 'AB8']}
# {'current_day': 4, 'current_airport': 'AB4', 'remaining_zones': ['1', '3', '5', '6', '7', '9'], 'visited_zones': ['0', '2', '8', '4'], 'total_cost': 3984, 'path': ['AB0', 'AB2', 'AB8', 'AB4']}
# {'current_day': 5, 'current_airport': 'AB7', 'remaining_zones': ['1', '3', '5', '6', '9'], 'visited_zones': ['0', '2', '8', '4', '7'], 'total_cost': 4209, 'path': ['AB0', 'AB2', 'AB8', 'AB4', 'AB7']}
# {'current_day': 6, 'current_airport': 'AB1', 'remaining_zones': ['3', '5', '6', '9'], 'visited_zones': ['0', '2', '8', '4', '7', '1'], 'total_cost': 4484, 'path': ['AB0', 'AB2', 'AB8', 'AB4', 'AB7', 'AB1']}
# {'current_day': 7, 'current_airport': 'AB3', 'remaining_zones': ['5', '6', '9'], 'visited_zones': ['0', '2', '8', '4', '7', '1', '3'], 'total_cost': 7773, 'path': ['AB0', 'AB2', 'AB8', 'AB4', 'AB7', 'AB1', 'AB3']}
# {'current_day': 8, 'current_airport': 'AB6', 'remaining_zones': ['5', '9'], 'visited_zones': ['0', '2', '8', '4', '7', '1', '3', '6'], 'total_cost': 8034, 'path': ['AB0', 'AB2', 'AB8', 'AB4', 'AB7', 'AB1', 'AB3', 'AB6']}
# {'current_day': 9, 'current_airport': 'AB5', 'remaining_zones': ['9'], 'visited_zones': ['0', '2', '8', '4', '7', '1', '3', '6', '5'], 'total_cost': 12775, 'path': ['AB0', 'AB2', 'AB8', 'AB4', 'AB7', 'AB1', 'AB3', 'AB6', 'AB5']}
# 13916
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB3', 'remaining_zones': ['1', '2', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '3'], 'total_cost': 4618, 'path': ['AB0', 'AB3']}
# {'current_day': 3, 'current_airport': 'AB4', 'remaining_zones': ['1', '2', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '3', '4'], 'total_cost': 8061, 'path': ['AB0', 'AB3', 'AB4']}
# {'current_day': 4, 'current_airport': 'AB5', 'remaining_zones': ['1', '2', '6', '7', '8', '9'], 'visited_zones': ['0', '3', '4', '5'], 'total_cost': 8186, 'path': ['AB0', 'AB3', 'AB4', 'AB5']}
# {'current_day': 5, 'current_airport': 'AB7', 'remaining_zones': ['1', '2', '6', '8', '9'], 'visited_zones': ['0', '3', '4', '5', '7'], 'total_cost': 13839, 'path': ['AB0', 'AB3', 'AB4', 'AB5', 'AB7']}
# {'current_day': 6, 'current_airport': 'AB9', 'remaining_zones': ['1', '2', '6', '8'], 'visited_zones': ['0', '3', '4', '5', '7', '9'], 'total_cost': 15727, 'path': ['AB0', 'AB3', 'AB4', 'AB5', 'AB7', 'AB9']}
# {'current_day': 7, 'current_airport': 'AB1', 'remaining_zones': ['2', '6', '8'], 'visited_zones': ['0', '3', '4', '5', '7', '9', '1'], 'total_cost': 15994, 'path': ['AB0', 'AB3', 'AB4', 'AB5', 'AB7', 'AB9', 'AB1']}
# {'current_day': 8, 'current_airport': 'AB2', 'remaining_zones': ['6', '8'], 'visited_zones': ['0', '3', '4', '5', '7', '9', '1', '2'], 'total_cost': 21621, 'path': ['AB0', 'AB3', 'AB4', 'AB5', 'AB7', 'AB9', 'AB1', 'AB2']}
# {'current_day': 9, 'current_airport': 'AB8', 'remaining_zones': ['6'], 'visited_zones': ['0', '3', '4', '5', '7', '9', '1', '2', '8'], 'total_cost': 21914, 'path': ['AB0', 'AB3', 'AB4', 'AB5', 'AB7', 'AB9', 'AB1', 'AB2', 'AB8']}
# 27759
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '2'], 'total_cost': 3619, 'path': ['AB0', 'AB2']}
# {'current_day': 3, 'current_airport': 'AB5', 'remaining_zones': ['1', '3', '4', '6', '7', '8', '9'], 'visited_zones': ['0', '2', '5'], 'total_cost': 3907, 'path': ['AB0', 'AB2', 'AB5']}
# {'current_day': 4, 'current_airport': 'AB9', 'remaining_zones': ['1', '3', '4', '6', '7', '8'], 'visited_zones': ['0', '2', '5', '9'], 'total_cost': 6231, 'path': ['AB0', 'AB2', 'AB5', 'AB9']}
# {'current_day': 5, 'current_airport': 'AB6', 'remaining_zones': ['1', '3', '4', '7', '8'], 'visited_zones': ['0', '2', '5', '9', '6'], 'total_cost': 9294, 'path': ['AB0', 'AB2', 'AB5', 'AB9', 'AB6']}
# {'current_day': 6, 'current_airport': 'AB7', 'remaining_zones': ['1', '3', '4', '8'], 'visited_zones': ['0', '2', '5', '9', '6', '7'], 'total_cost': 14176, 'path': ['AB0', 'AB2', 'AB5', 'AB9', 'AB6', 'AB7']}
# {'current_day': 7, 'current_airport': 'AB3', 'remaining_zones': ['1', '4', '8'], 'visited_zones': ['0', '2', '5', '9', '6', '7', '3'], 'total_cost': 14390, 'path': ['AB0', 'AB2', 'AB5', 'AB9', 'AB6', 'AB7', 'AB3']}
# {'current_day': 8, 'current_airport': 'AB8', 'remaining_zones': ['1', '4'], 'visited_zones': ['0', '2', '5', '9', '6', '7', '3', '8'], 'total_cost': 14644, 'path': ['AB0', 'AB2', 'AB5', 'AB9', 'AB6', 'AB7', 'AB3', 'AB8']}
# {'current_day': 9, 'current_airport': 'AB4', 'remaining_zones': ['1'], 'visited_zones': ['0', '2', '5', '9', '6', '7', '3', '8', '4'], 'total_cost': 14914, 'path': ['AB0', 'AB2', 'AB5', 'AB9', 'AB6', 'AB7', 'AB3', 'AB8', 'AB4']}
# 19314
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8'], 'total_cost': 283, 'path': ['AB0', 'AB8']}
# {'current_day': 3, 'current_airport': 'AB5', 'remaining_zones': ['1', '2', '3', '4', '6', '7', '9'], 'visited_zones': ['0', '8', '5'], 'total_cost': 4421, 'path': ['AB0', 'AB8', 'AB5']}
# {'current_day': 4, 'current_airport': 'AB1', 'remaining_zones': ['2', '3', '4', '6', '7', '9'], 'visited_zones': ['0', '8', '5', '1'], 'total_cost': 4652, 'path': ['AB0', 'AB8', 'AB5', 'AB1']}
# {'current_day': 5, 'current_airport': 'AB7', 'remaining_zones': ['2', '3', '4', '6', '9'], 'visited_zones': ['0', '8', '5', '1', '7'], 'total_cost': 4776, 'path': ['AB0', 'AB8', 'AB5', 'AB1', 'AB7']}
# {'current_day': 6, 'current_airport': 'AB6', 'remaining_zones': ['2', '3', '4', '9'], 'visited_zones': ['0', '8', '5', '1', '7', '6'], 'total_cost': 6048, 'path': ['AB0', 'AB8', 'AB5', 'AB1', 'AB7', 'AB6']}
# {'current_day': 7, 'current_airport': 'AB9', 'remaining_zones': ['2', '3', '4'], 'visited_zones': ['0', '8', '5', '1', '7', '6', '9'], 'total_cost': 10872, 'path': ['AB0', 'AB8', 'AB5', 'AB1', 'AB7', 'AB6', 'AB9']}
# {'current_day': 8, 'current_airport': 'AB4', 'remaining_zones': ['2', '3'], 'visited_zones': ['0', '8', '5', '1', '7', '6', '9', '4'], 'total_cost': 11069, 'path': ['AB0', 'AB8', 'AB5', 'AB1', 'AB7', 'AB6', 'AB9', 'AB4']}
# {'current_day': 9, 'current_airport': 'AB2', 'remaining_zones': ['3'], 'visited_zones': ['0', '8', '5', '1', '7', '6', '9', '4', '2'], 'total_cost': 15153, 'path': ['AB0', 'AB8', 'AB5', 'AB1', 'AB7', 'AB6', 'AB9', 'AB4', 'AB2']}
# 21018
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB4', 'remaining_zones': ['1', '2', '3', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '4'], 'total_cost': 2127, 'path': ['AB0', 'AB4']}
# {'current_day': 3, 'current_airport': 'AB9', 'remaining_zones': ['1', '2', '3', '5', '6', '7', '8'], 'visited_zones': ['0', '4', '9'], 'total_cost': 2315, 'path': ['AB0', 'AB4', 'AB9']}
# {'current_day': 4, 'current_airport': 'AB6', 'remaining_zones': ['1', '2', '3', '5', '7', '8'], 'visited_zones': ['0', '4', '9', '6'], 'total_cost': 6961, 'path': ['AB0', 'AB4', 'AB9', 'AB6']}
# {'current_day': 5, 'current_airport': 'AB5', 'remaining_zones': ['1', '2', '3', '7', '8'], 'visited_zones': ['0', '4', '9', '6', '5'], 'total_cost': 11702, 'path': ['AB0', 'AB4', 'AB9', 'AB6', 'AB5']}
# {'current_day': 6, 'current_airport': 'AB1', 'remaining_zones': ['2', '3', '7', '8'], 'visited_zones': ['0', '4', '9', '6', '5', '1'], 'total_cost': 11996, 'path': ['AB0', 'AB4', 'AB9', 'AB6', 'AB5', 'AB1']}
# {'current_day': 7, 'current_airport': 'AB3', 'remaining_zones': ['2', '7', '8'], 'visited_zones': ['0', '4', '9', '6', '5', '1', '3'], 'total_cost': 15285, 'path': ['AB0', 'AB4', 'AB9', 'AB6', 'AB5', 'AB1', 'AB3']}
# {'current_day': 8, 'current_airport': 'AB2', 'remaining_zones': ['7', '8'], 'visited_zones': ['0', '4', '9', '6', '5', '1', '3', '2'], 'total_cost': 17455, 'path': ['AB0', 'AB4', 'AB9', 'AB6', 'AB5', 'AB1', 'AB3', 'AB2']}
# {'current_day': 9, 'current_airport': 'AB7', 'remaining_zones': ['8'], 'visited_zones': ['0', '4', '9', '6', '5', '1', '3', '2', '7'], 'total_cost': 17700, 'path': ['AB0', 'AB4', 'AB9', 'AB6', 'AB5', 'AB1', 'AB3', 'AB2', 'AB7']}
# 19580
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB4', 'remaining_zones': ['1', '2', '3', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '4'], 'total_cost': 2127, 'path': ['AB0', 'AB4']}
# {'current_day': 3, 'current_airport': 'AB6', 'remaining_zones': ['1', '2', '3', '5', '7', '8', '9'], 'visited_zones': ['0', '4', '6'], 'total_cost': 2367, 'path': ['AB0', 'AB4', 'AB6']}
# {'current_day': 4, 'current_airport': 'AB5', 'remaining_zones': ['1', '2', '3', '7', '8', '9'], 'visited_zones': ['0', '4', '6', '5'], 'total_cost': 6506, 'path': ['AB0', 'AB4', 'AB6', 'AB5']}
# {'current_day': 5, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '7', '8', '9'], 'visited_zones': ['0', '4', '6', '5', '2'], 'total_cost': 6740, 'path': ['AB0', 'AB4', 'AB6', 'AB5', 'AB2']}
# {'current_day': 6, 'current_airport': 'AB7', 'remaining_zones': ['1', '3', '8', '9'], 'visited_zones': ['0', '4', '6', '5', '2', '7'], 'total_cost': 7016, 'path': ['AB0', 'AB4', 'AB6', 'AB5', 'AB2', 'AB7']}
# {'current_day': 7, 'current_airport': 'AB1', 'remaining_zones': ['3', '8', '9'], 'visited_zones': ['0', '4', '6', '5', '2', '7', '1'], 'total_cost': 7145, 'path': ['AB0', 'AB4', 'AB6', 'AB5', 'AB2', 'AB7', 'AB1']}
# {'current_day': 8, 'current_airport': 'AB9', 'remaining_zones': ['3', '8'], 'visited_zones': ['0', '4', '6', '5', '2', '7', '1', '9'], 'total_cost': 7304, 'path': ['AB0', 'AB4', 'AB6', 'AB5', 'AB2', 'AB7', 'AB1', 'AB9']}
# {'current_day': 9, 'current_airport': 'AB8', 'remaining_zones': ['3'], 'visited_zones': ['0', '4', '6', '5', '2', '7', '1', '9', '8'], 'total_cost': 9937, 'path': ['AB0', 'AB4', 'AB6', 'AB5', 'AB2', 'AB7', 'AB1', 'AB9', 'AB8']}
# 10236
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB5', 'remaining_zones': ['1', '2', '3', '4', '6', '7', '8', '9'], 'visited_zones': ['0', '5'], 'total_cost': 173, 'path': ['AB0', 'AB5']}
# {'current_day': 3, 'current_airport': 'AB6', 'remaining_zones': ['1', '2', '3', '4', '7', '8', '9'], 'visited_zones': ['0', '5', '6'], 'total_cost': 4971, 'path': ['AB0', 'AB5', 'AB6']}
# {'current_day': 4, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '4', '7', '8', '9'], 'visited_zones': ['0', '5', '6', '2'], 'total_cost': 5183, 'path': ['AB0', 'AB5', 'AB6', 'AB2']}
# {'current_day': 5, 'current_airport': 'AB9', 'remaining_zones': ['1', '3', '4', '7', '8'], 'visited_zones': ['0', '5', '6', '2', '9'], 'total_cost': 5345, 'path': ['AB0', 'AB5', 'AB6', 'AB2', 'AB9']}
# {'current_day': 6, 'current_airport': 'AB7', 'remaining_zones': ['1', '3', '4', '8'], 'visited_zones': ['0', '5', '6', '2', '9', '7'], 'total_cost': 9089, 'path': ['AB0', 'AB5', 'AB6', 'AB2', 'AB9', 'AB7']}
# {'current_day': 7, 'current_airport': 'AB3', 'remaining_zones': ['1', '4', '8'], 'visited_zones': ['0', '5', '6', '2', '9', '7', '3'], 'total_cost': 9303, 'path': ['AB0', 'AB5', 'AB6', 'AB2', 'AB9', 'AB7', 'AB3']}
# {'current_day': 8, 'current_airport': 'AB4', 'remaining_zones': ['1', '8'], 'visited_zones': ['0', '5', '6', '2', '9', '7', '3', '4'], 'total_cost': 12460, 'path': ['AB0', 'AB5', 'AB6', 'AB2', 'AB9', 'AB7', 'AB3', 'AB4']}
# {'current_day': 9, 'current_airport': 'AB8', 'remaining_zones': ['1'], 'visited_zones': ['0', '5', '6', '2', '9', '7', '3', '4', '8'], 'total_cost': 12627, 'path': ['AB0', 'AB5', 'AB6', 'AB2', 'AB9', 'AB7', 'AB3', 'AB4', 'AB8']}
# 12897
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '2'], 'total_cost': 3619, 'path': ['AB0', 'AB2']}
# {'current_day': 3, 'current_airport': 'AB8', 'remaining_zones': ['1', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '2', '8'], 'total_cost': 3829, 'path': ['AB0', 'AB2', 'AB8']}
# {'current_day': 4, 'current_airport': 'AB1', 'remaining_zones': ['3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '2', '8', '1'], 'total_cost': 4016, 'path': ['AB0', 'AB2', 'AB8', 'AB1']}
# {'current_day': 5, 'current_airport': 'AB7', 'remaining_zones': ['3', '4', '5', '6', '9'], 'visited_zones': ['0', '2', '8', '1', '7'], 'total_cost': 4140, 'path': ['AB0', 'AB2', 'AB8', 'AB1', 'AB7']}
# {'current_day': 6, 'current_airport': 'AB6', 'remaining_zones': ['3', '4', '5', '9'], 'visited_zones': ['0', '2', '8', '1', '7', '6'], 'total_cost': 5412, 'path': ['AB0', 'AB2', 'AB8', 'AB1', 'AB7', 'AB6']}
# {'current_day': 7, 'current_airport': 'AB9', 'remaining_zones': ['3', '4', '5'], 'visited_zones': ['0', '2', '8', '1', '7', '6', '9'], 'total_cost': 10236, 'path': ['AB0', 'AB2', 'AB8', 'AB1', 'AB7', 'AB6', 'AB9']}
# {'current_day': 8, 'current_airport': 'AB4', 'remaining_zones': ['3', '5'], 'visited_zones': ['0', '2', '8', '1', '7', '6', '9', '4'], 'total_cost': 10433, 'path': ['AB0', 'AB2', 'AB8', 'AB1', 'AB7', 'AB6', 'AB9', 'AB4']}
# {'current_day': 9, 'current_airport': 'AB5', 'remaining_zones': ['3'], 'visited_zones': ['0', '2', '8', '1', '7', '6', '9', '4', '5'], 'total_cost': 10591, 'path': ['AB0', 'AB2', 'AB8', 'AB1', 'AB7', 'AB6', 'AB9', 'AB4', 'AB5']}
# 10800
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB5', 'remaining_zones': ['1', '2', '3', '4', '6', '7', '8', '9'], 'visited_zones': ['0', '5'], 'total_cost': 173, 'path': ['AB0', 'AB5']}
# {'current_day': 3, 'current_airport': 'AB1', 'remaining_zones': ['2', '3', '4', '6', '7', '8', '9'], 'visited_zones': ['0', '5', '1'], 'total_cost': 448, 'path': ['AB0', 'AB5', 'AB1']}
# {'current_day': 4, 'current_airport': 'AB9', 'remaining_zones': ['2', '3', '4', '6', '7', '8'], 'visited_zones': ['0', '5', '1', '9'], 'total_cost': 739, 'path': ['AB0', 'AB5', 'AB1', 'AB9']}
# {'current_day': 5, 'current_airport': 'AB4', 'remaining_zones': ['2', '3', '6', '7', '8'], 'visited_zones': ['0', '5', '1', '9', '4'], 'total_cost': 946, 'path': ['AB0', 'AB5', 'AB1', 'AB9', 'AB4']}
# {'current_day': 6, 'current_airport': 'AB6', 'remaining_zones': ['2', '3', '7', '8'], 'visited_zones': ['0', '5', '1', '9', '4', '6'], 'total_cost': 1129, 'path': ['AB0', 'AB5', 'AB1', 'AB9', 'AB4', 'AB6']}
# {'current_day': 7, 'current_airport': 'AB2', 'remaining_zones': ['3', '7', '8'], 'visited_zones': ['0', '5', '1', '9', '4', '6', '2'], 'total_cost': 1235, 'path': ['AB0', 'AB5', 'AB1', 'AB9', 'AB4', 'AB6', 'AB2']}
# {'current_day': 8, 'current_airport': 'AB3', 'remaining_zones': ['7', '8'], 'visited_zones': ['0', '5', '1', '9', '4', '6', '2', '3'], 'total_cost': 5935, 'path': ['AB0', 'AB5', 'AB1', 'AB9', 'AB4', 'AB6', 'AB2', 'AB3']}
# {'current_day': 9, 'current_airport': 'AB8', 'remaining_zones': ['7'], 'visited_zones': ['0', '5', '1', '9', '4', '6', '2', '3', '8'], 'total_cost': 6091, 'path': ['AB0', 'AB5', 'AB1', 'AB9', 'AB4', 'AB6', 'AB2', 'AB3', 'AB8']}
# 9065
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB1', 'remaining_zones': ['2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '1'], 'total_cost': 1, 'path': ['AB0', 'AB1']}
# {'current_day': 3, 'current_airport': 'AB9', 'remaining_zones': ['2', '3', '4', '5', '6', '7', '8'], 'visited_zones': ['0', '1', '9'], 'total_cost': 144, 'path': ['AB0', 'AB1', 'AB9']}
# {'current_day': 4, 'current_airport': 'AB6', 'remaining_zones': ['2', '3', '4', '5', '7', '8'], 'visited_zones': ['0', '1', '9', '6'], 'total_cost': 4790, 'path': ['AB0', 'AB1', 'AB9', 'AB6']}
# {'current_day': 5, 'current_airport': 'AB5', 'remaining_zones': ['2', '3', '4', '7', '8'], 'visited_zones': ['0', '1', '9', '6', '5'], 'total_cost': 9531, 'path': ['AB0', 'AB1', 'AB9', 'AB6', 'AB5']}
# {'current_day': 6, 'current_airport': 'AB2', 'remaining_zones': ['3', '4', '7', '8'], 'visited_zones': ['0', '1', '9', '6', '5', '2'], 'total_cost': 9763, 'path': ['AB0', 'AB1', 'AB9', 'AB6', 'AB5', 'AB2']}
# {'current_day': 7, 'current_airport': 'AB3', 'remaining_zones': ['4', '7', '8'], 'visited_zones': ['0', '1', '9', '6', '5', '2', '3'], 'total_cost': 13560, 'path': ['AB0', 'AB1', 'AB9', 'AB6', 'AB5', 'AB2', 'AB3']}
# {'current_day': 8, 'current_airport': 'AB7', 'remaining_zones': ['4', '8'], 'visited_zones': ['0', '1', '9', '6', '5', '2', '3', '7'], 'total_cost': 13804, 'path': ['AB0', 'AB1', 'AB9', 'AB6', 'AB5', 'AB2', 'AB3', 'AB7']}
# {'current_day': 9, 'current_airport': 'AB8', 'remaining_zones': ['4'], 'visited_zones': ['0', '1', '9', '6', '5', '2', '3', '7', '8'], 'total_cost': 19789, 'path': ['AB0', 'AB1', 'AB9', 'AB6', 'AB5', 'AB2', 'AB3', 'AB7', 'AB8']}
# 19938
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB3', 'remaining_zones': ['1', '2', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '3'], 'total_cost': 4618, 'path': ['AB0', 'AB3']}
# {'current_day': 3, 'current_airport': 'AB9', 'remaining_zones': ['1', '2', '4', '5', '6', '7', '8'], 'visited_zones': ['0', '3', '9'], 'total_cost': 4900, 'path': ['AB0', 'AB3', 'AB9']}
# {'current_day': 4, 'current_airport': 'AB5', 'remaining_zones': ['1', '2', '4', '6', '7', '8'], 'visited_zones': ['0', '3', '9', '5'], 'total_cost': 9697, 'path': ['AB0', 'AB3', 'AB9', 'AB5']}
# {'current_day': 5, 'current_airport': 'AB7', 'remaining_zones': ['1', '2', '4', '6', '8'], 'visited_zones': ['0', '3', '9', '5', '7'], 'total_cost': 15350, 'path': ['AB0', 'AB3', 'AB9', 'AB5', 'AB7']}
# {'current_day': 6, 'current_airport': 'AB2', 'remaining_zones': ['1', '4', '6', '8'], 'visited_zones': ['0', '3', '9', '5', '7', '2'], 'total_cost': 15476, 'path': ['AB0', 'AB3', 'AB9', 'AB5', 'AB7', 'AB2']}
# {'current_day': 7, 'current_airport': 'AB6', 'remaining_zones': ['1', '4', '8'], 'visited_zones': ['0', '3', '9', '5', '7', '2', '6'], 'total_cost': 15770, 'path': ['AB0', 'AB3', 'AB9', 'AB5', 'AB7', 'AB2', 'AB6']}
# {'current_day': 8, 'current_airport': 'AB4', 'remaining_zones': ['1', '8'], 'visited_zones': ['0', '3', '9', '5', '7', '2', '6', '4'], 'total_cost': 16038, 'path': ['AB0', 'AB3', 'AB9', 'AB5', 'AB7', 'AB2', 'AB6', 'AB4']}
# {'current_day': 9, 'current_airport': 'AB1', 'remaining_zones': ['8'], 'visited_zones': ['0', '3', '9', '5', '7', '2', '6', '4', '1'], 'total_cost': 21336, 'path': ['AB0', 'AB3', 'AB9', 'AB5', 'AB7', 'AB2', 'AB6', 'AB4', 'AB1']}
# 21595
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB5', 'remaining_zones': ['1', '2', '3', '4', '6', '7', '8', '9'], 'visited_zones': ['0', '5'], 'total_cost': 173, 'path': ['AB0', 'AB5']}
# {'current_day': 3, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '3', '4', '6', '7', '9'], 'visited_zones': ['0', '5', '8'], 'total_cost': 2503, 'path': ['AB0', 'AB5', 'AB8']}
# {'current_day': 4, 'current_airport': 'AB9', 'remaining_zones': ['1', '2', '3', '4', '6', '7'], 'visited_zones': ['0', '5', '8', '9'], 'total_cost': 7256, 'path': ['AB0', 'AB5', 'AB8', 'AB9']}
# {'current_day': 5, 'current_airport': 'AB4', 'remaining_zones': ['1', '2', '3', '6', '7'], 'visited_zones': ['0', '5', '8', '9', '4'], 'total_cost': 7463, 'path': ['AB0', 'AB5', 'AB8', 'AB9', 'AB4']}
# {'current_day': 6, 'current_airport': 'AB3', 'remaining_zones': ['1', '2', '6', '7'], 'visited_zones': ['0', '5', '8', '9', '4', '3'], 'total_cost': 8757, 'path': ['AB0', 'AB5', 'AB8', 'AB9', 'AB4', 'AB3']}
# {'current_day': 7, 'current_airport': 'AB1', 'remaining_zones': ['2', '6', '7'], 'visited_zones': ['0', '5', '8', '9', '4', '3', '1'], 'total_cost': 10966, 'path': ['AB0', 'AB5', 'AB8', 'AB9', 'AB4', 'AB3', 'AB1']}
# {'current_day': 8, 'current_airport': 'AB7', 'remaining_zones': ['2', '6'], 'visited_zones': ['0', '5', '8', '9', '4', '3', '1', '7'], 'total_cost': 11210, 'path': ['AB0', 'AB5', 'AB8', 'AB9', 'AB4', 'AB3', 'AB1', 'AB7']}
# {'current_day': 9, 'current_airport': 'AB6', 'remaining_zones': ['2'], 'visited_zones': ['0', '5', '8', '9', '4', '3', '1', '7', '6'], 'total_cost': 12786, 'path': ['AB0', 'AB5', 'AB8', 'AB9', 'AB4', 'AB3', 'AB1', 'AB7', 'AB6']}
# 12949
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB7', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '8', '9'], 'visited_zones': ['0', '7'], 'total_cost': 192, 'path': ['AB0', 'AB7']}
# {'current_day': 3, 'current_airport': 'AB4', 'remaining_zones': ['1', '2', '3', '5', '6', '8', '9'], 'visited_zones': ['0', '7', '4'], 'total_cost': 329, 'path': ['AB0', 'AB7', 'AB4']}
# {'current_day': 4, 'current_airport': 'AB5', 'remaining_zones': ['1', '2', '3', '6', '8', '9'], 'visited_zones': ['0', '7', '4', '5'], 'total_cost': 454, 'path': ['AB0', 'AB7', 'AB4', 'AB5']}
# {'current_day': 5, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '3', '6', '9'], 'visited_zones': ['0', '7', '4', '5', '8'], 'total_cost': 3658, 'path': ['AB0', 'AB7', 'AB4', 'AB5', 'AB8']}
# {'current_day': 6, 'current_airport': 'AB1', 'remaining_zones': ['2', '3', '6', '9'], 'visited_zones': ['0', '7', '4', '5', '8', '1'], 'total_cost': 3799, 'path': ['AB0', 'AB7', 'AB4', 'AB5', 'AB8', 'AB1']}
# {'current_day': 7, 'current_airport': 'AB2', 'remaining_zones': ['3', '6', '9'], 'visited_zones': ['0', '7', '4', '5', '8', '1', '2'], 'total_cost': 8006, 'path': ['AB0', 'AB7', 'AB4', 'AB5', 'AB8', 'AB1', 'AB2']}
# {'current_day': 8, 'current_airport': 'AB6', 'remaining_zones': ['3', '9'], 'visited_zones': ['0', '7', '4', '5', '8', '1', '2', '6'], 'total_cost': 8302, 'path': ['AB0', 'AB7', 'AB4', 'AB5', 'AB8', 'AB1', 'AB2', 'AB6']}
# {'current_day': 9, 'current_airport': 'AB9', 'remaining_zones': ['3'], 'visited_zones': ['0', '7', '4', '5', '8', '1', '2', '6', '9'], 'total_cost': 13818, 'path': ['AB0', 'AB7', 'AB4', 'AB5', 'AB8', 'AB1', 'AB2', 'AB6', 'AB9']}
# 13972
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB4', 'remaining_zones': ['1', '2', '3', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '4'], 'total_cost': 2127, 'path': ['AB0', 'AB4']}
# {'current_day': 3, 'current_airport': 'AB7', 'remaining_zones': ['1', '2', '3', '5', '6', '8', '9'], 'visited_zones': ['0', '4', '7'], 'total_cost': 2309, 'path': ['AB0', 'AB4', 'AB7']}
# {'current_day': 4, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '3', '5', '6', '9'], 'visited_zones': ['0', '4', '7', '8'], 'total_cost': 8235, 'path': ['AB0', 'AB4', 'AB7', 'AB8']}
# {'current_day': 5, 'current_airport': 'AB3', 'remaining_zones': ['1', '2', '5', '6', '9'], 'visited_zones': ['0', '4', '7', '8', '3'], 'total_cost': 8376, 'path': ['AB0', 'AB4', 'AB7', 'AB8', 'AB3']}
# ...
# {'current_day': 4, 'current_airport': 'AB4', 'remaining_zones': ['1', '3', '5', '7', '8', '9'], 'visited_zones': ['0', '6', '2', '4'], 'total_cost': 5089, 'path': ['AB0', 'AB6', 'AB2', 'AB4']}
# {'current_day': 5, 'current_airport': 'AB7', 'remaining_zones': ['1', '3', '5', '8', '9'], 'visited_zones': ['0', '6', '2', '4', '7'], 'total_cost': 5314, 'path': ['AB0', 'AB6', 'AB2', 'AB4', 'AB7']}
# {'current_day': 6, 'current_airport': 'AB1', 'remaining_zones': ['3', '5', '8', '9'], 'visited_zones': ['0', '6', '2', '4', '7', '1'], 'total_cost': 5589, 'path': ['AB0', 'AB6', 'AB2', 'AB4', 'AB7', 'AB1']}
# {'current_day': 7, 'current_airport': 'AB8', 'remaining_zones': ['3', '5', '9'], 'visited_zones': ['0', '6', '2', '4', '7', '1', '8'], 'total_cost': 5690, 'path': ['AB0', 'AB6', 'AB2', 'AB4', 'AB7', 'AB1', 'AB8']}
# {'current_day': 8, 'current_airport': 'AB5', 'remaining_zones': ['3', '9'], 'visited_zones': ['0', '6', '2', '4', '7', '1', '8', '5'], 'total_cost': 8254, 'path': ['AB0', 'AB6', 'AB2', 'AB4', 'AB7', 'AB1', 'AB8', 'AB5']}
# {'current_day': 9, 'current_airport': 'AB9', 'remaining_zones': ['3'], 'visited_zones': ['0', '6', '2', '4', '7', '1', '8', '5', '9'], 'total_cost': 9845, 'path': ['AB0', 'AB6', 'AB2', 'AB4', 'AB7', 'AB1', 'AB8', 'AB5', 'AB9']}
# 9999
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB9', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8'], 'visited_zones': ['0', '9'], 'total_cost': 103, 'path': ['AB0', 'AB9']}
# {'current_day': 3, 'current_airport': 'AB1', 'remaining_zones': ['2', '3', '4', '5', '6', '7', '8'], 'visited_zones': ['0', '9', '1'], 'total_cost': 302, 'path': ['AB0', 'AB9', 'AB1']}
# {'current_day': 4, 'current_airport': 'AB4', 'remaining_zones': ['2', '3', '5', '6', '7', '8'], 'visited_zones': ['0', '9', '1', '4'], 'total_cost': 2786, 'path': ['AB0', 'AB9', 'AB1', 'AB4']}
# {'current_day': 5, 'current_airport': 'AB2', 'remaining_zones': ['3', '5', '6', '7', '8'], 'visited_zones': ['0', '9', '1', '4', '2'], 'total_cost': 8531, 'path': ['AB0', 'AB9', 'AB1', 'AB4', 'AB2']}
# {'current_day': 6, 'current_airport': 'AB8', 'remaining_zones': ['3', '5', '6', '7'], 'visited_zones': ['0', '9', '1', '4', '2', '8'], 'total_cost': 8772, 'path': ['AB0', 'AB9', 'AB1', 'AB4', 'AB2', 'AB8']}
# {'current_day': 7, 'current_airport': 'AB6', 'remaining_zones': ['3', '5', '7'], 'visited_zones': ['0', '9', '1', '4', '2', '8', '6'], 'total_cost': 10944, 'path': ['AB0', 'AB9', 'AB1', 'AB4', 'AB2', 'AB8', 'AB6']}
# {'current_day': 8, 'current_airport': 'AB3', 'remaining_zones': ['5', '7'], 'visited_zones': ['0', '9', '1', '4', '2', '8', '6', '3'], 'total_cost': 11179, 'path': ['AB0', 'AB9', 'AB1', 'AB4', 'AB2', 'AB8', 'AB6', 'AB3']}
# {'current_day': 9, 'current_airport': 'AB5', 'remaining_zones': ['7'], 'visited_zones': ['0', '9', '1', '4', '2', '8', '6', '3', '5'], 'total_cost': 11317, 'path': ['AB0', 'AB9', 'AB1', 'AB4', 'AB2', 'AB8', 'AB6', 'AB3', 'AB5']}
# 15793
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8'], 'total_cost': 283, 'path': ['AB0', 'AB8']}
# {'current_day': 3, 'current_airport': 'AB3', 'remaining_zones': ['1', '2', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '3'], 'total_cost': 406, 'path': ['AB0', 'AB8', 'AB3']}
# {'current_day': 4, 'current_airport': 'AB4', 'remaining_zones': ['1', '2', '5', '6', '7', '9'], 'visited_zones': ['0', '8', '3', '4'], 'total_cost': 4573, 'path': ['AB0', 'AB8', 'AB3', 'AB4']}
# {'current_day': 5, 'current_airport': 'AB9', 'remaining_zones': ['1', '2', '5', '6', '7'], 'visited_zones': ['0', '8', '3', '4', '9'], 'total_cost': 4677, 'path': ['AB0', 'AB8', 'AB3', 'AB4', 'AB9']}
# {'current_day': 6, 'current_airport': 'AB6', 'remaining_zones': ['1', '2', '5', '7'], 'visited_zones': ['0', '8', '3', '4', '9', '6'], 'total_cost': 7183, 'path': ['AB0', 'AB8', 'AB3', 'AB4', 'AB9', 'AB6']}
# {'current_day': 7, 'current_airport': 'AB1', 'remaining_zones': ['2', '5', '7'], 'visited_zones': ['0', '8', '3', '4', '9', '6', '1'], 'total_cost': 7325, 'path': ['AB0', 'AB8', 'AB3', 'AB4', 'AB9', 'AB6', 'AB1']}
# {'current_day': 8, 'current_airport': 'AB5', 'remaining_zones': ['2', '7'], 'visited_zones': ['0', '8', '3', '4', '9', '6', '1', '5'], 'total_cost': 7609, 'path': ['AB0', 'AB8', 'AB3', 'AB4', 'AB9', 'AB6', 'AB1', 'AB5']}
# {'current_day': 9, 'current_airport': 'AB2', 'remaining_zones': ['7'], 'visited_zones': ['0', '8', '3', '4', '9', '6', '1', '5', '2'], 'total_cost': 7871, 'path': ['AB0', 'AB8', 'AB3', 'AB4', 'AB9', 'AB6', 'AB1', 'AB5', 'AB2']}
# 8068
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB5', 'remaining_zones': ['1', '2', '3', '4', '6', '7', '8', '9'], 'visited_zones': ['0', '5'], 'total_cost': 173, 'path': ['AB0', 'AB5']}
# {'current_day': 3, 'current_airport': 'AB7', 'remaining_zones': ['1', '2', '3', '4', '6', '8', '9'], 'visited_zones': ['0', '5', '7'], 'total_cost': 2643, 'path': ['AB0', 'AB5', 'AB7']}
# {'current_day': 4, 'current_airport': 'AB4', 'remaining_zones': ['1', '2', '3', '6', '8', '9'], 'visited_zones': ['0', '5', '7', '4'], 'total_cost': 2911, 'path': ['AB0', 'AB5', 'AB7', 'AB4']}
# {'current_day': 5, 'current_airport': 'AB6', 'remaining_zones': ['1', '2', '3', '8', '9'], 'visited_zones': ['0', '5', '7', '4', '6'], 'total_cost': 3084, 'path': ['AB0', 'AB5', 'AB7', 'AB4', 'AB6']}
# {'current_day': 6, 'current_airport': 'AB9', 'remaining_zones': ['1', '2', '3', '8'], 'visited_zones': ['0', '5', '7', '4', '6', '9'], 'total_cost': 8339, 'path': ['AB0', 'AB5', 'AB7', 'AB4', 'AB6', 'AB9']}
# {'current_day': 7, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '8'], 'visited_zones': ['0', '5', '7', '4', '6', '9', '2'], 'total_cost': 8484, 'path': ['AB0', 'AB5', 'AB7', 'AB4', 'AB6', 'AB9', 'AB2']}
# {'current_day': 8, 'current_airport': 'AB8', 'remaining_zones': ['1', '3'], 'visited_zones': ['0', '5', '7', '4', '6', '9', '2', '8'], 'total_cost': 8651, 'path': ['AB0', 'AB5', 'AB7', 'AB4', 'AB6', 'AB9', 'AB2', 'AB8']}
# {'current_day': 9, 'current_airport': 'AB3', 'remaining_zones': ['1'], 'visited_zones': ['0', '5', '7', '4', '6', '9', '2', '8', '3'], 'total_cost': 8760, 'path': ['AB0', 'AB5', 'AB7', 'AB4', 'AB6', 'AB9', 'AB2', 'AB8', 'AB3']}
# 12489
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB6', 'remaining_zones': ['1', '2', '3', '4', '5', '7', '8', '9'], 'visited_zones': ['0', '6'], 'total_cost': 179, 'path': ['AB0', 'AB6']}
# {'current_day': 3, 'current_airport': 'AB3', 'remaining_zones': ['1', '2', '4', '5', '7', '8', '9'], 'visited_zones': ['0', '6', '3'], 'total_cost': 305, 'path': ['AB0', 'AB6', 'AB3']}
# {'current_day': 4, 'current_airport': 'AB4', 'remaining_zones': ['1', '2', '5', '7', '8', '9'], 'visited_zones': ['0', '6', '3', '4'], 'total_cost': 4472, 'path': ['AB0', 'AB6', 'AB3', 'AB4']}
# {'current_day': 5, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '5', '7', '9'], 'visited_zones': ['0', '6', '3', '4', '8'], 'total_cost': 4751, 'path': ['AB0', 'AB6', 'AB3', 'AB4', 'AB8']}
# {'current_day': 6, 'current_airport': 'AB9', 'remaining_zones': ['1', '2', '5', '7'], 'visited_zones': ['0', '6', '3', '4', '8', '9'], 'total_cost': 6529, 'path': ['AB0', 'AB6', 'AB3', 'AB4', 'AB8', 'AB9']}
# {'current_day': 7, 'current_airport': 'AB5', 'remaining_zones': ['1', '2', '7'], 'visited_zones': ['0', '6', '3', '4', '8', '9', '5'], 'total_cost': 8497, 'path': ['AB0', 'AB6', 'AB3', 'AB4', 'AB8', 'AB9', 'AB5']}
# {'current_day': 8, 'current_airport': 'AB7', 'remaining_zones': ['1', '2'], 'visited_zones': ['0', '6', '3', '4', '8', '9', '5', '7'], 'total_cost': 13954, 'path': ['AB0', 'AB6', 'AB3', 'AB4', 'AB8', 'AB9', 'AB5', 'AB7']}
# {'current_day': 9, 'current_airport': 'AB1', 'remaining_zones': ['2'], 'visited_zones': ['0', '6', '3', '4', '8', '9', '5', '7', '1'], 'total_cost': 14097, 'path': ['AB0', 'AB6', 'AB3', 'AB4', 'AB8', 'AB9', 'AB5', 'AB7', 'AB1']}
# 17803
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB4', 'remaining_zones': ['1', '2', '3', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '4'], 'total_cost': 2127, 'path': ['AB0', 'AB4']}
# {'current_day': 3, 'current_airport': 'AB9', 'remaining_zones': ['1', '2', '3', '5', '6', '7', '8'], 'visited_zones': ['0', '4', '9'], 'total_cost': 2315, 'path': ['AB0', 'AB4', 'AB9']}
# {'current_day': 4, 'current_airport': 'AB7', 'remaining_zones': ['1', '2', '3', '5', '6', '8'], 'visited_zones': ['0', '4', '9', '7'], 'total_cost': 3714, 'path': ['AB0', 'AB4', 'AB9', 'AB7']}
# {'current_day': 5, 'current_airport': 'AB5', 'remaining_zones': ['1', '2', '3', '6', '8'], 'visited_zones': ['0', '4', '9', '7', '5'], 'total_cost': 9454, 'path': ['AB0', 'AB4', 'AB9', 'AB7', 'AB5']}
# {'current_day': 6, 'current_airport': 'AB3', 'remaining_zones': ['1', '2', '6', '8'], 'visited_zones': ['0', '4', '9', '7', '5', '3'], 'total_cost': 9689, 'path': ['AB0', 'AB4', 'AB9', 'AB7', 'AB5', 'AB3']}
# {'current_day': 7, 'current_airport': 'AB6', 'remaining_zones': ['1', '2', '8'], 'visited_zones': ['0', '4', '9', '7', '5', '3', '6'], 'total_cost': 9903, 'path': ['AB0', 'AB4', 'AB9', 'AB7', 'AB5', 'AB3', 'AB6']}
# {'current_day': 8, 'current_airport': 'AB2', 'remaining_zones': ['1', '8'], 'visited_zones': ['0', '4', '9', '7', '5', '3', '6', '2'], 'total_cost': 10168, 'path': ['AB0', 'AB4', 'AB9', 'AB7', 'AB5', 'AB3', 'AB6', 'AB2']}
# {'current_day': 9, 'current_airport': 'AB1', 'remaining_zones': ['8'], 'visited_zones': ['0', '4', '9', '7', '5', '3', '6', '2', '1'], 'total_cost': 15935, 'path': ['AB0', 'AB4', 'AB9', 'AB7', 'AB5', 'AB3', 'AB6', 'AB2', 'AB1']}
# 16194
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB3', 'remaining_zones': ['1', '2', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '3'], 'total_cost': 4618, 'path': ['AB0', 'AB3']}
# {'current_day': 3, 'current_airport': 'AB7', 'remaining_zones': ['1', '2', '4', '5', '6', '8', '9'], 'visited_zones': ['0', '3', '7'], 'total_cost': 4826, 'path': ['AB0', 'AB3', 'AB7']}
# {'current_day': 4, 'current_airport': 'AB4', 'remaining_zones': ['1', '2', '5', '6', '8', '9'], 'visited_zones': ['0', '3', '7', '4'], 'total_cost': 5094, 'path': ['AB0', 'AB3', 'AB7', 'AB4']}
# {'current_day': 5, 'current_airport': 'AB5', 'remaining_zones': ['1', '2', '6', '8', '9'], 'visited_zones': ['0', '3', '7', '4', '5'], 'total_cost': 5239, 'path': ['AB0', 'AB3', 'AB7', 'AB4', 'AB5']}
# {'current_day': 6, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '6', '9'], 'visited_zones': ['0', '3', '7', '4', '5', '8'], 'total_cost': 9586, 'path': ['AB0', 'AB3', 'AB7', 'AB4', 'AB5', 'AB8']}
# {'current_day': 7, 'current_airport': 'AB1', 'remaining_zones': ['2', '6', '9'], 'visited_zones': ['0', '3', '7', '4', '5', '8', '1'], 'total_cost': 9764, 'path': ['AB0', 'AB3', 'AB7', 'AB4', 'AB5', 'AB8', 'AB1']}
# {'current_day': 8, 'current_airport': 'AB2', 'remaining_zones': ['6', '9'], 'visited_zones': ['0', '3', '7', '4', '5', '8', '1', '2'], 'total_cost': 15391, 'path': ['AB0', 'AB3', 'AB7', 'AB4', 'AB5', 'AB8', 'AB1', 'AB2']}
# {'current_day': 9, 'current_airport': 'AB9', 'remaining_zones': ['6'], 'visited_zones': ['0', '3', '7', '4', '5', '8', '1', '2', '9'], 'total_cost': 15613, 'path': ['AB0', 'AB3', 'AB7', 'AB4', 'AB5', 'AB8', 'AB1', 'AB2', 'AB9']}
# 17167
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB4', 'remaining_zones': ['1', '2', '3', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '4'], 'total_cost': 2127, 'path': ['AB0', 'AB4']}
# {'current_day': 3, 'current_airport': 'AB1', 'remaining_zones': ['2', '3', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '4', '1'], 'total_cost': 3138, 'path': ['AB0', 'AB4', 'AB1']}
# {'current_day': 4, 'current_airport': 'AB2', 'remaining_zones': ['3', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '4', '1', '2'], 'total_cost': 4257, 'path': ['AB0', 'AB4', 'AB1', 'AB2']}
# {'current_day': 5, 'current_airport': 'AB3', 'remaining_zones': ['5', '6', '7', '8', '9'], 'visited_zones': ['0', '4', '1', '2', '3'], 'total_cost': 7181, 'path': ['AB0', 'AB4', 'AB1', 'AB2', 'AB3']}
# {'current_day': 6, 'current_airport': 'AB6', 'remaining_zones': ['5', '7', '8', '9'], 'visited_zones': ['0', '4', '1', '2', '3', '6'], 'total_cost': 7371, 'path': ['AB0', 'AB4', 'AB1', 'AB2', 'AB3', 'AB6']}
# {'current_day': 7, 'current_airport': 'AB7', 'remaining_zones': ['5', '8', '9'], 'visited_zones': ['0', '4', '1', '2', '3', '6', '7'], 'total_cost': 10471, 'path': ['AB0', 'AB4', 'AB1', 'AB2', 'AB3', 'AB6', 'AB7']}
# {'current_day': 8, 'current_airport': 'AB8', 'remaining_zones': ['5', '9'], 'visited_zones': ['0', '4', '1', '2', '3', '6', '7', '8'], 'total_cost': 13848, 'path': ['AB0', 'AB4', 'AB1', 'AB2', 'AB3', 'AB6', 'AB7', 'AB8']}
# {'current_day': 9, 'current_airport': 'AB9', 'remaining_zones': ['5'], 'visited_zones': ['0', '4', '1', '2', '3', '6', '7', '8', '9'], 'total_cost': 18313, 'path': ['AB0', 'AB4', 'AB1', 'AB2', 'AB3', 'AB6', 'AB7', 'AB8', 'AB9']}
# 19422
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB4', 'remaining_zones': ['1', '2', '3', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '4'], 'total_cost': 2127, 'path': ['AB0', 'AB4']}
# {'current_day': 3, 'current_airport': 'AB3', 'remaining_zones': ['1', '2', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '4', '3'], 'total_cost': 3378, 'path': ['AB0', 'AB4', 'AB3']}
# {'current_day': 4, 'current_airport': 'AB6', 'remaining_zones': ['1', '2', '5', '7', '8', '9'], 'visited_zones': ['0', '4', '3', '6'], 'total_cost': 3658, 'path': ['AB0', 'AB4', 'AB3', 'AB6']}
# {'current_day': 5, 'current_airport': 'AB2', 'remaining_zones': ['1', '5', '7', '8', '9'], 'visited_zones': ['0', '4', '3', '6', '2'], 'total_cost': 3873, 'path': ['AB0', 'AB4', 'AB3', 'AB6', 'AB2']}
# {'current_day': 6, 'current_airport': 'AB1', 'remaining_zones': ['5', '7', '8', '9'], 'visited_zones': ['0', '4', '3', '6', '2', '1'], 'total_cost': 6236, 'path': ['AB0', 'AB4', 'AB3', 'AB6', 'AB2', 'AB1']}
# {'current_day': 7, 'current_airport': 'AB5', 'remaining_zones': ['7', '8', '9'], 'visited_zones': ['0', '4', '3', '6', '2', '1', '5'], 'total_cost': 6452, 'path': ['AB0', 'AB4', 'AB3', 'AB6', 'AB2', 'AB1', 'AB5']}
# {'current_day': 8, 'current_airport': 'AB8', 'remaining_zones': ['7', '9'], 'visited_zones': ['0', '4', '3', '6', '2', '1', '5', '8'], 'total_cost': 11896, 'path': ['AB0', 'AB4', 'AB3', 'AB6', 'AB2', 'AB1', 'AB5', 'AB8']}
# {'current_day': 9, 'current_airport': 'AB7', 'remaining_zones': ['9'], 'visited_zones': ['0', '4', '3', '6', '2', '1', '5', '8', '7'], 'total_cost': 14340, 'path': ['AB0', 'AB4', 'AB3', 'AB6', 'AB2', 'AB1', 'AB5', 'AB8', 'AB7']}
# 18779
# {'current_day': 10, 'current_airport': 'AB9', 'remaining_zones': [], 'visited_zones': ['0', '7', '1', '5', '4', '6', '2', '8', '3', '9'], 'total_cost': 1468, 'path': ['AB0', 'AB7', 'AB1', 'AB5', 'AB4', 'AB6', 'AB2', 'AB8', 'AB3', 'AB9']} 1468

# %% [markdown]
# #### GPT NOT SURE

# %%
class MCTS(data_preprocessing):
    def __init__(self, instance, root_state, iterations):
        super().__init__(instance_path=instance)
        self.root = Node(root_state)
        self.iterations = iterations
        self.best_leaf = None
        self.best_leaf_cost = float('inf')
        
    def expand_node(self, node):
        actions = self.possible_flights_from_an_airport_at_a_specific_day_with_previous_areas(
            node.state['current_day'], node.state['current_airport'], node.state['visited_zones'])

        for action in actions:
            new_state = self.transition_function(node.state, action)
            node.add_child(new_state)
            
    def transition_function(self, state, action):
        new_state = deepcopy(state)  # Deep copy to avoid side effects
        new_state['current_day'] += 1
        new_state['current_airport'] = action[0]
        new_state['total_cost'] += action[1]
        new_state['path'].append(action[0])
        new_state['remaining_zones'].remove(self.associated_area_to_airport(airport=new_state['current_airport']))
        new_state['visited_zones'].append(self.associated_area_to_airport(airport=action[0]))
        return new_state

    def random_policy(self, state):
        actions = self.possible_flights_from_an_airport_at_a_specific_day_with_previous_areas(
            day=state['current_day'], from_airport=state['current_airport'], visited_areas=state['visited_zones']
        )
        return random.choice(actions)
    
    def select(self, node):
        current_node = node
        while current_node.is_fully_expanded() and current_node.children:
            current_node = current_node.best_child()
        return current_node

    def simulate(self, node):
        current_simulation_state = deepcopy(node.state)
        while current_simulation_state['current_day'] != self.number_of_areas:
            action = self.random_policy(current_simulation_state)
            current_simulation_state = self.transition_function(current_simulation_state, action)
            
        if current_simulation_state['total_cost'] < self.best_leaf_cost:
            self.best_leaf = current_simulation_state
            self.best_leaf_cost = current_simulation_state['total_cost']
        
        return current_simulation_state['total_cost']

    def backpropagate(self, node, cost):
        current_node = node
        while current_node is not None:
            current_node.visit_count += 1
            current_node.total_cost += cost
            current_node = current_node.parent

    def search(self):
        for _ in range(self.iterations):
            node_to_explore = self.select(self.root)
            if not node_to_explore.is_fully_expanded():
                self.expand_node(node_to_explore)
            cost = self.simulate(node_to_explore)
            self.backpropagate(node_to_explore, cost)
        
        return self.best_leaf, self.best_leaf_cost

instance_path = 'Flight connections dataset/1.in'
data_processor = data_preprocessing(instance_path=instance_path)

# Define root state
root_state = {
    'current_day': 1,
    'current_airport': data_processor.starting_airport,
    'remaining_zones': [x for x in data_processor.list_areas if x != data_processor.starting_area],  # Exclude the starting area
    'visited_zones': [data_processor.starting_area],  # Exclude the starting area
    'total_cost': 0,
    'path': [data_processor.starting_airport]
}

for k in range(10):
    mcts = MCTS(instance=instance_path, root_state=root_state, iterations=1000)
    # mcts = MCTS(instance=instance, root_state=root_state, iterations=1000)
    best_path, best_cost = mcts.search()
    print(f"Best Path: {best_path}, Best Cost: {best_cost}")
# Out:
# Best Path: {'current_day': 10, 'current_airport': 'AB7', 'remaining_zones': [], 'visited_zones': ['0', '5', '2', '9', '3', '8', '1', '6', '4', '7'], 'total_cost': 1542, 'path': ['AB0', 'AB5', 'AB2', 'AB9', 'AB3', 'AB8', 'AB1', 'AB6', 'AB4', 'AB7']}, Best Cost: 1542
# Best Path: {'current_day': 10, 'current_airport': 'AB7', 'remaining_zones': [], 'visited_zones': ['0', '9', '4', '6', '1', '8', '3', '5', '2', '7'], 'total_cost': 1469, 'path': ['AB0', 'AB9', 'AB4', 'AB6', 'AB1', 'AB8', 'AB3', 'AB5', 'AB2', 'AB7']}, Best Cost: 1469
# Best Path: {'current_day': 10, 'current_airport': 'AB8', 'remaining_zones': [], 'visited_zones': ['0', '5', '4', '7', '1', '6', '2', '9', '3', '8'], 'total_cost': 1490, 'path': ['AB0', 'AB5', 'AB4', 'AB7', 'AB1', 'AB6', 'AB2', 'AB9', 'AB3', 'AB8']}, Best Cost: 1490
# Best Path: {'current_day': 10, 'current_airport': 'AB5', 'remaining_zones': [], 'visited_zones': ['0', '9', '3', '8', '1', '6', '2', '7', '4', '5'], 'total_cost': 1482, 'path': ['AB0', 'AB9', 'AB3', 'AB8', 'AB1', 'AB6', 'AB2', 'AB7', 'AB4', 'AB5']}, Best Cost: 1482
# Best Path: {'current_day': 10, 'current_airport': 'AB9', 'remaining_zones': [], 'visited_zones': ['0', '6', '2', '5', '4', '8', '3', '7', '1', '9'], 'total_cost': 1649, 'path': ['AB0', 'AB6', 'AB2', 'AB5', 'AB4', 'AB8', 'AB3', 'AB7', 'AB1', 'AB9']}, Best Cost: 1649
# Best Path: {'current_day': 10, 'current_airport': 'AB7', 'remaining_zones': [], 'visited_zones': ['0', '5', '3', '9', '1', '6', '4', '8', '2', '7'], 'total_cost': 1419, 'path': ['AB0', 'AB5', 'AB3', 'AB9', 'AB1', 'AB6', 'AB4', 'AB8', 'AB2', 'AB7']}, Best Cost: 1419
# Best Path: {'current_day': 10, 'current_airport': 'AB8', 'remaining_zones': [], 'visited_zones': ['0', '6', '1', '9', '3', '5', '4', '7', '2', '8'], 'total_cost': 1759, 'path': ['AB0', 'AB6', 'AB1', 'AB9', 'AB3', 'AB5', 'AB4', 'AB7', 'AB2', 'AB8']}, Best Cost: 1759
# Best Path: {'current_day': 10, 'current_airport': 'AB9', 'remaining_zones': [], 'visited_zones': ['0', '8', '2', '5', '4', '7', '1', '6', '3', '9'], 'total_cost': 1678, 'path': ['AB0', 'AB8', 'AB2', 'AB5', 'AB4', 'AB7', 'AB1', 'AB6', 'AB3', 'AB9']}, Best Cost: 1678
# Best Path: {'current_day': 10, 'current_airport': 'AB5', 'remaining_zones': [], 'visited_zones': ['0', '6', '3', '8', '2', '7', '1', '9', '4', '5'], 'total_cost': 1630, 'path': ['AB0', 'AB6', 'AB3', 'AB8', 'AB2', 'AB7', 'AB1', 'AB9', 'AB4', 'AB5']}, Best Cost: 1630
# Best Path: {'current_day': 10, 'current_airport': 'AB7', 'remaining_zones': [], 'visited_zones': ['0', '5', '3', '9', '1', '6', '4', '8', '2', '7'], 'total_cost': 1419, 'path': ['AB0', 'AB5', 'AB3', 'AB9', 'AB1', 'AB6', 'AB4', 'AB8', 'AB2', 'AB7']}, Best Cost: 1419

# %%
data_processor.possible_flights_from_an_airport_at_a_specific_day(day=9,
                                                                  from_airport='AB6')
# Out:
# [['AB5', 5854],
#  ['AB7', 2188],
#  ['AB8', 1144],
#  ['AB9', 3763],
#  ['AB0', 172],
#  ['AB1', 292],
#  ['AB2', 163],
#  ['AB3', 128],
#  ['AB4', 155]]

# %% [markdown]
# ### WORK

# %%
class MCTS(data_preprocessing):
    def __init__(self, instance, root_state, iterations):
        super().__init__(instance_path=instance)
        self.root = Node(root_state)
        self.iterations = iterations

    def select_node(self):
        node = self.root
        while node.is_fully_expanded() and node.children:
            node = node.best_child()
        return node

    def expand_node(self, node):
        actions = self.possible_flights_from_an_airport_at_a_specific_day(
            node.state['current_day'], node.state['current_airport']
        )
        print(f'\n\n Available actions at day {node.state["current_day"]}')
        print(actions)

        for action in actions:
            print(action)
            new_state = self.transition_function(node.state, action)
           
            node.add_child(new_state)
            print(new_state)
            
    def run(self):
        for _ in range(self.iterations):
            leaf = self.select_node()
            print('Selected leaf')
            print(leaf.state)
            if not leaf.is_fully_expanded():
                self.expand_node(leaf)
            
            simulation_cost = self.simulate(leaf.state)
            print(simulation_cost)
            self.backpropagate(leaf, simulation_cost)
        return self.get_best_path()

    def transition_function(self, state, action):
        new_state = deepcopy(state)  # Deep copy to avoid side effects
        new_state['current_day'] += 1
        new_state['current_airport'] = action[0]
        new_state['total_cost'] += action[1]
        new_state['path'].append(action[0])
        #print(new_state)
        #print(type(self.associated_area_to_airport(airport=new_state['current_airport'])))
        print(f"Remove {self.associated_area_to_airport(airport=new_state['current_airport'])}")
        new_state['remaining_zones'].remove(self.associated_area_to_airport(airport=new_state['current_airport']))
        #print("New state after transition:", new_state)
        return new_state

    def random_policy(self, state):
        actions = self.possible_flights_from_an_airport_at_a_specific_day(
            state['current_day'], state['current_airport']
        )
        return random.choice(actions)
    
    def simulate(self, state):
        total_cost = state['total_cost']
        current_state = state.copy()
        while current_state['remaining_zones']:
            action = self.random_policy(current_state)
            current_state = self.transition_function(current_state, action)
            total_cost += self.get_cost(
                current_state['current_day'], current_state['current_airport'], action[0]
            )
        return total_cost

    def backpropagate(self, node, simulation_cost):
        while node is not None:
            node.visit_count += 1
            node.total_cost += simulation_cost
            node = node.parent

    def get_best_path(self):
        best_node = self.root.best_child(c_param=0)
        return best_node.state['path'], best_node.total_cost /(pow(10,-10)+best_node.visit_count)

# %%
instance_path = 'Flight connections dataset/1.in'

# Initialize data preprocessing instance
data_processor = data_preprocessing(instance_path=instance_path)

# Define root state
root_state = {
    'current_day': 1,
    'current_airport': data_processor.starting_airport,
    'remaining_zones': [x for x in data_processor.list_areas if x != data_processor.starting_area],  # Exclude the starting area
    'total_cost': 0,
    'path': [data_processor.starting_airport]
}

mcts = MCTS(instance=instance_path, root_state=root_state, iterations=2)
# Run MCTS
best_path, best_cost = mcts.run()
# Out:
# Selected leaf
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'total_cost': 0, 'path': ['AB0']}
#
#
#  Available actions at day 1
# [['AB1', 1], ['AB2', 3619], ['AB3', 4618], ['AB4', 2127], ['AB5', 173], ['AB6', 179], ['AB7', 192], ['AB8', 283], ['AB9', 103]]
# ['AB1', 1]
# Remove 1
# {'current_day': 2, 'current_airport': 'AB1', 'remaining_zones': ['2', '3', '4', '5', '6', '7', '8', '9'], 'total_cost': 1, 'path': ['AB0', 'AB1']}
# ['AB2', 3619]
# Remove 2
# {'current_day': 2, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '4', '5', '6', '7', '8', '9'], 'total_cost': 3619, 'path': ['AB0', 'AB2']}
# ['AB3', 4618]
# Remove 3
# {'current_day': 2, 'current_airport': 'AB3', 'remaining_zones': ['1', '2', '4', '5', '6', '7', '8', '9'], 'total_cost': 4618, 'path': ['AB0', 'AB3']}
# ['AB4', 2127]
# Remove 4
# {'current_day': 2, 'current_airport': 'AB4', 'remaining_zones': ['1', '2', '3', '5', '6', '7', '8', '9'], 'total_cost': 2127, 'path': ['AB0', 'AB4']}
# ['AB5', 173]
# Remove 5
# {'current_day': 2, 'current_airport': 'AB5', 'remaining_zones': ['1', '2', '3', '4', '6', '7', '8', '9'], 'total_cost': 173, 'path': ['AB0', 'AB5']}
# ['AB6', 179]
# Remove 6
# {'current_day': 2, 'current_airport': 'AB6', 'remaining_zones': ['1', '2', '3', '4', '5', '7', '8', '9'], 'total_cost': 179, 'path': ['AB0', 'AB6']}
# ['AB7', 192]
# Remove 7
# {'current_day': 2, 'current_airport': 'AB7', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '8', '9'], 'total_cost': 192, 'path': ['AB0', 'AB7']}
# ['AB8', 283]
# Remove 8
# {'current_day': 2, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '9'], 'total_cost': 283, 'path': ['AB0', 'AB8']}
# ['AB9', 103]
# Remove 9
# {'current_day': 2, 'current_airport': 'AB9', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8'], 'total_cost': 103, 'path': ['AB0', 'AB9']}
# Remove 4
# Remove 6
# Remove 7
# Remove 5
# Remove 7
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2962], line 17
#      15 mcts = MCTS(instance=instance_path, root_state=root_state, iterations=2)
#      16 # Run MCTS
# ---> 17 best_path, best_cost = mcts.run()
#
# Cell In[2961], line 35, in MCTS.run(self)
#      32 if not leaf.is_fully_expanded():
#      33     self.expand_node(leaf)
# ---> 35 simulation_cost = self.simulate(leaf.state)
#      36 print(simulation_cost)
#      37 self.backpropagate(leaf, simulation_cost)
#
# Cell In[2961], line 64, in MCTS.simulate(self, state)
#      62 while current_state['remaining_zones']:
#      63     action = self.random_policy(current_state)
# ---> 64     current_state = self.transition_function(current_state, action)
#      65     total_cost += self.get_cost(
#      66         current_state['current_day'], current_state['current_airport'], action[0]
#      67     )
#      68 return total_cost
#
# Cell In[2961], line 49, in MCTS.transition_function(self, state, action)
#      46 #print(new_state)
#      47 #print(type(self.associated_area_to_airport(airport=new_state['current_airport'])))
#      48 print(f"Remove {self.associated_area_to_airport(airport=new_state['current_airport'])}")
# ---> 49 new_state['remaining_zones'].remove(self.associated_area_to_airport(airport=new_state['current_airport']))
#      50 #print("New state after transition:", new_state)
#      51 return new_state
#
# ValueError: list.remove(x): x not in list
