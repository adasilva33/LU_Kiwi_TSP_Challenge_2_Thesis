# %%
import numpy as np
import random
from copy import deepcopy

# %%
class data_preprocessing:
    def __init__(self,instance_path):
        self.instance_path=instance_path
        
        self.info, self.flights = self.read_file(f_name=self.instance_path)
        self.number_of_areas,self.starting_airport=int(self.info[0][0]),self.info[0][1]
        
        
        self.flights_by_day_dict = self.flights_by_day(flight_list=self.flights)
        
        self.flights_by_day_dict=self.remove_duplicate(flights_by_day=self.flights_by_day_dict)
        
        self.list_days= [k for k in range(1,self.number_of_areas)]
        
        self.airports_by_area = self.get_airports_by_areas()
        self.area_to_explore=self.which_area_to_explore(airports_by_area=self.airports_by_area)
        self.area_by_airport=self.invert_dict(original_dict=self.airports_by_area)
        
        self.starting_area=self.associated_area_to_airport(airport=self.starting_airport)
        self.list_airports=self.get_list_of_airports()
        self.list_areas=list(self.airports_by_area.keys())
        self.areas_connections_by_day=self.possible_flights_from_zone_to_zone_specific_day()
        
    def read_file(self,f_name):
        dist = []
        line_nu = -1
        with open(f_name) as infile:
            for line in infile:
                line_nu += 1
                if line_nu == 0:
                    index = int(line.split()[0]) * 2 + 1
                if line_nu >= index:
                    temp = line.split()
                    temp[2] = int(temp[2])
                    temp[3] = int(temp[3])
                    dist.append(temp)
                else:
                    dist.append(line.split())
            info = dist[:int(dist[0][0])*2+1]
            flights = dist[int(dist[0][0])*2+1:]
        return info, flights
    
    def flights_by_day(self,flight_list):
        # Create an empty dictionary to hold flights organized by day
        flights_by_day = {}

        # Iterate over each flight in the input list
        for flight in flight_list:
            # Extract the day from the flight entry
            day = flight[2]

            # Create a flight entry without the day
            flight_without_day = flight[:2] + flight[3:]

            # Add the flight to the corresponding day in the dictionary
            if day not in flights_by_day:
                flights_by_day[day] = []
            flights_by_day[day].append(flight_without_day)
            
        return flights_by_day
    
    def flights_from_airport(self,flights_by_day, from_airport, considered_day):
        flights_from_airport = []
        for day, flights in flights_by_day.items():
            if day==considered_day:
                for flight in flights:
                    if flight[0] == from_airport:
                        flights_from_airport.append(flight)
                return flights_from_airport
            else:
                return None

    def invert_dict(self,original_dict):
        inverted_dict = {}
        for key, value_list in original_dict.items():
            for value in value_list:
                if value in inverted_dict:
                    inverted_dict[value].append(key)
                else:
                    inverted_dict[value] = key
        return inverted_dict

    def get_cost(self, day, from_airport, to_airport):
        # Retrieve flights for the specified day and day 0
        flights_day = self.flights_by_day_dict.get(day, [])
        flights_day_0 = self.flights_by_day_dict.get(0, [])
        
        # Find the cost for the specified day
        cost_day = next(
            (flight[2]
            for flight in flights_day
            if flight[0] == from_airport and flight[1] == to_airport),
            float('inf')
        )
        
        # Find the cost for day 0
        cost_day_0 = next(
            (flight[2]
            for flight in flights_day_0
            if flight[0] == from_airport and flight[1] == to_airport),
            float('inf')
        )
        
        # Return the minimum cost if either exists, otherwise inf
        if cost_day == float('inf') and cost_day_0 == float('inf'):
            return float('inf')
        
        return min(cost_day, cost_day_0)

    def possible_flights_from_zone_to_zone_specific_day(self):
        areas_connections_by_day = {}

        for day, flights in self.flights_by_day_dict.items():
            areas_connections_list = []

            for flight in flights:
                connection = f"{self.area_by_airport.get(flight[0])} to {self.area_by_airport.get(flight[1])}"
                if connection not in areas_connections_list:
                    areas_connections_list.append(connection)

            areas_connections_by_day[day] = areas_connections_list

        return areas_connections_by_day

    def get_airports_by_areas(self):
        area_num = int(self.info[0][0])
        return {f"{i}": self.info[2+i * 2] for i in range(0, area_num)}
    
    def get_list_of_airports(self):
        unique_airports = set()

        # Iterate through each sublist and add elements to the set
        for sublist in self.airports_by_area.values():
            for airport in sublist:
                unique_airports.add(airport)
        
        return list(unique_airports)
                    
    def associated_area_to_airport(self,airport):
        return next(
            (
                area
                for area, airports in self.airports_by_area.items()
                if airport in airports
            ),
            "Airport not found",
        ) 
    
    def remove_duplicate(self,flights_by_day):
        for day, flights in flights_by_day.items():
            unique_flights = {}
            for flight in flights:
                flight_key = (flight[0], flight[1])
                if flight_key not in unique_flights:
                    unique_flights[flight_key] = flight
                else:
                    if flight[2] < unique_flights[flight_key][2]:
                        #print(flight[2],unique_flights[flight_key][2])
                        unique_flights[flight_key] = flight
                flights_by_day[day] = list(unique_flights.values())
        return flights_by_day
    
    def possible_flights_from_an_airport_at_a_specific_day(self,day,from_airport):
        daily_flights = self.flights_by_day_dict.get(day, [])
        
        flights_from_airport = []
        for flight in daily_flights:
            if flight[0] == from_airport:
                
                flights_from_airport.append([flight[1], flight[2]])

        return flights_from_airport
    
    def possible_flights_from_an_airport_at_a_specific_day_with_previous_areas(self,day,from_airport, visited_areas):
        daily_flights = self.flights_by_day_dict.get(day, [])
        
        flights_from_airport = []
        for flight in daily_flights:
            #print(self.associated_area_to_airport(airport=flight[0]))
            if (flight[0] == from_airport) and (self.associated_area_to_airport(airport=flight[1]) not in visited_areas):
                
                flights_from_airport.append([flight[1], flight[2]])

        return flights_from_airport
    
    def which_area_to_explore(self,airports_by_area):
        return list({key: len(value) for key, value in airports_by_area.items() if len(value) > 1})

# %%
class Node:
    def __init__(self, state, parent=None):
        self.state = state  # State is a dictionary representing the current situation
        self.parent = parent  # Parent node
        self.children = []  # List of child nodes
        self.visit_count = 0  # Number of times this node has been visited
        self.total_cost = 0  # Total cost accumulated in simulations from this node

    def add_child(self, child_state):
        child_node = Node(child_state, self)
        self.children.append(child_node)
        return child_node

    def is_fully_expanded(self):
        return len(self.children) > 0 and all(child.visit_count > 0 for child in self.children)

    def best_child(self, c_param=1.41):
        epsilon=1e-6
        choices_weights = [
            (child.total_cost / (child.visit_count + epsilon)) + 
            c_param * (2 * np.log(self.visit_count + 1) / (child.visit_count + epsilon)) ** 0.5
            for child in self.children
        ]
        #return choices_weights
        return self.children[np.argmin(choices_weights)]

# %% [markdown]
# #### TEST

# %%
class MCTS(data_preprocessing):
    def __init__(self, instance, root_state, iterations):
        super().__init__(instance_path=instance)
        self.root = Node(root_state)
        self.iterations = iterations
        self.best_leaf = None
        self.best_leaf_cost = float('inf')
        self.search()
        
    def expand_node(self, node):
        actions = self.possible_flights_from_an_airport_at_a_specific_day_with_previous_areas(
            node.state['current_day'], node.state['current_airport'],node.state['visited_zones'])

        for action in actions:
            #print(action)
            new_state = self.transition_function(node.state, action)
            node.add_child(new_state)
            #print(new_state)
            
    def transition_function(self, state, action):
        new_state = deepcopy(state)  # Deep copy to avoid side effects
        new_state['current_day'] += 1
        new_state['current_airport'] = action[0]
        new_state['total_cost'] += action[1]
        new_state['path'].append(action[0])
        #print(f"Remove {self.associated_area_to_airport(airport=new_state['current_airport'])}")
        new_state['remaining_zones'].remove(self.associated_area_to_airport(airport=new_state['current_airport']))
        new_state['visited_zones'].append(self.associated_area_to_airport(airport=action[0]))
        return new_state

    def random_policy(self, state):
        actions = self.possible_flights_from_an_airport_at_a_specific_day_with_previous_areas(
            day=state['current_day'], from_airport=state['current_airport'],visited_areas=state['visited_zones']
        )
        return random.choice(actions)
    
    def select(self, node):
        current_node = node
        while current_node.is_fully_expanded() and current_node.children:
            current_node = current_node.best_child()
            #print(current_node)
        return current_node

    def simulate(self, node):
        current_simulation_state = deepcopy(node.state)
        while current_simulation_state['current_day']!=self.number_of_areas:
            print(current_simulation_state)
            action = self.random_policy(current_simulation_state)
            current_simulation_state = self.transition_function(current_simulation_state, action)
        
        #current_simulation_state['remaining_zones'].append(self.starting_area)
        #action = self.random_policy(current_simulation_state)
        #current_simulation_state = self.transition_function(current_simulation_state, action)
        print(current_simulation_state['total_cost'])
        
        if current_simulation_state['total_cost'] < self.best_leaf_cost:
            self.best_leaf = current_simulation_state
            self.best_leaf_cost = current_simulation_state['total_cost']
                
        return current_simulation_state['total_cost']

    def backpropagate(self, node, cost):
        current_node = node
        while current_node is not None:
            current_node.visit_count += 1
            current_node.total_cost += cost
            current_node = current_node.parent

    def search(self):
        for _ in range(self.iterations):
            node_to_explore = self.select(self.root)
            if not node_to_explore.is_fully_expanded():
                self.expand_node(node_to_explore)
            cost = self.simulate(node_to_explore)
            self.backpropagate(node_to_explore, cost)
        best_node = self.root.best_child(c_param=0)
        
        return self.root.best_child(c_param=0).state['path'], self.root.best_child(c_param=0).state['total_cost']

# %%
instance_path = 'Flight connections dataset/1.in'
data_processor = data_preprocessing(instance_path=instance_path)

# Define root state
root_state = {
    'current_day': 1,
    'current_airport': data_processor.starting_airport,
    'remaining_zones': [x for x in data_processor.list_areas if x != data_processor.starting_area],  # Exclude the starting area
    'visited_zones': [data_processor.starting_area],  # Exclude the starting area
    'total_cost': 0,
    'path': [data_processor.starting_airport]
}

mcts = MCTS(instance=instance_path, root_state=root_state, iterations=1000)

print(mcts.best_leaf,mcts.best_leaf_cost)
# Out:
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '2'], 'total_cost': 3619, 'path': ['AB0', 'AB2']}
# {'current_day': 3, 'current_airport': 'AB9', 'remaining_zones': ['1', '3', '4', '5', '6', '7', '8'], 'visited_zones': ['0', '2', '9'], 'total_cost': 3887, 'path': ['AB0', 'AB2', 'AB9']}
# {'current_day': 4, 'current_airport': 'AB5', 'remaining_zones': ['1', '3', '4', '6', '7', '8'], 'visited_zones': ['0', '2', '9', '5'], 'total_cost': 8684, 'path': ['AB0', 'AB2', 'AB9', 'AB5']}
# {'current_day': 5, 'current_airport': 'AB1', 'remaining_zones': ['3', '4', '6', '7', '8'], 'visited_zones': ['0', '2', '9', '5', '1'], 'total_cost': 8863, 'path': ['AB0', 'AB2', 'AB9', 'AB5', 'AB1']}
# {'current_day': 6, 'current_airport': 'AB7', 'remaining_zones': ['3', '4', '6', '8'], 'visited_zones': ['0', '2', '9', '5', '1', '7'], 'total_cost': 9049, 'path': ['AB0', 'AB2', 'AB9', 'AB5', 'AB1', 'AB7']}
# {'current_day': 7, 'current_airport': 'AB6', 'remaining_zones': ['3', '4', '8'], 'visited_zones': ['0', '2', '9', '5', '1', '7', '6'], 'total_cost': 11618, 'path': ['AB0', 'AB2', 'AB9', 'AB5', 'AB1', 'AB7', 'AB6']}
# {'current_day': 8, 'current_airport': 'AB8', 'remaining_zones': ['3', '4'], 'visited_zones': ['0', '2', '9', '5', '1', '7', '6', '8'], 'total_cost': 13328, 'path': ['AB0', 'AB2', 'AB9', 'AB5', 'AB1', 'AB7', 'AB6', 'AB8']}
# {'current_day': 9, 'current_airport': 'AB3', 'remaining_zones': ['4'], 'visited_zones': ['0', '2', '9', '5', '1', '7', '6', '8', '3'], 'total_cost': 13437, 'path': ['AB0', 'AB2', 'AB9', 'AB5', 'AB1', 'AB7', 'AB6', 'AB8', 'AB3']}
# 18943
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB7', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '8', '9'], 'visited_zones': ['0', '7'], 'total_cost': 192, 'path': ['AB0', 'AB7']}
# {'current_day': 3, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '9'], 'visited_zones': ['0', '7', '8'], 'total_cost': 5155, 'path': ['AB0', 'AB7', 'AB8']}
# {'current_day': 4, 'current_airport': 'AB5', 'remaining_zones': ['1', '2', '3', '4', '6', '9'], 'visited_zones': ['0', '7', '8', '5'], 'total_cost': 8041, 'path': ['AB0', 'AB7', 'AB8', 'AB5']}
# {'current_day': 5, 'current_airport': 'AB1', 'remaining_zones': ['2', '3', '4', '6', '9'], 'visited_zones': ['0', '7', '8', '5', '1'], 'total_cost': 8220, 'path': ['AB0', 'AB7', 'AB8', 'AB5', 'AB1']}
# {'current_day': 6, 'current_airport': 'AB3', 'remaining_zones': ['2', '4', '6', '9'], 'visited_zones': ['0', '7', '8', '5', '1', '3'], 'total_cost': 12337, 'path': ['AB0', 'AB7', 'AB8', 'AB5', 'AB1', 'AB3']}
# {'current_day': 7, 'current_airport': 'AB4', 'remaining_zones': ['2', '6', '9'], 'visited_zones': ['0', '7', '8', '5', '1', '3', '4'], 'total_cost': 17966, 'path': ['AB0', 'AB7', 'AB8', 'AB5', 'AB1', 'AB3', 'AB4']}
# {'current_day': 8, 'current_airport': 'AB9', 'remaining_zones': ['2', '6'], 'visited_zones': ['0', '7', '8', '5', '1', '3', '4', '9'], 'total_cost': 18129, 'path': ['AB0', 'AB7', 'AB8', 'AB5', 'AB1', 'AB3', 'AB4', 'AB9']}
# {'current_day': 9, 'current_airport': 'AB2', 'remaining_zones': ['6'], 'visited_zones': ['0', '7', '8', '5', '1', '3', '4', '9', '2'], 'total_cost': 18328, 'path': ['AB0', 'AB7', 'AB8', 'AB5', 'AB1', 'AB3', 'AB4', 'AB9', 'AB2']}
# 18445
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8'], 'total_cost': 283, 'path': ['AB0', 'AB8']}
# {'current_day': 3, 'current_airport': 'AB6', 'remaining_zones': ['1', '2', '3', '4', '5', '7', '9'], 'visited_zones': ['0', '8', '6'], 'total_cost': 5281, 'path': ['AB0', 'AB8', 'AB6']}
# {'current_day': 4, 'current_airport': 'AB9', 'remaining_zones': ['1', '2', '3', '4', '5', '7'], 'visited_zones': ['0', '8', '6', '9'], 'total_cost': 8464, 'path': ['AB0', 'AB8', 'AB6', 'AB9']}
# {'current_day': 5, 'current_airport': 'AB3', 'remaining_zones': ['1', '2', '4', '5', '7'], 'visited_zones': ['0', '8', '6', '9', '3'], 'total_cost': 8609, 'path': ['AB0', 'AB8', 'AB6', 'AB9', 'AB3']}
# {'current_day': 6, 'current_airport': 'AB5', 'remaining_zones': ['1', '2', '4', '7'], 'visited_zones': ['0', '8', '6', '9', '3', '5'], 'total_cost': 8882, 'path': ['AB0', 'AB8', 'AB6', 'AB9', 'AB3', 'AB5']}
# {'current_day': 7, 'current_airport': 'AB4', 'remaining_zones': ['1', '2', '7'], 'visited_zones': ['0', '8', '6', '9', '3', '5', '4'], 'total_cost': 9097, 'path': ['AB0', 'AB8', 'AB6', 'AB9', 'AB3', 'AB5', 'AB4']}
# {'current_day': 8, 'current_airport': 'AB2', 'remaining_zones': ['1', '7'], 'visited_zones': ['0', '8', '6', '9', '3', '5', '4', '2'], 'total_cost': 12835, 'path': ['AB0', 'AB8', 'AB6', 'AB9', 'AB3', 'AB5', 'AB4', 'AB2']}
# {'current_day': 9, 'current_airport': 'AB7', 'remaining_zones': ['1'], 'visited_zones': ['0', '8', '6', '9', '3', '5', '4', '2', '7'], 'total_cost': 13080, 'path': ['AB0', 'AB8', 'AB6', 'AB9', 'AB3', 'AB5', 'AB4', 'AB2', 'AB7']}
# 13345
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB6', 'remaining_zones': ['1', '2', '3', '4', '5', '7', '8', '9'], 'visited_zones': ['0', '6'], 'total_cost': 179, 'path': ['AB0', 'AB6']}
# {'current_day': 3, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '4', '5', '7', '8', '9'], 'visited_zones': ['0', '6', '2'], 'total_cost': 381, 'path': ['AB0', 'AB6', 'AB2']}
# {'current_day': 4, 'current_airport': 'AB7', 'remaining_zones': ['1', '3', '4', '5', '8', '9'], 'visited_zones': ['0', '6', '2', '7'], 'total_cost': 648, 'path': ['AB0', 'AB6', 'AB2', 'AB7']}
# {'current_day': 5, 'current_airport': 'AB3', 'remaining_zones': ['1', '4', '5', '8', '9'], 'visited_zones': ['0', '6', '2', '7', '3'], 'total_cost': 848, 'path': ['AB0', 'AB6', 'AB2', 'AB7', 'AB3']}
# {'current_day': 6, 'current_airport': 'AB4', 'remaining_zones': ['1', '5', '8', '9'], 'visited_zones': ['0', '6', '2', '7', '3', '4'], 'total_cost': 6558, 'path': ['AB0', 'AB6', 'AB2', 'AB7', 'AB3', 'AB4']}
# {'current_day': 7, 'current_airport': 'AB8', 'remaining_zones': ['1', '5', '9'], 'visited_zones': ['0', '6', '2', '7', '3', '4', '8'], 'total_cost': 6685, 'path': ['AB0', 'AB6', 'AB2', 'AB7', 'AB3', 'AB4', 'AB8']}
# {'current_day': 8, 'current_airport': 'AB1', 'remaining_zones': ['5', '9'], 'visited_zones': ['0', '6', '2', '7', '3', '4', '8', '1'], 'total_cost': 6866, 'path': ['AB0', 'AB6', 'AB2', 'AB7', 'AB3', 'AB4', 'AB8', 'AB1']}
# {'current_day': 9, 'current_airport': 'AB5', 'remaining_zones': ['9'], 'visited_zones': ['0', '6', '2', '7', '3', '4', '8', '1', '5'], 'total_cost': 7029, 'path': ['AB0', 'AB6', 'AB2', 'AB7', 'AB3', 'AB4', 'AB8', 'AB1', 'AB5']}
# 8170
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB6', 'remaining_zones': ['1', '2', '3', '4', '5', '7', '8', '9'], 'visited_zones': ['0', '6'], 'total_cost': 179, 'path': ['AB0', 'AB6']}
# {'current_day': 3, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '4', '5', '7', '8', '9'], 'visited_zones': ['0', '6', '2'], 'total_cost': 381, 'path': ['AB0', 'AB6', 'AB2']}
# {'current_day': 4, 'current_airport': 'AB4', 'remaining_zones': ['1', '3', '5', '7', '8', '9'], 'visited_zones': ['0', '6', '2', '4'], 'total_cost': 5089, 'path': ['AB0', 'AB6', 'AB2', 'AB4']}
# {'current_day': 5, 'current_airport': 'AB3', 'remaining_zones': ['1', '5', '7', '8', '9'], 'visited_zones': ['0', '6', '2', '4', '3'], 'total_cost': 10519, 'path': ['AB0', 'AB6', 'AB2', 'AB4', 'AB3']}
# {'current_day': 6, 'current_airport': 'AB7', 'remaining_zones': ['1', '5', '8', '9'], 'visited_zones': ['0', '6', '2', '4', '3', '7'], 'total_cost': 10781, 'path': ['AB0', 'AB6', 'AB2', 'AB4', 'AB3', 'AB7']}
# {'current_day': 7, 'current_airport': 'AB9', 'remaining_zones': ['1', '5', '8'], 'visited_zones': ['0', '6', '2', '4', '3', '7', '9'], 'total_cost': 13011, 'path': ['AB0', 'AB6', 'AB2', 'AB4', 'AB3', 'AB7', 'AB9']}
# {'current_day': 8, 'current_airport': 'AB8', 'remaining_zones': ['1', '5'], 'visited_zones': ['0', '6', '2', '4', '3', '7', '9', '8'], 'total_cost': 15771, 'path': ['AB0', 'AB6', 'AB2', 'AB4', 'AB3', 'AB7', 'AB9', 'AB8']}
# {'current_day': 9, 'current_airport': 'AB5', 'remaining_zones': ['1'], 'visited_zones': ['0', '6', '2', '4', '3', '7', '9', '8', '5'], 'total_cost': 17240, 'path': ['AB0', 'AB6', 'AB2', 'AB4', 'AB3', 'AB7', 'AB9', 'AB8', 'AB5']}
# 17497
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB4', 'remaining_zones': ['1', '2', '3', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '4'], 'total_cost': 2127, 'path': ['AB0', 'AB4']}
# {'current_day': 3, 'current_airport': 'AB3', 'remaining_zones': ['1', '2', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '4', '3'], 'total_cost': 3378, 'path': ['AB0', 'AB4', 'AB3']}
# {'current_day': 4, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '5', '6', '7', '9'], 'visited_zones': ['0', '4', '3', '8'], 'total_cost': 3567, 'path': ['AB0', 'AB4', 'AB3', 'AB8']}
# {'current_day': 5, 'current_airport': 'AB5', 'remaining_zones': ['1', '2', '6', '7', '9'], 'visited_zones': ['0', '4', '3', '8', '5'], 'total_cost': 7999, 'path': ['AB0', 'AB4', 'AB3', 'AB8', 'AB5']}
# {'current_day': 6, 'current_airport': 'AB9', 'remaining_zones': ['1', '2', '6', '7'], 'visited_zones': ['0', '4', '3', '8', '5', '9'], 'total_cost': 13136, 'path': ['AB0', 'AB4', 'AB3', 'AB8', 'AB5', 'AB9']}
# {'current_day': 7, 'current_airport': 'AB1', 'remaining_zones': ['2', '6', '7'], 'visited_zones': ['0', '4', '3', '8', '5', '9', '1'], 'total_cost': 13403, 'path': ['AB0', 'AB4', 'AB3', 'AB8', 'AB5', 'AB9', 'AB1']}
# {'current_day': 8, 'current_airport': 'AB7', 'remaining_zones': ['2', '6'], 'visited_zones': ['0', '4', '3', '8', '5', '9', '1', '7'], 'total_cost': 13647, 'path': ['AB0', 'AB4', 'AB3', 'AB8', 'AB5', 'AB9', 'AB1', 'AB7']}
# {'current_day': 9, 'current_airport': 'AB2', 'remaining_zones': ['6'], 'visited_zones': ['0', '4', '3', '8', '5', '9', '1', '7', '2'], 'total_cost': 13846, 'path': ['AB0', 'AB4', 'AB3', 'AB8', 'AB5', 'AB9', 'AB1', 'AB7', 'AB2']}
# 13963
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB5', 'remaining_zones': ['1', '2', '3', '4', '6', '7', '8', '9'], 'visited_zones': ['0', '5'], 'total_cost': 173, 'path': ['AB0', 'AB5']}
# {'current_day': 3, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '4', '6', '7', '8', '9'], 'visited_zones': ['0', '5', '2'], 'total_cost': 380, 'path': ['AB0', 'AB5', 'AB2']}
# {'current_day': 4, 'current_airport': 'AB9', 'remaining_zones': ['1', '3', '4', '6', '7', '8'], 'visited_zones': ['0', '5', '2', '9'], 'total_cost': 546, 'path': ['AB0', 'AB5', 'AB2', 'AB9']}
# {'current_day': 5, 'current_airport': 'AB1', 'remaining_zones': ['3', '4', '6', '7', '8'], 'visited_zones': ['0', '5', '2', '9', '1'], 'total_cost': 660, 'path': ['AB0', 'AB5', 'AB2', 'AB9', 'AB1']}
# {'current_day': 6, 'current_airport': 'AB3', 'remaining_zones': ['4', '6', '7', '8'], 'visited_zones': ['0', '5', '2', '9', '1', '3'], 'total_cost': 4777, 'path': ['AB0', 'AB5', 'AB2', 'AB9', 'AB1', 'AB3']}
# {'current_day': 7, 'current_airport': 'AB7', 'remaining_zones': ['4', '6', '8'], 'visited_zones': ['0', '5', '2', '9', '1', '3', '7'], 'total_cost': 4953, 'path': ['AB0', 'AB5', 'AB2', 'AB9', 'AB1', 'AB3', 'AB7']}
# {'current_day': 8, 'current_airport': 'AB8', 'remaining_zones': ['4', '6'], 'visited_zones': ['0', '5', '2', '9', '1', '3', '7', '8'], 'total_cost': 8330, 'path': ['AB0', 'AB5', 'AB2', 'AB9', 'AB1', 'AB3', 'AB7', 'AB8']}
# {'current_day': 9, 'current_airport': 'AB6', 'remaining_zones': ['4'], 'visited_zones': ['0', '5', '2', '9', '1', '3', '7', '8', '6'], 'total_cost': 10793, 'path': ['AB0', 'AB5', 'AB2', 'AB9', 'AB1', 'AB3', 'AB7', 'AB8', 'AB6']}
# 10948
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB4', 'remaining_zones': ['1', '2', '3', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '4'], 'total_cost': 2127, 'path': ['AB0', 'AB4']}
# {'current_day': 3, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '3', '5', '6', '7', '9'], 'visited_zones': ['0', '4', '8'], 'total_cost': 2291, 'path': ['AB0', 'AB4', 'AB8']}
# {'current_day': 4, 'current_airport': 'AB3', 'remaining_zones': ['1', '2', '5', '6', '7', '9'], 'visited_zones': ['0', '4', '8', '3'], 'total_cost': 2494, 'path': ['AB0', 'AB4', 'AB8', 'AB3']}
# {'current_day': 5, 'current_airport': 'AB1', 'remaining_zones': ['2', '5', '6', '7', '9'], 'visited_zones': ['0', '4', '8', '3', '1'], 'total_cost': 8124, 'path': ['AB0', 'AB4', 'AB8', 'AB3', 'AB1']}
# {'current_day': 6, 'current_airport': 'AB7', 'remaining_zones': ['2', '5', '6', '9'], 'visited_zones': ['0', '4', '8', '3', '1', '7'], 'total_cost': 8310, 'path': ['AB0', 'AB4', 'AB8', 'AB3', 'AB1', 'AB7']}
# {'current_day': 7, 'current_airport': 'AB9', 'remaining_zones': ['2', '5', '6'], 'visited_zones': ['0', '4', '8', '3', '1', '7', '9'], 'total_cost': 10540, 'path': ['AB0', 'AB4', 'AB8', 'AB3', 'AB1', 'AB7', 'AB9']}
# {'current_day': 8, 'current_airport': 'AB2', 'remaining_zones': ['5', '6'], 'visited_zones': ['0', '4', '8', '3', '1', '7', '9', '2'], 'total_cost': 10818, 'path': ['AB0', 'AB4', 'AB8', 'AB3', 'AB1', 'AB7', 'AB9', 'AB2']}
# {'current_day': 9, 'current_airport': 'AB6', 'remaining_zones': ['5'], 'visited_zones': ['0', '4', '8', '3', '1', '7', '9', '2', '6'], 'total_cost': 10968, 'path': ['AB0', 'AB4', 'AB8', 'AB3', 'AB1', 'AB7', 'AB9', 'AB2', 'AB6']}
# 16822
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB5', 'remaining_zones': ['1', '2', '3', '4', '6', '7', '8', '9'], 'visited_zones': ['0', '5'], 'total_cost': 173, 'path': ['AB0', 'AB5']}
# {'current_day': 3, 'current_airport': 'AB1', 'remaining_zones': ['2', '3', '4', '6', '7', '8', '9'], 'visited_zones': ['0', '5', '1'], 'total_cost': 448, 'path': ['AB0', 'AB5', 'AB1']}
# {'current_day': 4, 'current_airport': 'AB9', 'remaining_zones': ['2', '3', '4', '6', '7', '8'], 'visited_zones': ['0', '5', '1', '9'], 'total_cost': 739, 'path': ['AB0', 'AB5', 'AB1', 'AB9']}
# {'current_day': 5, 'current_airport': 'AB3', 'remaining_zones': ['2', '4', '6', '7', '8'], 'visited_zones': ['0', '5', '1', '9', '3'], 'total_cost': 884, 'path': ['AB0', 'AB5', 'AB1', 'AB9', 'AB3']}
# {'current_day': 6, 'current_airport': 'AB4', 'remaining_zones': ['2', '6', '7', '8'], 'visited_zones': ['0', '5', '1', '9', '3', '4'], 'total_cost': 6594, 'path': ['AB0', 'AB5', 'AB1', 'AB9', 'AB3', 'AB4']}
# {'current_day': 7, 'current_airport': 'AB7', 'remaining_zones': ['2', '6', '8'], 'visited_zones': ['0', '5', '1', '9', '3', '4', '7'], 'total_cost': 6821, 'path': ['AB0', 'AB5', 'AB1', 'AB9', 'AB3', 'AB4', 'AB7']}
# {'current_day': 8, 'current_airport': 'AB6', 'remaining_zones': ['2', '8'], 'visited_zones': ['0', '5', '1', '9', '3', '4', '7', '6'], 'total_cost': 7830, 'path': ['AB0', 'AB5', 'AB1', 'AB9', 'AB3', 'AB4', 'AB7', 'AB6']}
# {'current_day': 9, 'current_airport': 'AB2', 'remaining_zones': ['8'], 'visited_zones': ['0', '5', '1', '9', '3', '4', '7', '6', '2'], 'total_cost': 8057, 'path': ['AB0', 'AB5', 'AB1', 'AB9', 'AB3', 'AB4', 'AB7', 'AB6', 'AB2']}
# 8157
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB6', 'remaining_zones': ['1', '2', '3', '4', '5', '7', '8', '9'], 'visited_zones': ['0', '6'], 'total_cost': 179, 'path': ['AB0', 'AB6']}
# {'current_day': 3, 'current_airport': 'AB1', 'remaining_zones': ['2', '3', '4', '5', '7', '8', '9'], 'visited_zones': ['0', '6', '1'], 'total_cost': 314, 'path': ['AB0', 'AB6', 'AB1']}
# {'current_day': 4, 'current_airport': 'AB9', 'remaining_zones': ['2', '3', '4', '5', '7', '8'], 'visited_zones': ['0', '6', '1', '9'], 'total_cost': 605, 'path': ['AB0', 'AB6', 'AB1', 'AB9']}
# {'current_day': 5, 'current_airport': 'AB4', 'remaining_zones': ['2', '3', '5', '7', '8'], 'visited_zones': ['0', '6', '1', '9', '4'], 'total_cost': 812, 'path': ['AB0', 'AB6', 'AB1', 'AB9', 'AB4']}
# {'current_day': 6, 'current_airport': 'AB2', 'remaining_zones': ['3', '5', '7', '8'], 'visited_zones': ['0', '6', '1', '9', '4', '2'], 'total_cost': 3020, 'path': ['AB0', 'AB6', 'AB1', 'AB9', 'AB4', 'AB2']}
# {'current_day': 7, 'current_airport': 'AB8', 'remaining_zones': ['3', '5', '7'], 'visited_zones': ['0', '6', '1', '9', '4', '2', '8'], 'total_cost': 3243, 'path': ['AB0', 'AB6', 'AB1', 'AB9', 'AB4', 'AB2', 'AB8']}
# {'current_day': 8, 'current_airport': 'AB5', 'remaining_zones': ['3', '7'], 'visited_zones': ['0', '6', '1', '9', '4', '2', '8', '5'], 'total_cost': 5807, 'path': ['AB0', 'AB6', 'AB1', 'AB9', 'AB4', 'AB2', 'AB8', 'AB5']}
# {'current_day': 9, 'current_airport': 'AB3', 'remaining_zones': ['7'], 'visited_zones': ['0', '6', '1', '9', '4', '2', '8', '5', '3'], 'total_cost': 5907, 'path': ['AB0', 'AB6', 'AB1', 'AB9', 'AB4', 'AB2', 'AB8', 'AB5', 'AB3']}
# 6101
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB3', 'remaining_zones': ['1', '2', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '3'], 'total_cost': 4618, 'path': ['AB0', 'AB3']}
# {'current_day': 3, 'current_airport': 'AB2', 'remaining_zones': ['1', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '3', '2'], 'total_cost': 7201, 'path': ['AB0', 'AB3', 'AB2']}
# {'current_day': 4, 'current_airport': 'AB5', 'remaining_zones': ['1', '4', '6', '7', '8', '9'], 'visited_zones': ['0', '3', '2', '5'], 'total_cost': 7357, 'path': ['AB0', 'AB3', 'AB2', 'AB5']}
# {'current_day': 5, 'current_airport': 'AB1', 'remaining_zones': ['4', '6', '7', '8', '9'], 'visited_zones': ['0', '3', '2', '5', '1'], 'total_cost': 7536, 'path': ['AB0', 'AB3', 'AB2', 'AB5', 'AB1']}
# {'current_day': 6, 'current_airport': 'AB8', 'remaining_zones': ['4', '6', '7', '9'], 'visited_zones': ['0', '3', '2', '5', '1', '8'], 'total_cost': 7650, 'path': ['AB0', 'AB3', 'AB2', 'AB5', 'AB1', 'AB8']}
# {'current_day': 7, 'current_airport': 'AB6', 'remaining_zones': ['4', '7', '9'], 'visited_zones': ['0', '3', '2', '5', '1', '8', '6'], 'total_cost': 9822, 'path': ['AB0', 'AB3', 'AB2', 'AB5', 'AB1', 'AB8', 'AB6']}
# {'current_day': 8, 'current_airport': 'AB9', 'remaining_zones': ['4', '7'], 'visited_zones': ['0', '3', '2', '5', '1', '8', '6', '9'], 'total_cost': 12400, 'path': ['AB0', 'AB3', 'AB2', 'AB5', 'AB1', 'AB8', 'AB6', 'AB9']}
# {'current_day': 9, 'current_airport': 'AB4', 'remaining_zones': ['7'], 'visited_zones': ['0', '3', '2', '5', '1', '8', '6', '9', '4'], 'total_cost': 12553, 'path': ['AB0', 'AB3', 'AB2', 'AB5', 'AB1', 'AB8', 'AB6', 'AB9', 'AB4']}
# 12687
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB6', 'remaining_zones': ['1', '2', '3', '4', '5', '7', '8', '9'], 'visited_zones': ['0', '6'], 'total_cost': 179, 'path': ['AB0', 'AB6']}
# {'current_day': 3, 'current_airport': 'AB7', 'remaining_zones': ['1', '2', '3', '4', '5', '8', '9'], 'visited_zones': ['0', '6', '7'], 'total_cost': 4564, 'path': ['AB0', 'AB6', 'AB7']}
# {'current_day': 4, 'current_airport': 'AB5', 'remaining_zones': ['1', '2', '3', '4', '8', '9'], 'visited_zones': ['0', '6', '7', '5'], 'total_cost': 7562, 'path': ['AB0', 'AB6', 'AB7', 'AB5']}
# {'current_day': 5, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '4', '8', '9'], 'visited_zones': ['0', '6', '7', '5', '2'], 'total_cost': 7796, 'path': ['AB0', 'AB6', 'AB7', 'AB5', 'AB2']}
# {'current_day': 6, 'current_airport': 'AB3', 'remaining_zones': ['1', '4', '8', '9'], 'visited_zones': ['0', '6', '7', '5', '2', '3'], 'total_cost': 10966, 'path': ['AB0', 'AB6', 'AB7', 'AB5', 'AB2', 'AB3']}
# {'current_day': 7, 'current_airport': 'AB8', 'remaining_zones': ['1', '4', '9'], 'visited_zones': ['0', '6', '7', '5', '2', '3', '8'], 'total_cost': 11204, 'path': ['AB0', 'AB6', 'AB7', 'AB5', 'AB2', 'AB3', 'AB8']}
# {'current_day': 8, 'current_airport': 'AB4', 'remaining_zones': ['1', '9'], 'visited_zones': ['0', '6', '7', '5', '2', '3', '8', '4'], 'total_cost': 11450, 'path': ['AB0', 'AB6', 'AB7', 'AB5', 'AB2', 'AB3', 'AB8', 'AB4']}
# {'current_day': 9, 'current_airport': 'AB9', 'remaining_zones': ['1'], 'visited_zones': ['0', '6', '7', '5', '2', '3', '8', '4', '9'], 'total_cost': 11710, 'path': ['AB0', 'AB6', 'AB7', 'AB5', 'AB2', 'AB3', 'AB8', 'AB4', 'AB9']}
# 11921
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB7', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '8', '9'], 'visited_zones': ['0', '7'], 'total_cost': 192, 'path': ['AB0', 'AB7']}
# {'current_day': 3, 'current_airport': 'AB9', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '8'], 'visited_zones': ['0', '7', '9'], 'total_cost': 4955, 'path': ['AB0', 'AB7', 'AB9']}
# {'current_day': 4, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '4', '5', '6', '8'], 'visited_zones': ['0', '7', '9', '2'], 'total_cost': 5140, 'path': ['AB0', 'AB7', 'AB9', 'AB2']}
# {'current_day': 5, 'current_airport': 'AB4', 'remaining_zones': ['1', '3', '5', '6', '8'], 'visited_zones': ['0', '7', '9', '2', '4'], 'total_cost': 8986, 'path': ['AB0', 'AB7', 'AB9', 'AB2', 'AB4']}
# {'current_day': 6, 'current_airport': 'AB1', 'remaining_zones': ['3', '5', '6', '8'], 'visited_zones': ['0', '7', '9', '2', '4', '1'], 'total_cost': 11417, 'path': ['AB0', 'AB7', 'AB9', 'AB2', 'AB4', 'AB1']}
# {'current_day': 7, 'current_airport': 'AB5', 'remaining_zones': ['3', '6', '8'], 'visited_zones': ['0', '7', '9', '2', '4', '1', '5'], 'total_cost': 11633, 'path': ['AB0', 'AB7', 'AB9', 'AB2', 'AB4', 'AB1', 'AB5']}
# {'current_day': 8, 'current_airport': 'AB3', 'remaining_zones': ['6', '8'], 'visited_zones': ['0', '7', '9', '2', '4', '1', '5', '3'], 'total_cost': 11804, 'path': ['AB0', 'AB7', 'AB9', 'AB2', 'AB4', 'AB1', 'AB5', 'AB3']}
# {'current_day': 9, 'current_airport': 'AB6', 'remaining_zones': ['8'], 'visited_zones': ['0', '7', '9', '2', '4', '1', '5', '3', '6'], 'total_cost': 12101, 'path': ['AB0', 'AB7', 'AB9', 'AB2', 'AB4', 'AB1', 'AB5', 'AB3', 'AB6']}
# 13245
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB6', 'remaining_zones': ['1', '2', '3', '4', '5', '7', '8', '9'], 'visited_zones': ['0', '6'], 'total_cost': 179, 'path': ['AB0', 'AB6']}
# {'current_day': 3, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '4', '5', '7', '8', '9'], 'visited_zones': ['0', '6', '2'], 'total_cost': 381, 'path': ['AB0', 'AB6', 'AB2']}
# {'current_day': 4, 'current_airport': 'AB7', 'remaining_zones': ['1', '3', '4', '5', '8', '9'], 'visited_zones': ['0', '6', '2', '7'], 'total_cost': 648, 'path': ['AB0', 'AB6', 'AB2', 'AB7']}
# {'current_day': 5, 'current_airport': 'AB3', 'remaining_zones': ['1', '4', '5', '8', '9'], 'visited_zones': ['0', '6', '2', '7', '3'], 'total_cost': 848, 'path': ['AB0', 'AB6', 'AB2', 'AB7', 'AB3']}
# {'current_day': 6, 'current_airport': 'AB4', 'remaining_zones': ['1', '5', '8', '9'], 'visited_zones': ['0', '6', '2', '7', '3', '4'], 'total_cost': 6558, 'path': ['AB0', 'AB6', 'AB2', 'AB7', 'AB3', 'AB4']}
# {'current_day': 7, 'current_airport': 'AB5', 'remaining_zones': ['1', '8', '9'], 'visited_zones': ['0', '6', '2', '7', '3', '4', '5'], 'total_cost': 6675, 'path': ['AB0', 'AB6', 'AB2', 'AB7', 'AB3', 'AB4', 'AB5']}
# {'current_day': 8, 'current_airport': 'AB8', 'remaining_zones': ['1', '9'], 'visited_zones': ['0', '6', '2', '7', '3', '4', '5', '8'], 'total_cost': 12119, 'path': ['AB0', 'AB6', 'AB2', 'AB7', 'AB3', 'AB4', 'AB5', 'AB8']}
# {'current_day': 9, 'current_airport': 'AB1', 'remaining_zones': ['9'], 'visited_zones': ['0', '6', '2', '7', '3', '4', '5', '8', '1'], 'total_cost': 12354, 'path': ['AB0', 'AB6', 'AB2', 'AB7', 'AB3', 'AB4', 'AB5', 'AB8', 'AB1']}
# 12531
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB3', 'remaining_zones': ['1', '2', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '3'], 'total_cost': 4618, 'path': ['AB0', 'AB3']}
# {'current_day': 3, 'current_airport': 'AB2', 'remaining_zones': ['1', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '3', '2'], 'total_cost': 7201, 'path': ['AB0', 'AB3', 'AB2']}
# {'current_day': 4, 'current_airport': 'AB4', 'remaining_zones': ['1', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '3', '2', '4'], 'total_cost': 11909, 'path': ['AB0', 'AB3', 'AB2', 'AB4']}
# {'current_day': 5, 'current_airport': 'AB9', 'remaining_zones': ['1', '5', '6', '7', '8'], 'visited_zones': ['0', '3', '2', '4', '9'], 'total_cost': 12013, 'path': ['AB0', 'AB3', 'AB2', 'AB4', 'AB9']}
# {'current_day': 6, 'current_airport': 'AB8', 'remaining_zones': ['1', '5', '6', '7'], 'visited_zones': ['0', '3', '2', '4', '9', '8'], 'total_cost': 16349, 'path': ['AB0', 'AB3', 'AB2', 'AB4', 'AB9', 'AB8']}
# {'current_day': 7, 'current_airport': 'AB7', 'remaining_zones': ['1', '5', '6'], 'visited_zones': ['0', '3', '2', '4', '9', '8', '7'], 'total_cost': 21116, 'path': ['AB0', 'AB3', 'AB2', 'AB4', 'AB9', 'AB8', 'AB7']}
# {'current_day': 8, 'current_airport': 'AB6', 'remaining_zones': ['1', '5'], 'visited_zones': ['0', '3', '2', '4', '9', '8', '7', '6'], 'total_cost': 22125, 'path': ['AB0', 'AB3', 'AB2', 'AB4', 'AB9', 'AB8', 'AB7', 'AB6']}
# {'current_day': 9, 'current_airport': 'AB5', 'remaining_zones': ['1'], 'visited_zones': ['0', '3', '2', '4', '9', '8', '7', '6', '5'], 'total_cost': 26866, 'path': ['AB0', 'AB3', 'AB2', 'AB4', 'AB9', 'AB8', 'AB7', 'AB6', 'AB5']}
# 27123
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB6', 'remaining_zones': ['1', '2', '3', '4', '5', '7', '8', '9'], 'visited_zones': ['0', '6'], 'total_cost': 179, 'path': ['AB0', 'AB6']}
# {'current_day': 3, 'current_airport': 'AB5', 'remaining_zones': ['1', '2', '3', '4', '7', '8', '9'], 'visited_zones': ['0', '6', '5'], 'total_cost': 3805, 'path': ['AB0', 'AB6', 'AB5']}
# {'current_day': 4, 'current_airport': 'AB4', 'remaining_zones': ['1', '2', '3', '7', '8', '9'], 'visited_zones': ['0', '6', '5', '4'], 'total_cost': 3979, 'path': ['AB0', 'AB6', 'AB5', 'AB4']}
# {'current_day': 5, 'current_airport': 'AB7', 'remaining_zones': ['1', '2', '3', '8', '9'], 'visited_zones': ['0', '6', '5', '4', '7'], 'total_cost': 4204, 'path': ['AB0', 'AB6', 'AB5', 'AB4', 'AB7']}
# {'current_day': 6, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '8', '9'], 'visited_zones': ['0', '6', '5', '4', '7', '2'], 'total_cost': 4330, 'path': ['AB0', 'AB6', 'AB5', 'AB4', 'AB7', 'AB2']}
# {'current_day': 7, 'current_airport': 'AB8', 'remaining_zones': ['1', '3', '9'], 'visited_zones': ['0', '6', '5', '4', '7', '2', '8'], 'total_cost': 4553, 'path': ['AB0', 'AB6', 'AB5', 'AB4', 'AB7', 'AB2', 'AB8']}
# {'current_day': 8, 'current_airport': 'AB9', 'remaining_zones': ['1', '3'], 'visited_zones': ['0', '6', '5', '4', '7', '2', '8', '9'], 'total_cost': 10100, 'path': ['AB0', 'AB6', 'AB5', 'AB4', 'AB7', 'AB2', 'AB8', 'AB9']}
# {'current_day': 9, 'current_airport': 'AB3', 'remaining_zones': ['1'], 'visited_zones': ['0', '6', '5', '4', '7', '2', '8', '9', '3'], 'total_cost': 10299, 'path': ['AB0', 'AB6', 'AB5', 'AB4', 'AB7', 'AB2', 'AB8', 'AB9', 'AB3']}
# 14028
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB3', 'remaining_zones': ['1', '2', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '3'], 'total_cost': 4618, 'path': ['AB0', 'AB3']}
# {'current_day': 3, 'current_airport': 'AB6', 'remaining_zones': ['1', '2', '4', '5', '7', '8', '9'], 'visited_zones': ['0', '3', '6'], 'total_cost': 4741, 'path': ['AB0', 'AB3', 'AB6']}
# {'current_day': 4, 'current_airport': 'AB9', 'remaining_zones': ['1', '2', '4', '5', '7', '8'], 'visited_zones': ['0', '3', '6', '9'], 'total_cost': 7924, 'path': ['AB0', 'AB3', 'AB6', 'AB9']}
# {'current_day': 5, 'current_airport': 'AB1', 'remaining_zones': ['2', '4', '5', '7', '8'], 'visited_zones': ['0', '3', '6', '9', '1'], 'total_cost': 8038, 'path': ['AB0', 'AB3', 'AB6', 'AB9', 'AB1']}
# {'current_day': 6, 'current_airport': 'AB2', 'remaining_zones': ['4', '5', '7', '8'], 'visited_zones': ['0', '3', '6', '9', '1', '2'], 'total_cost': 10818, 'path': ['AB0', 'AB3', 'AB6', 'AB9', 'AB1', 'AB2']}
# {'current_day': 7, 'current_airport': 'AB8', 'remaining_zones': ['4', '5', '7'], 'visited_zones': ['0', '3', '6', '9', '1', '2', '8'], 'total_cost': 11041, 'path': ['AB0', 'AB3', 'AB6', 'AB9', 'AB1', 'AB2', 'AB8']}
# {'current_day': 8, 'current_airport': 'AB4', 'remaining_zones': ['5', '7'], 'visited_zones': ['0', '3', '6', '9', '1', '2', '8', '4'], 'total_cost': 11287, 'path': ['AB0', 'AB3', 'AB6', 'AB9', 'AB1', 'AB2', 'AB8', 'AB4']}
# {'current_day': 9, 'current_airport': 'AB7', 'remaining_zones': ['5'], 'visited_zones': ['0', '3', '6', '9', '1', '2', '8', '4', '7'], 'total_cost': 11566, 'path': ['AB0', 'AB3', 'AB6', 'AB9', 'AB1', 'AB2', 'AB8', 'AB4', 'AB7']}
# 14163
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '2'], 'total_cost': 3619, 'path': ['AB0', 'AB2']}
# {'current_day': 3, 'current_airport': 'AB7', 'remaining_zones': ['1', '3', '4', '5', '6', '8', '9'], 'visited_zones': ['0', '2', '7'], 'total_cost': 3796, 'path': ['AB0', 'AB2', 'AB7']}
# {'current_day': 4, 'current_airport': 'AB1', 'remaining_zones': ['3', '4', '5', '6', '8', '9'], 'visited_zones': ['0', '2', '7', '1'], 'total_cost': 3904, 'path': ['AB0', 'AB2', 'AB7', 'AB1']}
# {'current_day': 5, 'current_airport': 'AB6', 'remaining_zones': ['3', '4', '5', '8', '9'], 'visited_zones': ['0', '2', '7', '1', '6'], 'total_cost': 4143, 'path': ['AB0', 'AB2', 'AB7', 'AB1', 'AB6']}
# {'current_day': 6, 'current_airport': 'AB5', 'remaining_zones': ['3', '4', '8', '9'], 'visited_zones': ['0', '2', '7', '1', '6', '5'], 'total_cost': 8366, 'path': ['AB0', 'AB2', 'AB7', 'AB1', 'AB6', 'AB5']}
# {'current_day': 7, 'current_airport': 'AB9', 'remaining_zones': ['3', '4', '8'], 'visited_zones': ['0', '2', '7', '1', '6', '5', '9'], 'total_cost': 10685, 'path': ['AB0', 'AB2', 'AB7', 'AB1', 'AB6', 'AB5', 'AB9']}
# {'current_day': 8, 'current_airport': 'AB8', 'remaining_zones': ['3', '4'], 'visited_zones': ['0', '2', '7', '1', '6', '5', '9', '8'], 'total_cost': 13445, 'path': ['AB0', 'AB2', 'AB7', 'AB1', 'AB6', 'AB5', 'AB9', 'AB8']}
# {'current_day': 9, 'current_airport': 'AB3', 'remaining_zones': ['4'], 'visited_zones': ['0', '2', '7', '1', '6', '5', '9', '8', '3'], 'total_cost': 13554, 'path': ['AB0', 'AB2', 'AB7', 'AB1', 'AB6', 'AB5', 'AB9', 'AB8', 'AB3']}
# 19060
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB9', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8'], 'visited_zones': ['0', '9'], 'total_cost': 103, 'path': ['AB0', 'AB9']}
# {'current_day': 3, 'current_airport': 'AB1', 'remaining_zones': ['2', '3', '4', '5', '6', '7', '8'], 'visited_zones': ['0', '9', '1'], 'total_cost': 302, 'path': ['AB0', 'AB9', 'AB1']}
# {'current_day': 4, 'current_airport': 'AB4', 'remaining_zones': ['2', '3', '5', '6', '7', '8'], 'visited_zones': ['0', '9', '1', '4'], 'total_cost': 2786, 'path': ['AB0', 'AB9', 'AB1', 'AB4']}
# {'current_day': 5, 'current_airport': 'AB8', 'remaining_zones': ['2', '3', '5', '6', '7'], 'visited_zones': ['0', '9', '1', '4', '8'], 'total_cost': 3065, 'path': ['AB0', 'AB9', 'AB1', 'AB4', 'AB8']}
# {'current_day': 6, 'current_airport': 'AB5', 'remaining_zones': ['2', '3', '6', '7'], 'visited_zones': ['0', '9', '1', '4', '8', '5'], 'total_cost': 4310, 'path': ['AB0', 'AB9', 'AB1', 'AB4', 'AB8', 'AB5']}
# {'current_day': 7, 'current_airport': 'AB6', 'remaining_zones': ['2', '3', '7'], 'visited_zones': ['0', '9', '1', '4', '8', '5', '6'], 'total_cost': 6199, 'path': ['AB0', 'AB9', 'AB1', 'AB4', 'AB8', 'AB5', 'AB6']}
# {'current_day': 8, 'current_airport': 'AB7', 'remaining_zones': ['2', '3'], 'visited_zones': ['0', '9', '1', '4', '8', '5', '6', '7'], 'total_cost': 8371, 'path': ['AB0', 'AB9', 'AB1', 'AB4', 'AB8', 'AB5', 'AB6', 'AB7']}
# {'current_day': 9, 'current_airport': 'AB2', 'remaining_zones': ['3'], 'visited_zones': ['0', '9', '1', '4', '8', '5', '6', '7', '2'], 'total_cost': 8570, 'path': ['AB0', 'AB9', 'AB1', 'AB4', 'AB8', 'AB5', 'AB6', 'AB7', 'AB2']}
# 14435
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB6', 'remaining_zones': ['1', '2', '3', '4', '5', '7', '8', '9'], 'visited_zones': ['0', '6'], 'total_cost': 179, 'path': ['AB0', 'AB6']}
# {'current_day': 3, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '3', '4', '5', '7', '9'], 'visited_zones': ['0', '6', '8'], 'total_cost': 2721, 'path': ['AB0', 'AB6', 'AB8']}
# {'current_day': 4, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '4', '5', '7', '9'], 'visited_zones': ['0', '6', '8', '2'], 'total_cost': 2900, 'path': ['AB0', 'AB6', 'AB8', 'AB2']}
# {'current_day': 5, 'current_airport': 'AB9', 'remaining_zones': ['1', '3', '4', '5', '7'], 'visited_zones': ['0', '6', '8', '2', '9'], 'total_cost': 3062, 'path': ['AB0', 'AB6', 'AB8', 'AB2', 'AB9']}
# {'current_day': 6, 'current_airport': 'AB5', 'remaining_zones': ['1', '3', '4', '7'], 'visited_zones': ['0', '6', '8', '2', '9', '5'], 'total_cost': 4908, 'path': ['AB0', 'AB6', 'AB8', 'AB2', 'AB9', 'AB5']}
# {'current_day': 7, 'current_airport': 'AB4', 'remaining_zones': ['1', '3', '7'], 'visited_zones': ['0', '6', '8', '2', '9', '5', '4'], 'total_cost': 5123, 'path': ['AB0', 'AB6', 'AB8', 'AB2', 'AB9', 'AB5', 'AB4']}
# {'current_day': 8, 'current_airport': 'AB7', 'remaining_zones': ['1', '3'], 'visited_zones': ['0', '6', '8', '2', '9', '5', '4', '7'], 'total_cost': 5345, 'path': ['AB0', 'AB6', 'AB8', 'AB2', 'AB9', 'AB5', 'AB4', 'AB7']}
# {'current_day': 9, 'current_airport': 'AB1', 'remaining_zones': ['3'], 'visited_zones': ['0', '6', '8', '2', '9', '5', '4', '7', '1'], 'total_cost': 5488, 'path': ['AB0', 'AB6', 'AB8', 'AB2', 'AB9', 'AB5', 'AB4', 'AB7', 'AB1']}
# 10865
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB9', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8'], 'visited_zones': ['0', '9'], 'total_cost': 103, 'path': ['AB0', 'AB9']}
# {'current_day': 3, 'current_airport': 'AB1', 'remaining_zones': ['2', '3', '4', '5', '6', '7', '8'], 'visited_zones': ['0', '9', '1'], 'total_cost': 302, 'path': ['AB0', 'AB9', 'AB1']}
# {'current_day': 4, 'current_airport': 'AB4', 'remaining_zones': ['2', '3', '5', '6', '7', '8'], 'visited_zones': ['0', '9', '1', '4'], 'total_cost': 2786, 'path': ['AB0', 'AB9', 'AB1', 'AB4']}
# {'current_day': 5, 'current_airport': 'AB3', 'remaining_zones': ['2', '5', '6', '7', '8'], 'visited_zones': ['0', '9', '1', '4', '3'], 'total_cost': 8216, 'path': ['AB0', 'AB9', 'AB1', 'AB4', 'AB3']}
# {'current_day': 6, 'current_airport': 'AB2', 'remaining_zones': ['5', '6', '7', '8'], 'visited_zones': ['0', '9', '1', '4', '3', '2'], 'total_cost': 10728, 'path': ['AB0', 'AB9', 'AB1', 'AB4', 'AB3', 'AB2']}
# {'current_day': 7, 'current_airport': 'AB6', 'remaining_zones': ['5', '7', '8'], 'visited_zones': ['0', '9', '1', '4', '3', '2', '6'], 'total_cost': 11022, 'path': ['AB0', 'AB9', 'AB1', 'AB4', 'AB3', 'AB2', 'AB6']}
# {'current_day': 8, 'current_airport': 'AB5', 'remaining_zones': ['7', '8'], 'visited_zones': ['0', '9', '1', '4', '3', '2', '6', '5'], 'total_cost': 16044, 'path': ['AB0', 'AB9', 'AB1', 'AB4', 'AB3', 'AB2', 'AB6', 'AB5']}
# {'current_day': 9, 'current_airport': 'AB7', 'remaining_zones': ['8'], 'visited_zones': ['0', '9', '1', '4', '3', '2', '6', '5', '7'], 'total_cost': 17892, 'path': ['AB0', 'AB9', 'AB1', 'AB4', 'AB3', 'AB2', 'AB6', 'AB5', 'AB7']}
# 19772
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '8'], 'total_cost': 283, 'path': ['AB0', 'AB8']}
# {'current_day': 3, 'current_airport': 'AB9', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7'], 'visited_zones': ['0', '8', '9'], 'total_cost': 2794, 'path': ['AB0', 'AB8', 'AB9']}
# {'current_day': 4, 'current_airport': 'AB5', 'remaining_zones': ['1', '2', '3', '4', '6', '7'], 'visited_zones': ['0', '8', '9', '5'], 'total_cost': 7591, 'path': ['AB0', 'AB8', 'AB9', 'AB5']}
# {'current_day': 5, 'current_airport': 'AB6', 'remaining_zones': ['1', '2', '3', '4', '7'], 'visited_zones': ['0', '8', '9', '5', '6'], 'total_cost': 12645, 'path': ['AB0', 'AB8', 'AB9', 'AB5', 'AB6']}
# {'current_day': 6, 'current_airport': 'AB7', 'remaining_zones': ['1', '2', '3', '4'], 'visited_zones': ['0', '8', '9', '5', '6', '7'], 'total_cost': 17527, 'path': ['AB0', 'AB8', 'AB9', 'AB5', 'AB6', 'AB7']}
# {'current_day': 7, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '4'], 'visited_zones': ['0', '8', '9', '5', '6', '7', '2'], 'total_cost': 17720, 'path': ['AB0', 'AB8', 'AB9', 'AB5', 'AB6', 'AB7', 'AB2']}
# {'current_day': 8, 'current_airport': 'AB3', 'remaining_zones': ['1', '4'], 'visited_zones': ['0', '8', '9', '5', '6', '7', '2', '3'], 'total_cost': 22420, 'path': ['AB0', 'AB8', 'AB9', 'AB5', 'AB6', 'AB7', 'AB2', 'AB3']}
# {'current_day': 9, 'current_airport': 'AB1', 'remaining_zones': ['4'], 'visited_zones': ['0', '8', '9', '5', '6', '7', '2', '3', '1'], 'total_cost': 23942, 'path': ['AB0', 'AB8', 'AB9', 'AB5', 'AB6', 'AB7', 'AB2', 'AB3', 'AB1']}
# 26662
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB6', 'remaining_zones': ['1', '2', '3', '4', '5', '7', '8', '9'], 'visited_zones': ['0', '6'], 'total_cost': 179, 'path': ['AB0', 'AB6']}
# {'current_day': 3, 'current_airport': 'AB4', 'remaining_zones': ['1', '2', '3', '5', '7', '8', '9'], 'visited_zones': ['0', '6', '4'], 'total_cost': 460, 'path': ['AB0', 'AB6', 'AB4']}
# {'current_day': 4, 'current_airport': 'AB5', 'remaining_zones': ['1', '2', '3', '7', '8', '9'], 'visited_zones': ['0', '6', '4', '5'], 'total_cost': 585, 'path': ['AB0', 'AB6', 'AB4', 'AB5']}
# {'current_day': 5, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '3', '7', '9'], 'visited_zones': ['0', '6', '4', '5', '8'], 'total_cost': 3789, 'path': ['AB0', 'AB6', 'AB4', 'AB5', 'AB8']}
# {'current_day': 6, 'current_airport': 'AB1', 'remaining_zones': ['2', '3', '7', '9'], 'visited_zones': ['0', '6', '4', '5', '8', '1'], 'total_cost': 3930, 'path': ['AB0', 'AB6', 'AB4', 'AB5', 'AB8', 'AB1']}
# {'current_day': 7, 'current_airport': 'AB9', 'remaining_zones': ['2', '3', '7'], 'visited_zones': ['0', '6', '4', '5', '8', '1', '9'], 'total_cost': 4123, 'path': ['AB0', 'AB6', 'AB4', 'AB5', 'AB8', 'AB1', 'AB9']}
# {'current_day': 8, 'current_airport': 'AB2', 'remaining_zones': ['3', '7'], 'visited_zones': ['0', '6', '4', '5', '8', '1', '9', '2'], 'total_cost': 4401, 'path': ['AB0', 'AB6', 'AB4', 'AB5', 'AB8', 'AB1', 'AB9', 'AB2']}
# {'current_day': 9, 'current_airport': 'AB7', 'remaining_zones': ['3'], 'visited_zones': ['0', '6', '4', '5', '8', '1', '9', '2', '7'], 'total_cost': 4646, 'path': ['AB0', 'AB6', 'AB4', 'AB5', 'AB8', 'AB1', 'AB9', 'AB2', 'AB7']}
# 4894
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB1', 'remaining_zones': ['2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '1'], 'total_cost': 1, 'path': ['AB0', 'AB1']}
# {'current_day': 3, 'current_airport': 'AB7', 'remaining_zones': ['2', '3', '4', '5', '6', '8', '9'], 'visited_zones': ['0', '1', '7'], 'total_cost': 259, 'path': ['AB0', 'AB1', 'AB7']}
# {'current_day': 4, 'current_airport': 'AB2', 'remaining_zones': ['3', '4', '5', '6', '8', '9'], 'visited_zones': ['0', '1', '7', '2'], 'total_cost': 453, 'path': ['AB0', 'AB1', 'AB7', 'AB2']}
# {'current_day': 5, 'current_airport': 'AB6', 'remaining_zones': ['3', '4', '5', '8', '9'], 'visited_zones': ['0', '1', '7', '2', '6'], 'total_cost': 652, 'path': ['AB0', 'AB1', 'AB7', 'AB2', 'AB6']}
# {'current_day': 6, 'current_airport': 'AB3', 'remaining_zones': ['4', '5', '8', '9'], 'visited_zones': ['0', '1', '7', '2', '6', '3'], 'total_cost': 805, 'path': ['AB0', 'AB1', 'AB7', 'AB2', 'AB6', 'AB3']}
# {'current_day': 7, 'current_airport': 'AB5', 'remaining_zones': ['4', '8', '9'], 'visited_zones': ['0', '1', '7', '2', '6', '3', '5'], 'total_cost': 1098, 'path': ['AB0', 'AB1', 'AB7', 'AB2', 'AB6', 'AB3', 'AB5']}
# {'current_day': 8, 'current_airport': 'AB4', 'remaining_zones': ['8', '9'], 'visited_zones': ['0', '1', '7', '2', '6', '3', '5', '4'], 'total_cost': 1305, 'path': ['AB0', 'AB1', 'AB7', 'AB2', 'AB6', 'AB3', 'AB5', 'AB4']}
# {'current_day': 9, 'current_airport': 'AB9', 'remaining_zones': ['8'], 'visited_zones': ['0', '1', '7', '2', '6', '3', '5', '4', '9'], 'total_cost': 1565, 'path': ['AB0', 'AB1', 'AB7', 'AB2', 'AB6', 'AB3', 'AB5', 'AB4', 'AB9']}
# 4644
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '2'], 'total_cost': 3619, 'path': ['AB0', 'AB2']}
# {'current_day': 3, 'current_airport': 'AB3', 'remaining_zones': ['1', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '2', '3'], 'total_cost': 7827, 'path': ['AB0', 'AB2', 'AB3']}
# {'current_day': 4, 'current_airport': 'AB6', 'remaining_zones': ['1', '4', '5', '7', '8', '9'], 'visited_zones': ['0', '2', '3', '6'], 'total_cost': 8107, 'path': ['AB0', 'AB2', 'AB3', 'AB6']}
# {'current_day': 5, 'current_airport': 'AB1', 'remaining_zones': ['4', '5', '7', '8', '9'], 'visited_zones': ['0', '2', '3', '6', '1'], 'total_cost': 8238, 'path': ['AB0', 'AB2', 'AB3', 'AB6', 'AB1']}
# {'current_day': 6, 'current_airport': 'AB7', 'remaining_zones': ['4', '5', '8', '9'], 'visited_zones': ['0', '2', '3', '6', '1', '7'], 'total_cost': 8424, 'path': ['AB0', 'AB2', 'AB3', 'AB6', 'AB1', 'AB7']}
# {'current_day': 7, 'current_airport': 'AB8', 'remaining_zones': ['4', '5', '9'], 'visited_zones': ['0', '2', '3', '6', '1', '7', '8'], 'total_cost': 14229, 'path': ['AB0', 'AB2', 'AB3', 'AB6', 'AB1', 'AB7', 'AB8']}
# {'current_day': 8, 'current_airport': 'AB4', 'remaining_zones': ['5', '9'], 'visited_zones': ['0', '2', '3', '6', '1', '7', '8', '4'], 'total_cost': 14475, 'path': ['AB0', 'AB2', 'AB3', 'AB6', 'AB1', 'AB7', 'AB8', 'AB4']}
# {'current_day': 9, 'current_airport': 'AB9', 'remaining_zones': ['5'], 'visited_zones': ['0', '2', '3', '6', '1', '7', '8', '4', '9'], 'total_cost': 14735, 'path': ['AB0', 'AB2', 'AB3', 'AB6', 'AB1', 'AB7', 'AB8', 'AB4', 'AB9']}
# 15844
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB6', 'remaining_zones': ['1', '2', '3', '4', '5', '7', '8', '9'], 'visited_zones': ['0', '6'], 'total_cost': 179, 'path': ['AB0', 'AB6']}
# {'current_day': 3, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '4', '5', '7', '8', '9'], 'visited_zones': ['0', '6', '2'], 'total_cost': 381, 'path': ['AB0', 'AB6', 'AB2']}
# {'current_day': 4, 'current_airport': 'AB5', 'remaining_zones': ['1', '3', '4', '7', '8', '9'], 'visited_zones': ['0', '6', '2', '5'], 'total_cost': 537, 'path': ['AB0', 'AB6', 'AB2', 'AB5']}
# {'current_day': 5, 'current_airport': 'AB8', 'remaining_zones': ['1', '3', '4', '7', '9'], 'visited_zones': ['0', '6', '2', '5', '8'], 'total_cost': 3741, 'path': ['AB0', 'AB6', 'AB2', 'AB5', 'AB8']}
# {'current_day': 6, 'current_airport': 'AB3', 'remaining_zones': ['1', '4', '7', '9'], 'visited_zones': ['0', '6', '2', '5', '8', '3'], 'total_cost': 3942, 'path': ['AB0', 'AB6', 'AB2', 'AB5', 'AB8', 'AB3']}
# {'current_day': 7, 'current_airport': 'AB9', 'remaining_zones': ['1', '4', '7'], 'visited_zones': ['0', '6', '2', '5', '8', '3', '9'], 'total_cost': 4161, 'path': ['AB0', 'AB6', 'AB2', 'AB5', 'AB8', 'AB3', 'AB9']}
# {'current_day': 8, 'current_airport': 'AB4', 'remaining_zones': ['1', '7'], 'visited_zones': ['0', '6', '2', '5', '8', '3', '9', '4'], 'total_cost': 4358, 'path': ['AB0', 'AB6', 'AB2', 'AB5', 'AB8', 'AB3', 'AB9', 'AB4']}
# {'current_day': 9, 'current_airport': 'AB1', 'remaining_zones': ['7'], 'visited_zones': ['0', '6', '2', '5', '8', '3', '9', '4', '1'], 'total_cost': 9656, 'path': ['AB0', 'AB6', 'AB2', 'AB5', 'AB8', 'AB3', 'AB9', 'AB4', 'AB1']}
# 9941
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB9', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8'], 'visited_zones': ['0', '9'], 'total_cost': 103, 'path': ['AB0', 'AB9']}
# {'current_day': 3, 'current_airport': 'AB4', 'remaining_zones': ['1', '2', '3', '5', '6', '7', '8'], 'visited_zones': ['0', '9', '4'], 'total_cost': 320, 'path': ['AB0', 'AB9', 'AB4']}
# {'current_day': 4, 'current_airport': 'AB1', 'remaining_zones': ['2', '3', '5', '6', '7', '8'], 'visited_zones': ['0', '9', '4', '1'], 'total_cost': 2913, 'path': ['AB0', 'AB9', 'AB4', 'AB1']}
# {'current_day': 5, 'current_airport': 'AB6', 'remaining_zones': ['2', '3', '5', '7', '8'], 'visited_zones': ['0', '9', '4', '1', '6'], 'total_cost': 3152, 'path': ['AB0', 'AB9', 'AB4', 'AB1', 'AB6']}
# ...
# {'current_day': 4, 'current_airport': 'AB1', 'remaining_zones': ['2', '3', '4', '5', '7', '9'], 'visited_zones': ['0', '6', '8', '1'], 'total_cost': 2908, 'path': ['AB0', 'AB6', 'AB8', 'AB1']}
# {'current_day': 5, 'current_airport': 'AB3', 'remaining_zones': ['2', '4', '5', '7', '9'], 'visited_zones': ['0', '6', '8', '1', '3'], 'total_cost': 6864, 'path': ['AB0', 'AB6', 'AB8', 'AB1', 'AB3']}
# {'current_day': 6, 'current_airport': 'AB7', 'remaining_zones': ['2', '4', '5', '9'], 'visited_zones': ['0', '6', '8', '1', '3', '7'], 'total_cost': 7126, 'path': ['AB0', 'AB6', 'AB8', 'AB1', 'AB3', 'AB7']}
# {'current_day': 7, 'current_airport': 'AB4', 'remaining_zones': ['2', '5', '9'], 'visited_zones': ['0', '6', '8', '1', '3', '7', '4'], 'total_cost': 7421, 'path': ['AB0', 'AB6', 'AB8', 'AB1', 'AB3', 'AB7', 'AB4']}
# {'current_day': 8, 'current_airport': 'AB9', 'remaining_zones': ['2', '5'], 'visited_zones': ['0', '6', '8', '1', '3', '7', '4', '9'], 'total_cost': 7584, 'path': ['AB0', 'AB6', 'AB8', 'AB1', 'AB3', 'AB7', 'AB4', 'AB9']}
# {'current_day': 9, 'current_airport': 'AB5', 'remaining_zones': ['2'], 'visited_zones': ['0', '6', '8', '1', '3', '7', '4', '9', '5'], 'total_cost': 10141, 'path': ['AB0', 'AB6', 'AB8', 'AB1', 'AB3', 'AB7', 'AB4', 'AB9', 'AB5']}
# 10260
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB6', 'remaining_zones': ['1', '2', '3', '4', '5', '7', '8', '9'], 'visited_zones': ['0', '6'], 'total_cost': 179, 'path': ['AB0', 'AB6']}
# {'current_day': 3, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '3', '4', '5', '7', '9'], 'visited_zones': ['0', '6', '8'], 'total_cost': 2721, 'path': ['AB0', 'AB6', 'AB8']}
# {'current_day': 4, 'current_airport': 'AB3', 'remaining_zones': ['1', '2', '4', '5', '7', '9'], 'visited_zones': ['0', '6', '8', '3'], 'total_cost': 2924, 'path': ['AB0', 'AB6', 'AB8', 'AB3']}
# {'current_day': 5, 'current_airport': 'AB7', 'remaining_zones': ['1', '2', '4', '5', '9'], 'visited_zones': ['0', '6', '8', '3', '7'], 'total_cost': 3148, 'path': ['AB0', 'AB6', 'AB8', 'AB3', 'AB7']}
# {'current_day': 6, 'current_airport': 'AB2', 'remaining_zones': ['1', '4', '5', '9'], 'visited_zones': ['0', '6', '8', '3', '7', '2'], 'total_cost': 3274, 'path': ['AB0', 'AB6', 'AB8', 'AB3', 'AB7', 'AB2']}
# {'current_day': 7, 'current_airport': 'AB9', 'remaining_zones': ['1', '4', '5'], 'visited_zones': ['0', '6', '8', '3', '7', '2', '9'], 'total_cost': 3386, 'path': ['AB0', 'AB6', 'AB8', 'AB3', 'AB7', 'AB2', 'AB9']}
# {'current_day': 8, 'current_airport': 'AB4', 'remaining_zones': ['1', '5'], 'visited_zones': ['0', '6', '8', '3', '7', '2', '9', '4'], 'total_cost': 3583, 'path': ['AB0', 'AB6', 'AB8', 'AB3', 'AB7', 'AB2', 'AB9', 'AB4']}
# {'current_day': 9, 'current_airport': 'AB1', 'remaining_zones': ['5'], 'visited_zones': ['0', '6', '8', '3', '7', '2', '9', '4', '1'], 'total_cost': 8881, 'path': ['AB0', 'AB6', 'AB8', 'AB3', 'AB7', 'AB2', 'AB9', 'AB4', 'AB1']}
# 9134
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB9', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8'], 'visited_zones': ['0', '9'], 'total_cost': 103, 'path': ['AB0', 'AB9']}
# {'current_day': 3, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '4', '5', '6', '7', '8'], 'visited_zones': ['0', '9', '2'], 'total_cost': 308, 'path': ['AB0', 'AB9', 'AB2']}
# {'current_day': 4, 'current_airport': 'AB6', 'remaining_zones': ['1', '3', '4', '5', '7', '8'], 'visited_zones': ['0', '9', '2', '6'], 'total_cost': 603, 'path': ['AB0', 'AB9', 'AB2', 'AB6']}
# {'current_day': 5, 'current_airport': 'AB7', 'remaining_zones': ['1', '3', '4', '5', '8'], 'visited_zones': ['0', '9', '2', '6', '7'], 'total_cost': 2919, 'path': ['AB0', 'AB9', 'AB2', 'AB6', 'AB7']}
# {'current_day': 6, 'current_airport': 'AB1', 'remaining_zones': ['3', '4', '5', '8'], 'visited_zones': ['0', '9', '2', '6', '7', '1'], 'total_cost': 3194, 'path': ['AB0', 'AB9', 'AB2', 'AB6', 'AB7', 'AB1']}
# {'current_day': 7, 'current_airport': 'AB8', 'remaining_zones': ['3', '4', '5'], 'visited_zones': ['0', '9', '2', '6', '7', '1', '8'], 'total_cost': 3295, 'path': ['AB0', 'AB9', 'AB2', 'AB6', 'AB7', 'AB1', 'AB8']}
# {'current_day': 8, 'current_airport': 'AB5', 'remaining_zones': ['3', '4'], 'visited_zones': ['0', '9', '2', '6', '7', '1', '8', '5'], 'total_cost': 5859, 'path': ['AB0', 'AB9', 'AB2', 'AB6', 'AB7', 'AB1', 'AB8', 'AB5']}
# {'current_day': 9, 'current_airport': 'AB3', 'remaining_zones': ['4'], 'visited_zones': ['0', '9', '2', '6', '7', '1', '8', '5', '3'], 'total_cost': 5959, 'path': ['AB0', 'AB9', 'AB2', 'AB6', 'AB7', 'AB1', 'AB8', 'AB5', 'AB3']}
# 11465
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB3', 'remaining_zones': ['1', '2', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '3'], 'total_cost': 4618, 'path': ['AB0', 'AB3']}
# {'current_day': 3, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '4', '5', '6', '7', '9'], 'visited_zones': ['0', '3', '8'], 'total_cost': 4770, 'path': ['AB0', 'AB3', 'AB8']}
# {'current_day': 4, 'current_airport': 'AB5', 'remaining_zones': ['1', '2', '4', '6', '7', '9'], 'visited_zones': ['0', '3', '8', '5'], 'total_cost': 7656, 'path': ['AB0', 'AB3', 'AB8', 'AB5']}
# {'current_day': 5, 'current_airport': 'AB9', 'remaining_zones': ['1', '2', '4', '6', '7'], 'visited_zones': ['0', '3', '8', '5', '9'], 'total_cost': 12623, 'path': ['AB0', 'AB3', 'AB8', 'AB5', 'AB9']}
# {'current_day': 6, 'current_airport': 'AB4', 'remaining_zones': ['1', '2', '6', '7'], 'visited_zones': ['0', '3', '8', '5', '9', '4'], 'total_cost': 12886, 'path': ['AB0', 'AB3', 'AB8', 'AB5', 'AB9', 'AB4']}
# {'current_day': 7, 'current_airport': 'AB7', 'remaining_zones': ['1', '2', '6'], 'visited_zones': ['0', '3', '8', '5', '9', '4', '7'], 'total_cost': 13113, 'path': ['AB0', 'AB3', 'AB8', 'AB5', 'AB9', 'AB4', 'AB7']}
# {'current_day': 8, 'current_airport': 'AB6', 'remaining_zones': ['1', '2'], 'visited_zones': ['0', '3', '8', '5', '9', '4', '7', '6'], 'total_cost': 14122, 'path': ['AB0', 'AB3', 'AB8', 'AB5', 'AB9', 'AB4', 'AB7', 'AB6']}
# {'current_day': 9, 'current_airport': 'AB2', 'remaining_zones': ['1'], 'visited_zones': ['0', '3', '8', '5', '9', '4', '7', '6', '2'], 'total_cost': 14349, 'path': ['AB0', 'AB3', 'AB8', 'AB5', 'AB9', 'AB4', 'AB7', 'AB6', 'AB2']}
# 16848
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB9', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8'], 'visited_zones': ['0', '9'], 'total_cost': 103, 'path': ['AB0', 'AB9']}
# {'current_day': 3, 'current_airport': 'AB4', 'remaining_zones': ['1', '2', '3', '5', '6', '7', '8'], 'visited_zones': ['0', '9', '4'], 'total_cost': 320, 'path': ['AB0', 'AB9', 'AB4']}
# {'current_day': 4, 'current_airport': 'AB6', 'remaining_zones': ['1', '2', '3', '5', '7', '8'], 'visited_zones': ['0', '9', '4', '6'], 'total_cost': 458, 'path': ['AB0', 'AB9', 'AB4', 'AB6']}
# {'current_day': 5, 'current_airport': 'AB5', 'remaining_zones': ['1', '2', '3', '7', '8'], 'visited_zones': ['0', '9', '4', '6', '5'], 'total_cost': 5199, 'path': ['AB0', 'AB9', 'AB4', 'AB6', 'AB5']}
# {'current_day': 6, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '7', '8'], 'visited_zones': ['0', '9', '4', '6', '5', '2'], 'total_cost': 5431, 'path': ['AB0', 'AB9', 'AB4', 'AB6', 'AB5', 'AB2']}
# {'current_day': 7, 'current_airport': 'AB1', 'remaining_zones': ['3', '7', '8'], 'visited_zones': ['0', '9', '4', '6', '5', '2', '1'], 'total_cost': 9618, 'path': ['AB0', 'AB9', 'AB4', 'AB6', 'AB5', 'AB2', 'AB1']}
# {'current_day': 8, 'current_airport': 'AB8', 'remaining_zones': ['3', '7'], 'visited_zones': ['0', '9', '4', '6', '5', '2', '1', '8'], 'total_cost': 9853, 'path': ['AB0', 'AB9', 'AB4', 'AB6', 'AB5', 'AB2', 'AB1', 'AB8']}
# {'current_day': 9, 'current_airport': 'AB7', 'remaining_zones': ['3'], 'visited_zones': ['0', '9', '4', '6', '5', '2', '1', '8', '7'], 'total_cost': 12297, 'path': ['AB0', 'AB9', 'AB4', 'AB6', 'AB5', 'AB2', 'AB1', 'AB8', 'AB7']}
# 12545
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB6', 'remaining_zones': ['1', '2', '3', '4', '5', '7', '8', '9'], 'visited_zones': ['0', '6'], 'total_cost': 179, 'path': ['AB0', 'AB6']}
# {'current_day': 3, 'current_airport': 'AB7', 'remaining_zones': ['1', '2', '3', '4', '5', '8', '9'], 'visited_zones': ['0', '6', '7'], 'total_cost': 4564, 'path': ['AB0', 'AB6', 'AB7']}
# {'current_day': 4, 'current_airport': 'AB5', 'remaining_zones': ['1', '2', '3', '4', '8', '9'], 'visited_zones': ['0', '6', '7', '5'], 'total_cost': 7562, 'path': ['AB0', 'AB6', 'AB7', 'AB5']}
# {'current_day': 5, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '4', '8', '9'], 'visited_zones': ['0', '6', '7', '5', '2'], 'total_cost': 7796, 'path': ['AB0', 'AB6', 'AB7', 'AB5', 'AB2']}
# {'current_day': 6, 'current_airport': 'AB8', 'remaining_zones': ['1', '3', '4', '9'], 'visited_zones': ['0', '6', '7', '5', '2', '8'], 'total_cost': 8037, 'path': ['AB0', 'AB6', 'AB7', 'AB5', 'AB2', 'AB8']}
# {'current_day': 7, 'current_airport': 'AB9', 'remaining_zones': ['1', '3', '4'], 'visited_zones': ['0', '6', '7', '5', '2', '8', '9'], 'total_cost': 13752, 'path': ['AB0', 'AB6', 'AB7', 'AB5', 'AB2', 'AB8', 'AB9']}
# {'current_day': 8, 'current_airport': 'AB4', 'remaining_zones': ['1', '3'], 'visited_zones': ['0', '6', '7', '5', '2', '8', '9', '4'], 'total_cost': 13949, 'path': ['AB0', 'AB6', 'AB7', 'AB5', 'AB2', 'AB8', 'AB9', 'AB4']}
# {'current_day': 9, 'current_airport': 'AB3', 'remaining_zones': ['1'], 'visited_zones': ['0', '6', '7', '5', '2', '8', '9', '4', '3'], 'total_cost': 15527, 'path': ['AB0', 'AB6', 'AB7', 'AB5', 'AB2', 'AB8', 'AB9', 'AB4', 'AB3']}
# 19256
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB3', 'remaining_zones': ['1', '2', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '3'], 'total_cost': 4618, 'path': ['AB0', 'AB3']}
# {'current_day': 3, 'current_airport': 'AB4', 'remaining_zones': ['1', '2', '5', '6', '7', '8', '9'], 'visited_zones': ['0', '3', '4'], 'total_cost': 8061, 'path': ['AB0', 'AB3', 'AB4']}
# {'current_day': 4, 'current_airport': 'AB7', 'remaining_zones': ['1', '2', '5', '6', '8', '9'], 'visited_zones': ['0', '3', '4', '7'], 'total_cost': 8258, 'path': ['AB0', 'AB3', 'AB4', 'AB7']}
# {'current_day': 5, 'current_airport': 'AB1', 'remaining_zones': ['2', '5', '6', '8', '9'], 'visited_zones': ['0', '3', '4', '7', '1'], 'total_cost': 8421, 'path': ['AB0', 'AB3', 'AB4', 'AB7', 'AB1']}
# {'current_day': 6, 'current_airport': 'AB6', 'remaining_zones': ['2', '5', '8', '9'], 'visited_zones': ['0', '3', '4', '7', '1', '6'], 'total_cost': 8531, 'path': ['AB0', 'AB3', 'AB4', 'AB7', 'AB1', 'AB6']}
# {'current_day': 7, 'current_airport': 'AB8', 'remaining_zones': ['2', '5', '9'], 'visited_zones': ['0', '3', '4', '7', '1', '6', '8'], 'total_cost': 10788, 'path': ['AB0', 'AB3', 'AB4', 'AB7', 'AB1', 'AB6', 'AB8']}
# {'current_day': 8, 'current_airport': 'AB2', 'remaining_zones': ['5', '9'], 'visited_zones': ['0', '3', '4', '7', '1', '6', '8', '2'], 'total_cost': 11000, 'path': ['AB0', 'AB3', 'AB4', 'AB7', 'AB1', 'AB6', 'AB8', 'AB2']}
# {'current_day': 9, 'current_airport': 'AB5', 'remaining_zones': ['9'], 'visited_zones': ['0', '3', '4', '7', '1', '6', '8', '2', '5'], 'total_cost': 11194, 'path': ['AB0', 'AB3', 'AB4', 'AB7', 'AB1', 'AB6', 'AB8', 'AB2', 'AB5']}
# 12335
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB5', 'remaining_zones': ['1', '2', '3', '4', '6', '7', '8', '9'], 'visited_zones': ['0', '5'], 'total_cost': 173, 'path': ['AB0', 'AB5']}
# {'current_day': 3, 'current_airport': 'AB6', 'remaining_zones': ['1', '2', '3', '4', '7', '8', '9'], 'visited_zones': ['0', '5', '6'], 'total_cost': 4971, 'path': ['AB0', 'AB5', 'AB6']}
# {'current_day': 4, 'current_airport': 'AB8', 'remaining_zones': ['1', '2', '3', '4', '7', '9'], 'visited_zones': ['0', '5', '6', '8'], 'total_cost': 9193, 'path': ['AB0', 'AB5', 'AB6', 'AB8']}
# {'current_day': 5, 'current_airport': 'AB4', 'remaining_zones': ['1', '2', '3', '7', '9'], 'visited_zones': ['0', '5', '6', '8', '4'], 'total_cost': 9435, 'path': ['AB0', 'AB5', 'AB6', 'AB8', 'AB4']}
# {'current_day': 6, 'current_airport': 'AB7', 'remaining_zones': ['1', '2', '3', '9'], 'visited_zones': ['0', '5', '6', '8', '4', '7'], 'total_cost': 9612, 'path': ['AB0', 'AB5', 'AB6', 'AB8', 'AB4', 'AB7']}
# {'current_day': 7, 'current_airport': 'AB2', 'remaining_zones': ['1', '3', '9'], 'visited_zones': ['0', '5', '6', '8', '4', '7', '2'], 'total_cost': 9805, 'path': ['AB0', 'AB5', 'AB6', 'AB8', 'AB4', 'AB7', 'AB2']}
# {'current_day': 8, 'current_airport': 'AB1', 'remaining_zones': ['3', '9'], 'visited_zones': ['0', '5', '6', '8', '4', '7', '2', '1'], 'total_cost': 12648, 'path': ['AB0', 'AB5', 'AB6', 'AB8', 'AB4', 'AB7', 'AB2', 'AB1']}
# {'current_day': 9, 'current_airport': 'AB9', 'remaining_zones': ['3'], 'visited_zones': ['0', '5', '6', '8', '4', '7', '2', '1', '9'], 'total_cost': 12774, 'path': ['AB0', 'AB5', 'AB6', 'AB8', 'AB4', 'AB7', 'AB2', 'AB1', 'AB9']}
# 12928
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 2, 'current_airport': 'AB7', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '8', '9'], 'visited_zones': ['0', '7'], 'total_cost': 192, 'path': ['AB0', 'AB7']}
# {'current_day': 3, 'current_airport': 'AB4', 'remaining_zones': ['1', '2', '3', '5', '6', '8', '9'], 'visited_zones': ['0', '7', '4'], 'total_cost': 329, 'path': ['AB0', 'AB7', 'AB4']}
# {'current_day': 4, 'current_airport': 'AB9', 'remaining_zones': ['1', '2', '3', '5', '6', '8'], 'visited_zones': ['0', '7', '4', '9'], 'total_cost': 504, 'path': ['AB0', 'AB7', 'AB4', 'AB9']}
# {'current_day': 5, 'current_airport': 'AB1', 'remaining_zones': ['2', '3', '5', '6', '8'], 'visited_zones': ['0', '7', '4', '9', '1'], 'total_cost': 618, 'path': ['AB0', 'AB7', 'AB4', 'AB9', 'AB1']}
# {'current_day': 6, 'current_airport': 'AB5', 'remaining_zones': ['2', '3', '6', '8'], 'visited_zones': ['0', '7', '4', '9', '1', '5'], 'total_cost': 869, 'path': ['AB0', 'AB7', 'AB4', 'AB9', 'AB1', 'AB5']}
# {'current_day': 7, 'current_airport': 'AB6', 'remaining_zones': ['2', '3', '8'], 'visited_zones': ['0', '7', '4', '9', '1', '5', '6'], 'total_cost': 2758, 'path': ['AB0', 'AB7', 'AB4', 'AB9', 'AB1', 'AB5', 'AB6']}
# {'current_day': 8, 'current_airport': 'AB2', 'remaining_zones': ['3', '8'], 'visited_zones': ['0', '7', '4', '9', '1', '5', '6', '2'], 'total_cost': 3023, 'path': ['AB0', 'AB7', 'AB4', 'AB9', 'AB1', 'AB5', 'AB6', 'AB2']}
# {'current_day': 9, 'current_airport': 'AB3', 'remaining_zones': ['8'], 'visited_zones': ['0', '7', '4', '9', '1', '5', '6', '2', '3'], 'total_cost': 7531, 'path': ['AB0', 'AB7', 'AB4', 'AB9', 'AB1', 'AB5', 'AB6', 'AB2', 'AB3']}
# 7705
# {'current_day': 10, 'current_airport': 'AB6', 'remaining_zones': [], 'visited_zones': ['0', '7', '2', '9', '1', '8', '4', '5', '3', '6'], 'total_cost': 1471, 'path': ['AB0', 'AB7', 'AB2', 'AB9', 'AB1', 'AB8', 'AB4', 'AB5', 'AB3', 'AB6']} 1471

# %% [markdown]
# #### GPT NOT SURE

# %%
class MCTS(data_preprocessing):
    def __init__(self, instance, root_state, iterations):
        super().__init__(instance_path=instance)
        self.root = Node(root_state)
        self.iterations = iterations
        self.best_leaf = None
        self.best_leaf_cost = float('inf')
        
    def expand_node(self, node):
        actions = self.possible_flights_from_an_airport_at_a_specific_day_with_previous_areas(
            node.state['current_day'], node.state['current_airport'], node.state['visited_zones'])

        for action in actions:
            new_state = self.transition_function(node.state, action)
            node.add_child(new_state)
            
    def transition_function(self, state, action):
        new_state = deepcopy(state)  # Deep copy to avoid side effects
        new_state['current_day'] += 1
        new_state['current_airport'] = action[0]
        new_state['total_cost'] += action[1]
        new_state['path'].append(action[0])
        new_state['remaining_zones'].remove(self.associated_area_to_airport(airport=new_state['current_airport']))
        new_state['visited_zones'].append(self.associated_area_to_airport(airport=action[0]))
        return new_state

    def random_policy(self, state):
        actions = self.possible_flights_from_an_airport_at_a_specific_day_with_previous_areas(
            day=state['current_day'], from_airport=state['current_airport'], visited_areas=state['visited_zones']
        )
        return random.choice(actions)
    
    def select(self, node):
        current_node = node
        while current_node.is_fully_expanded() and current_node.children:
            current_node = current_node.best_child()
        return current_node

    def simulate(self, node):
        current_simulation_state = deepcopy(node.state)
        while current_simulation_state['current_day'] != self.number_of_areas:
            action = self.random_policy(current_simulation_state)
            current_simulation_state = self.transition_function(current_simulation_state, action)
            
        if current_simulation_state['total_cost'] < self.best_leaf_cost:
            self.best_leaf = current_simulation_state
            self.best_leaf_cost = current_simulation_state['total_cost']
        
        return current_simulation_state['total_cost']

    def backpropagate(self, node, cost):
        current_node = node
        while current_node is not None:
            current_node.visit_count += 1
            current_node.total_cost += cost
            current_node = current_node.parent

    def search(self):
        for _ in range(self.iterations):
            node_to_explore = self.select(self.root)
            print(node_to_explore.state)
            if not node_to_explore.is_fully_expanded():
                self.expand_node(node_to_explore)
            cost = self.simulate(node_to_explore)
            self.backpropagate(node_to_explore, cost)
        
        return self.best_leaf, self.best_leaf_cost

instance_path = 'Flight connections dataset/1.in'
data_processor = data_preprocessing(instance_path=instance_path)

# Define root state
root_state = {
    'current_day': 1,
    'current_airport': data_processor.starting_airport,
    'remaining_zones': [x for x in data_processor.list_areas if x != data_processor.starting_area],  # Exclude the starting area
    'visited_zones': [data_processor.starting_area],  # Exclude the starting area
    'total_cost': 0,
    'path': [data_processor.starting_airport]
}

for k in range(1):
    mcts = MCTS(instance=instance_path, root_state=root_state, iterations=1000)
    # mcts = MCTS(instance=instance, root_state=root_state, iterations=1000)
    best_path, best_cost = mcts.search()
    print(f"Best Path: {best_path}, Best Cost: {best_cost}")
# Out:
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# ...
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# {'current_day': 1, 'current_airport': 'AB0', 'remaining_zones': ['1', '2', '3', '4', '5', '6', '7', '8', '9'], 'visited_zones': ['0'], 'total_cost': 0, 'path': ['AB0']}
# Best Path: {'current_day': 10, 'current_airport': 'AB8', 'remaining_zones': [], 'visited_zones': ['0', '5', '1', '7', '3', '6', '2', '9', '4', '8'], 'total_cost': 1588, 'path': ['AB0', 'AB5', 'AB1', 'AB7', 'AB3', 'AB6', 'AB2', 'AB9', 'AB4', 'AB8']}, Best Cost: 1588
